# %%
using Pkg
# cd("D:\\Home\\Git\\Oceananigans.jl")
# cd("C:\\Users\\Ali\\Documents\\Git\\Oceananigans.jl\\")
cd("/home/gridsan/aramadhan/Oceananigans.jl/")
Pkg.activate(".");

# %%
using Oceananigans

# %%
include("examples/deep_convection_3d.jl")
# Out:
# make_temperature_movies (generic function with 1 method)

# %%
deep_convection_3d()
# Out:
# Planning Fourier transforms... (planner_flag=FFTW.PATIENT)
# FFT!:    1.036234 seconds (44 allocations: 3.031 KiB)
# IFFT!:   1.061746 seconds (16.69 k allocations: 724.969 KiB)
# DCT!:    0.192741 seconds (11.64 k allocations: 605.602 KiB)
# IDCT!:   0.183356 seconds (11.07 k allocations: 568.633 KiB)
# [FieldWriter] Writing T to disk: ./deep_convection_3d_T_000000000000.dat
# model.clock.time = 2000 / 30000
# [FieldWriter] Writing T to disk: ./deep_convection_3d_T_000000002000.dat
# model.clock.time = 4000 / 30000
# [FieldWriter] Writing T to disk: ./deep_convection_3d_T_000000004000.dat
# model.clock.time = 6000 / 30000
# [FieldWriter] Writing T to disk: ./deep_convection_3d_T_000000006000.dat
# model.clock.time = 8000 / 30000
# [FieldWriter] Writing T to disk: ./deep_convection_3d_T_000000008000.dat
# model.clock.time = 10000 / 30000
# [FieldWriter] Writing T to disk: ./deep_convection_3d_T_000000010000.dat
# model.clock.time = 12000 / 30000
# [FieldWriter] Writing T to disk: ./deep_convection_3d_T_000000012000.dat
# model.clock.time = 14000 / 30000
# [FieldWriter] Writing T to disk: ./deep_convection_3d_T_000000014000.dat
# model.clock.time = 16000 / 30000
# [FieldWriter] Writing T to disk: ./deep_convection_3d_T_000000016000.dat
# model.clock.time = 18000 / 30000
# [FieldWriter] Writing T to disk: ./deep_convection_3d_T_000000018000.dat
# model.clock.time = 20000 / 30000
# [FieldWriter] Writing T to disk: ./deep_convection_3d_T_000000020000.dat
# model.clock.time = 22000 / 30000
# [FieldWriter] Writing T to disk: ./deep_convection_3d_T_000000022000.dat
# model.clock.time = 24000 / 30000
# [FieldWriter] Writing T to disk: ./deep_convection_3d_T_000000024000.dat
# model.clock.time = 26000 / 30000
# [FieldWriter] Writing T to disk: ./deep_convection_3d_T_000000026000.dat
# model.clock.time = 28000 / 30000
# [FieldWriter] Writing T to disk: ./deep_convection_3d_T_000000028000.dat
# model.clock.time = 30000 / 30000
# [FieldWriter] Writing T to disk: ./deep_convection_3d_T_000000030000.dat
# Creating temperature movie... (15 frames)
# frame = 15 / 15
# IOError: could not spawn `ffmpeg -v 0 -framerate 30 -loop 0 -i /state/partition1/slurm_tmp/161750.0.0/tmpCvVJTu/%06d.png -pix_fmt yuv420p -y /home/gridsan/aramadhan/Oceananigans.jl/deep_convection_3d_1550450259.mp4`: no such file or directory (ENOENT)
#
# Stacktrace:
#  [1] _spawn_primitive(::String, ::Cmd, ::Array{Any,1}) at ./process.jl:400
#  [2] setup_stdios(::getfield(Base, Symbol("##505#506")){Cmd}, ::Array{Any,1}) at ./process.jl:413
#  [3] _spawn at ./process.jl:412 [inlined]
#  [4] #run#515(::Bool, ::Function, ::Cmd) at ./process.jl:725
#  [5] run at ./process.jl:724 [inlined]
#  [6] #buildanimation#245(::Int64, ::Int64, ::Bool, ::Bool, ::Function, ::String, ::String, ::Bool) at /home/gridsan/aramadhan/.julia/packages/Plots/UQI78/src/animation.jl:87
#  [7] #buildanimation at ./none:0 [inlined]
#  [8] #mp4#244 at /home/gridsan/aramadhan/.julia/packages/Plots/UQI78/src/animation.jl:65 [inlined]
#  [9] #mp4 at ./none:0 [inlined]
#  [10] make_temperature_movies(::Model, ::FieldWriter) at /home/gridsan/aramadhan/Oceananigans.jl/examples/deep_convection_3d.jl:92
#  [11] deep_convection_3d() at /home/gridsan/aramadhan/Oceananigans.jl/examples/deep_convection_3d.jl:18
#  [12] top-level scope at In[5]:1

# %%
fio = open("./deep_convection_3d_T_000000030000.dat", "r")
arr = zeros(Float32, 100, 100, 50)
read!(fio, arr);

# %%
import PyPlot

# %%
PyPlot.pcolormesh(1:100, 1:100, arr[:, :, 1] .- 293.15)
PyPlot.colorbar()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f7e8f67a518>)
# PyObject <matplotlib.colorbar.Colorbar object at 0x7f7e8f61b908>

# %%
PyPlot.pcolormesh(1:100, 1:50, rotl90(arr[50, :, :]) .- 293.15)
PyPlot.colorbar()
PyPlot.axes()[:set_aspect]("equal")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f7e8f4bc518>)
