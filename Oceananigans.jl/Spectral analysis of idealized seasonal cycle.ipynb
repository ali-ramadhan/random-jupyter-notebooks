# %%
import os
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.colors as colors

from numpy import pi
from scipy.fftpack import fftn

# %%
os.environ["HDF5_USE_FILE_LOCKING"] = "FALSE"

# %%
plt.rcParams['figure.dpi'] = 200
plt.style.use("dark_background")

# %%
def fp(n):
    return "/home/gridsan/aramadhan/isc/idealized_seasonal_cycle_N256_dTdz0.01_k0.0001_dt3_c3_T7776000/idealized_seasonal_cycle_N256_dTdz0.01_k0.0001_dt3_c3_T7776000_" + str(n) + ".nc"

# %%
n = 265
ds = xr.open_dataset(fp(n))

# %%
xC = ds["xC"].values
Δx = xC[1] - xC[0]
λ = [2*pi/k for k in range(1, 256)]

# %%
u = ds["u"].values
v = ds["v"].values
w = ds["w"].values
T = ds["T"].values

ũ = fftn(u, axes=[1, 2])
ṽ = fftn(v, axes=[1, 2])
w̃ = fftn(w, axes=[1, 2])
T̃ = fftn(T, axes=[1, 2])

# %%
plt.pcolormesh(abs(T̃[150, :, :]), vmin=0, vmax=10)
plt.colorbar()

# %%
plt.pcolormesh(abs(ũ[150, :, :]), vmin=0, vmax=10)
plt.colorbar()

# %%
plt.pcolormesh(abs(ṽ[150, :, :]), vmin=0, vmax=10)
plt.colorbar()

# %%
plt.pcolormesh(abs(w̃[150, :, :]), vmin=0, vmax=10)
plt.colorbar()
