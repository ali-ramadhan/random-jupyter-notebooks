# %%
using WebIO, Interact, PyPlot

# %%
# cd("D:\\Home\\Git\\OceanDispatch.jl\\")
cd("C:\\Users\\Ali\\Documents\\Git\\OceanDispatch.jl\\")
pwd()
# Out:
# "C:\\Users\\Ali\\Documents\\Git\\OceanDispatch.jl"

# %%
include("examples\\deep_convection.jl")
# Out:
# ┌ Info: Ocean LES model parameters:
# │ NumType: Float64
# │ (Nˣ, Nʸ, Nᶻ) = (100, 100, 100) [#]
# │ (Lˣ, Lʸ, Lᶻ) = (2000, 2000, 2000) [m]
# │ (Δx, Δy, Δz) = (20.0, 20.0, 20.0) [m]
# │ (Aˣ, Aʸ, Aᶻ) = (400.0, 400.0, 400.0) [m²]
# │ V = 8000.0 [m³]
# │ M = 8.216e6 [kg]
# │ Nᵗ = 20 [s]
# │ Δt = 1 [s]
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:130
# ┌ Info: T₀[50, 50, 1] = 283 K
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:178
# ┌ Info: Temperature source term:
# │ div_flux:  mean=0, absmean=0, std=0
# │ lap_diff:  mean=0, absmean=0, std=0
# │ Fᵀ[:,:,1]: mean=-2.60126e-06, absmean=2.60126e-06, std=4.14276e-06
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:216
# ┌ Info: Salinity source term:
# │ div_flux:  mean=0, absmean=0, std=0
# │ lap_diff:  mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:226
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:246
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=0, max=0, mean=0, absmean=0, std=0
# │ RHS_rec: min=0, max=0, mean=0, absmean=0, std=0
# │ error:   min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:274
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:293
# ┌ Info: Time: 1
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -1.46525e-05 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=0, max=0, mean=0, absmean=0, std=0
# │ vⁿ:   min=0, max=0, mean=0, absmean=0, std=0
# │ wⁿ:   min=0, max=0, mean=0, absmean=0, std=0
# │ Tⁿ:   min=283, max=283, mean=283, absmean=283, std=7.81542e-07
# │ Sⁿ:   min=35, max=35, mean=35, absmean=35, std=0
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-0, max=-0, mean=0, absmean=0, std=0
# │ pⁿʰ⁺ˢ:min=0, max=0, mean=0, absmean=0, std=0
# │ pⁿ:   min=0, max=0, mean=0, absmean=0, std=0
# │ ρⁿ:   min=1027, max=1027, mean=1027, absmean=1027, std=0
# │ δρ:   min=0, max=0, mean=0, absmean=0, std=0
# │ Gᵘⁿ⁺ʰ: min=0, max=0, mean=0, absmean=0, std=0
# │ Gᵛⁿ⁺ʰ: min=0, max=0, mean=0, absmean=0, std=0
# │ Gʷⁿ⁺ʰ: min=0, max=0, mean=0, absmean=0, std=0
# │ Gᵀⁿ⁺ʰ: min=-1.48107e-05, max=0, mean=-4.16202e-08, absmean=4.16202e-08, std=7.81542e-07
# │ Gˢⁿ⁺ʰ: min=0, max=0, mean=0, absmean=0, std=0
# │ ∇⋅u1:  min=0, max=0, mean=0, absmean=0, std=0
# │ ∇⋅u2:  min=0, max=0, mean=0, absmean=0, std=0
# │ wSurf: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:314
# ┌ Info: Temperature source term:
# │ div_flux:  mean=0, absmean=0, std=0
# │ lap_diff:  mean=0, absmean=9.03052e-12, std=1.22225e-10
# │ Fᵀ[:,:,1]: mean=-2.60126e-06, absmean=2.60126e-06, std=4.14276e-06
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:216
# ┌ Info: Salinity source term:
# │ div_flux:  mean=0, absmean=0, std=0
# │ lap_diff:  mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:226
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:246
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-3.9199e-09, max=3.87884e-09, mean=5.0458e-28, absmean=9.89687e-11, std=5.29837e-10
# │ RHS_rec: min=-3.9199e-09, max=3.87884e-09, mean=-4.32615e-28, absmean=9.89687e-11, std=5.29837e-10
# │ error:   min=-6.14327e-24, max=5.91951e-24, mean=-4.07998e-28, absmean=6.71418e-25, std=9.30046e-25
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:274
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-1.63444e-12, max=3.10778e-12, mean=4.59499e-26, absmean=1.06827e-12, std=1.27783e-12
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:293
# ┌ Info: Time: 2
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -2.38081e-05 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-6.99938e-09, max=7.00062e-09, mean=-1.2639e-27, absmean=6.25034e-12, std=8.89611e-11
# │ vⁿ:   min=-7.00566e-09, max=7.0022e-09, mean=-2.84018e-27, absmean=6.25073e-12, std=8.89709e-11
# │ wⁿ:   min=-6.12797e-09, max=6.26062e-09, mean=-6.68918e-28, absmean=9.70957e-12, std=1.05637e-10
# │ Tⁿ:   min=283, max=283, mean=283, absmean=283, std=1.26987e-06
# │ Sⁿ:   min=35, max=35, mean=35, absmean=35, std=0
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-0.000498209, max=-0, mean=-0.000139304, absmean=0.000139304, std=0.000222231
# │ pⁿʰ⁺ˢ:min=-2.21612e-07, max=5.58039e-07, mean=1.02999e-24, absmean=3.11304e-07, std=3.45648e-07
# │ pⁿ:   min=-0.000497695, max=-7.31318e-08, mean=-0.000139304, absmean=0.000139304, std=0.000221886
# │ ρⁿ:   min=1027, max=1027, mean=1027, absmean=1027, std=1.34042e-07
# │ δρ:   min=0, max=2.54016e-06, mean=7.13824e-09, absmean=7.13824e-09, std=1.34042e-07
# │ Gᵘⁿ⁺ʰ: min=-3.88023e-08, max=3.88054e-08, mean=-2.11138e-27, absmean=5.04925e-10, std=4.20921e-09
# │ Gᵛⁿ⁺ʰ: min=-3.88059e-08, max=3.88032e-08, mean=-3.38813e-27, absmean=5.04533e-10, std=4.21125e-09
# │ Gʷⁿ⁺ʰ: min=0, max=0, mean=0, absmean=0, std=0
# │ Gᵀⁿ⁺ʰ: min=-9.25422e-06, max=0, mean=-2.60126e-08, absmean=2.60126e-08, std=4.88328e-07
# │ Gˢⁿ⁺ʰ: min=0, max=0, mean=0, absmean=0, std=0
# │ ∇⋅u1:  min=-5.7152e-24, max=5.29397e-24, mean=3.34077e-32, absmean=6.15724e-25, std=8.22943e-25
# │ ∇⋅u2:  min=-5.29396e-26, max=5.29396e-26, mean=-7.93939e-31, absmean=2.48691e-29, std=4.91257e-28
# │ wSurf: min=-5.44689e-21, max=5.81753e-21, mean=4.18634e-28, absmean=8.65336e-22, std=1.15298e-21
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:314
# ┌ Info: Temperature source term:
# │ div_flux:  mean=-1.17097e-28, absmean=2.40265e-18, std=8.44567e-17
# │ lap_diff:  mean=4.23516e-28, absmean=1.46713e-11, std=1.98555e-10
# │ Fᵀ[:,:,1]: mean=-2.60126e-06, absmean=2.60126e-06, std=4.14276e-06
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:216
# ┌ Info: Salinity source term:
# │ div_flux:  mean=3.59465e-29, absmean=2.15504e-23, std=2.8803e-23
# │ lap_diff:  mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:226
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-9.25135e-19, max=7.35371e-19, mean=-3.05723e-38, absmean=4.19444e-22, std=1.30613e-20
# │ Gwn_u_dot_w: min=-3.36648e-12, max=3.33834e-12, mean=-1.3546e-32, absmean=9.16268e-16, std=4.43844e-14
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:246
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-4.89611e-09, max=4.84544e-09, mean=2.12585e-28, absmean=1.23647e-10, std=6.61883e-10
# │ RHS_rec: min=-4.89611e-09, max=4.84544e-09, mean=1.11752e-27, absmean=1.23647e-10, std=6.61883e-10
# │ error:   min=-9.61597e-24, max=9.53843e-24, mean=1.302e-27, absmean=1.01721e-24, std=1.41772e-24
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:274
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-3.678e-12, max=6.99351e-12, mean=9.09899e-27, absmean=2.40395e-12, std=2.87552e-12
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:293
# ┌ Info: Time: 3
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -3.2963e-05 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-1.5745e-08, max=1.57478e-08, mean=-4.33527e-27, absmean=1.40639e-11, std=2.00121e-10
# │ vⁿ:   min=-1.57591e-08, max=1.57513e-08, mean=3.61809e-27, absmean=1.40646e-11, std=2.00141e-10
# │ wⁿ:   min=-1.37783e-08, max=1.40765e-08, mean=-4.60342e-26, absmean=2.18468e-11, std=2.37581e-10
# │ Tⁿ:   min=283, max=283, mean=283, absmean=283, std=1.75816e-06
# │ Sⁿ:   min=35, max=35, mean=35, absmean=35, std=0
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-0.000809588, max=-0, mean=-0.000226369, absmean=0.000226369, std=0.000361121
# │ pⁿʰ⁺ˢ:min=-2.76768e-07, max=6.97545e-07, mean=2.81893e-24, absmean=3.89123e-07, std=4.32053e-07
# │ pⁿ:   min=-0.000808929, max=-1.57737e-07, mean=-0.000226369, absmean=0.000226369, std=0.00036069
# │ ρⁿ:   min=1027, max=1027, mean=1027, absmean=1027, std=2.17794e-07
# │ δρ:   min=0, max=4.12734e-06, mean=1.15996e-08, absmean=1.15996e-08, std=2.17794e-07
# │ Gᵘⁿ⁺ʰ: min=-4.84842e-08, max=4.84943e-08, mean=-2.24936e-27, absmean=6.31025e-10, std=5.25937e-09
# │ Gᵛⁿ⁺ʰ: min=-4.84887e-08, max=4.84853e-08, mean=-1.69407e-27, absmean=6.30518e-10, std=5.26193e-09
# │ Gʷⁿ⁺ʰ: min=-5.38637e-12, max=5.34134e-12, mean=-5.99226e-32, absmean=1.46603e-15, std=7.1015e-14
# │ Gᵀⁿ⁺ʰ: min=-9.25361e-06, max=2.58784e-21, mean=-2.60126e-08, absmean=2.60126e-08, std=4.88294e-07
# │ Gˢⁿ⁺ʰ: min=-2.96462e-22, max=3.20051e-22, mean=5.75144e-29, absmean=3.44806e-23, std=4.60849e-23
# │ ∇⋅u1:  min=-9.8953e-24, max=1.19144e-23, mean=2.28015e-30, absmean=1.11603e-24, std=1.52924e-24
# │ ∇⋅u2:  min=-1.05879e-25, max=1.05879e-25, mean=7.12866e-31, absmean=6.83542e-29, std=1.16455e-27
# │ wSurf: min=-1.2043e-20, max=1.07816e-20, mean=-9.00489e-28, absmean=1.57395e-21, std=2.09438e-21
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:314
# ┌ Info: Temperature source term:
# │ div_flux:  mean=1.52218e-29, absmean=7.48256e-18, std=2.62994e-16
# │ lap_diff:  mean=1.96986e-27, absmean=2.03114e-11, std=2.7487e-10
# │ Fᵀ[:,:,1]: mean=-2.60126e-06, absmean=2.60126e-06, std=4.14276e-06
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:216
# ┌ Info: Salinity source term:
# │ div_flux:  mean=-4.47032e-29, absmean=3.90613e-23, std=5.35234e-23
# │ lap_diff:  mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:226
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-4.67944e-18, max=3.71898e-18, mean=3.95117e-38, absmean=2.12202e-21, std=6.60639e-20
# │ Gwn_u_dot_w: min=-7.56726e-12, max=7.50404e-12, mean=-7.01216e-32, absmean=2.06015e-15, std=9.97823e-14
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:246
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-6.42404e-09, max=6.3579e-09, mean=6.61744e-30, absmean=1.62251e-10, std=8.6849e-10
# │ RHS_rec: min=-6.42404e-09, max=6.3579e-09, mean=-3.24255e-28, absmean=1.62251e-10, std=8.6849e-10
# │ error:   min=-1.08309e-23, max=1.12973e-23, mean=1.17714e-28, absmean=1.26328e-24, std=1.66716e-24
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:274
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-6.36048e-12, max=1.20941e-11, mean=4.74802e-26, absmean=4.15722e-12, std=4.97272e-12
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:293
# ┌ Info: Time: 4
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -4.21171e-05 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-2.72217e-08, max=2.72265e-08, mean=7.87117e-27, absmean=2.43194e-11, std=3.45996e-10
# │ vⁿ:   min=-2.7246e-08, max=2.72325e-08, mean=3.57425e-27, absmean=2.43207e-11, std=3.46026e-10
# │ wⁿ:   min=-2.3814e-08, max=2.43293e-08, mean=1.44014e-26, absmean=3.77771e-11, std=4.107e-10
# │ Tⁿ:   min=283, max=283, mean=283, absmean=283, std=2.2464e-06
# │ Sⁿ:   min=35, max=35, mean=35, absmean=35, std=0
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-0.00112097, max=-0, mean=-0.000313434, absmean=0.000313434, std=0.00050001
# │ pⁿʰ⁺ˢ:min=-3.6312e-07, max=9.15525e-07, mean=1.19262e-24, absmean=5.10721e-07, std=5.67065e-07
# │ pⁿ:   min=-0.0011201, max=-2.16908e-07, mean=-0.000313434, absmean=0.000313434, std=0.000499444
# │ ρⁿ:   min=1027, max=1027, mean=1027, absmean=1027, std=3.01541e-07
# │ δρ:   min=0, max=5.71442e-06, mean=1.6061e-08, absmean=1.6061e-08, std=3.01541e-07
# │ Gᵘⁿ⁺ʰ: min=-6.3625e-08, max=6.36417e-08, mean=1.13205e-26, absmean=8.28146e-10, std=6.90172e-09
# │ Gᵛⁿ⁺ʰ: min=-6.36309e-08, max=6.36265e-08, mean=3.38813e-27, absmean=8.27472e-10, std=6.90507e-09
# │ Gʷⁿ⁺ʰ: min=-1.00877e-11, max=1.00035e-11, mean=-4.15033e-32, absmean=2.74648e-15, std=1.33021e-13
# │ Gᵀⁿ⁺ʰ: min=-9.25266e-06, max=4.10785e-21, mean=-2.60126e-08, absmean=2.60126e-08, std=4.88241e-07
# │ Gˢⁿ⁺ʰ: min=-5.98554e-22, max=5.08035e-22, mean=-9.3093e-29, absmean=5.61752e-23, std=7.73782e-23
# │ ∇⋅u1:  min=-1.33437e-23, max=1.6325e-23, mean=1.09214e-30, absmean=1.62619e-24, std=2.1815e-24
# │ ∇⋅u2:  min=-2.11758e-25, max=2.11758e-25, mean=-2.74361e-30, absmean=1.2067e-28, std=2.06677e-27
# │ wSurf: min=-1.86368e-20, max=1.24315e-20, mean=-7.47009e-27, absmean=2.28022e-21, std=3.03719e-21
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:314
# ┌ Info: Temperature source term:
# │ div_flux:  mean=4.37785e-28, absmean=1.65284e-17, std=5.80882e-16
# │ lap_diff:  mean=1.52059e-27, absmean=2.59501e-11, std=3.5116e-10
# │ Fᵀ[:,:,1]: mean=-2.60126e-06, absmean=2.60126e-06, std=4.14276e-06
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:216
# ┌ Info: Salinity source term:
# │ div_flux:  mean=-6.4016e-29, absmean=5.69165e-23, std=7.63522e-23
# │ lap_diff:  mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:226
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-1.39836e-17, max=1.11122e-17, mean=5.41954e-37, absmean=6.34209e-21, std=1.97416e-19
# │ Gwn_u_dot_w: min=-1.30767e-11, max=1.29675e-11, mean=-6.40324e-32, absmean=3.56067e-15, std=1.72446e-13
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:246
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-7.95085e-09, max=7.86943e-09, mean=-2.8455e-28, absmean=2.00836e-10, std=1.07497e-09
# │ RHS_rec: min=-7.95085e-09, max=7.86943e-09, mean=-6.6009e-28, absmean=2.00836e-10, std=1.07497e-09
# │ error:   min=-1.31525e-23, max=1.28342e-23, mean=-6.05231e-28, absmean=1.46643e-24, std=1.94346e-24
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:274
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-9.68202e-12, max=1.84098e-11, mean=-1.43599e-25, absmean=6.32819e-12, std=7.56955e-12
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:293
# ┌ Info: Time: 5
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -5.12702e-05 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-4.14282e-08, max=4.14356e-08, mean=-1.26649e-26, absmean=3.70172e-11, std=5.26572e-10
# │ vⁿ:   min=-4.14653e-08, max=4.14448e-08, mean=1.53483e-26, absmean=3.7019e-11, std=5.26615e-10
# │ wⁿ:   min=-3.62322e-08, max=3.70162e-08, mean=1.89138e-26, absmean=5.75004e-11, std=6.24965e-10
# │ Tⁿ:   min=283, max=283, mean=283, absmean=283, std=2.73459e-06
# │ Sⁿ:   min=35, max=35, mean=35, absmean=35, std=0
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-0.00143234, max=-0, mean=-0.000400499, absmean=0.000400499, std=0.000638897
# │ pⁿʰ⁺ˢ:min=-4.49398e-07, max=1.1335e-06, mean=3.25261e-25, absmean=6.32316e-07, std=7.02076e-07
# │ pⁿ:   min=-0.00143127, max=-2.68572e-07, mean=-0.000400499, absmean=0.000400499, std=0.000638196
# │ ρⁿ:   min=1027, max=1027, mean=1027, absmean=1027, std=3.85279e-07
# │ δρ:   min=0, max=7.30134e-06, mean=2.05224e-08, absmean=2.05224e-08, std=3.85279e-07
# │ Gᵘⁿ⁺ʰ: min=-7.87603e-08, max=7.87853e-08, mean=-1.94339e-26, absmean=1.02523e-09, std=8.54343e-09
# │ Gᵛⁿ⁺ʰ: min=-7.87675e-08, max=7.87621e-08, mean=2.4564e-26, absmean=1.02438e-09, std=8.54759e-09
# │ Gʷⁿ⁺ʰ: min=-1.63823e-11, max=1.62455e-11, mean=-1.45017e-33, absmean=4.46099e-15, std=2.16044e-13
# │ Gᵀⁿ⁺ʰ: min=-9.25171e-06, max=4.74773e-21, mean=-2.60126e-08, absmean=2.60126e-08, std=4.88188e-07
# │ Gˢⁿ⁺ʰ: min=-7.27254e-22, max=5.87182e-22, mean=-7.56038e-29, absmean=7.58755e-23, std=1.009e-22
# │ ∇⋅u1:  min=-1.81208e-23, max=2.16729e-23, mean=3.95288e-30, absmean=2.18002e-24, std=2.90459e-24
# │ ∇⋅u2:  min=-4.23516e-25, max=4.23516e-25, mean=3.72856e-30, absmean=1.80341e-28, std=3.01008e-27
# │ wSurf: min=-2.57159e-20, max=1.88486e-20, mean=1.31855e-27, absmean=3.217e-21, std=4.25967e-21
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:314
# ┌ Info: Temperature source term:
# │ div_flux:  mean=4.34717e-28, absmean=3.06196e-17, std=1.07602e-15
# │ lap_diff:  mean=2.55059e-27, absmean=3.15876e-11, std=4.27427e-10
# │ Fᵀ[:,:,1]: mean=-2.60126e-06, absmean=2.60126e-06, std=4.14276e-06
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:216
# ┌ Info: Salinity source term:
# │ div_flux:  mean=5.29916e-29, absmean=7.63007e-23, std=1.01661e-22
# │ lap_diff:  mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:226
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-3.238e-17, max=2.57287e-17, mean=-1.4513e-36, absmean=1.46873e-20, std=4.57125e-19
# │ Gwn_u_dot_w: min=-1.98926e-11, max=1.97265e-11, mean=-1.5131e-31, absmean=5.41742e-15, std=2.6235e-13
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:246
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-9.47674e-09, max=9.38021e-09, mean=-1.57164e-28, absmean=2.39406e-10, std=1.28136e-09
# │ RHS_rec: min=-9.47674e-09, max=9.38021e-09, mean=1.78671e-27, absmean=2.39406e-10, std=1.28136e-09
# │ error:   min=-2.01173e-23, max=2.01625e-23, mean=1.90941e-27, absmean=1.99229e-24, std=2.79203e-24
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:274
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-1.36428e-11, max=2.59409e-11, mean=-2.05472e-25, absmean=8.91693e-12, std=1.06661e-11
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:293
# ┌ Info: Time: 6
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -6.04225e-05 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-5.83639e-08, max=5.83742e-08, mean=-1.17655e-26, absmean=5.21574e-11, std=7.41841e-10
# │ vⁿ:   min=-5.84161e-08, max=5.83871e-08, mean=1.31331e-26, absmean=5.21598e-11, std=7.41895e-10
# │ wⁿ:   min=-5.10306e-08, max=5.21346e-08, mean=4.09262e-26, absmean=8.1017e-11, std=8.80349e-10
# │ Tⁿ:   min=283, max=283, mean=283, absmean=283, std=3.22273e-06
# │ Sⁿ:   min=35, max=35, mean=35, absmean=35, std=0
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-0.00174372, max=-0, mean=-0.000487564, absmean=0.000487564, std=0.000777783
# │ pⁿʰ⁺ˢ:min=-5.35617e-07, max=1.35148e-06, mean=-1.25767e-23, absmean=7.5391e-07, std=8.37085e-07
# │ pⁿ:   min=-0.00174244, max=-3.20275e-07, mean=-0.000487564, absmean=0.000487564, std=0.000776947
# │ ρⁿ:   min=1027, max=1027, mean=1027, absmean=1027, std=4.69007e-07
# │ δρ:   min=0, max=8.88809e-06, mean=2.49838e-08, absmean=2.49838e-08, std=4.69007e-07
# │ Gᵘⁿ⁺ʰ: min=-9.38911e-08, max=9.3926e-08, mean=5.85944e-28, absmean=1.22228e-09, std=1.01846e-08
# │ Gᵛⁿ⁺ʰ: min=-9.38996e-08, max=9.38931e-08, mean=1.18585e-26, absmean=1.22126e-09, std=1.01896e-08
# │ Gʷⁿ⁺ʰ: min=-2.39821e-11, max=2.37819e-11, mean=-2.27426e-31, absmean=6.53146e-15, std=3.16293e-13
# │ Gᵀⁿ⁺ʰ: min=-9.25076e-06, max=6.41742e-21, mean=-2.60126e-08, absmean=2.60126e-08, std=4.88135e-07
# │ Gˢⁿ⁺ʰ: min=-8.79135e-22, max=7.93674e-22, mean=1.23196e-28, absmean=9.71056e-23, std=1.28869e-22
# │ ∇⋅u1:  min=-2.65508e-23, max=3.21038e-23, mean=-9.79416e-31, absmean=2.90653e-24, std=3.94375e-24
# │ ∇⋅u2:  min=-4.23516e-25, max=4.23516e-25, mean=4.11012e-30, absmean=2.55412e-28, std=4.24876e-27
# │ wSurf: min=-2.98029e-20, max=3.21915e-20, mean=6.60519e-27, absmean=4.30288e-21, std=5.73713e-21
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:314
# ┌ Info: Temperature source term:
# │ div_flux:  mean=7.30309e-28, absmean=5.08349e-17, std=1.78627e-15
# │ lap_diff:  mean=3.85705e-27, absmean=3.72238e-11, std=5.0367e-10
# │ Fᵀ[:,:,1]: mean=-2.60126e-06, absmean=2.60126e-06, std=4.14276e-06
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:216
# ┌ Info: Salinity source term:
# │ div_flux:  mean=1.11846e-28, absmean=1.01729e-22, std=1.38032e-22
# │ lap_diff:  mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:226
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-6.42502e-17, max=5.10477e-17, mean=1.53576e-36, absmean=2.91466e-20, std=9.07041e-19
# │ Gwn_u_dot_w: min=-2.80132e-11, max=2.77794e-11, mean=-2.41144e-31, absmean=7.63002e-15, std=3.69475e-13
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:246
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-1.10017e-08, max=1.08902e-08, mean=4.96308e-29, absmean=2.77962e-10, std=1.48764e-09
# │ RHS_rec: min=-1.10017e-08, max=1.08902e-08, mean=-6.40238e-28, absmean=2.77962e-10, std=1.48764e-09
# │ error:   min=-2.10285e-23, max=2.01658e-23, mean=6.76688e-29, absmean=2.3036e-24, std=3.10921e-24
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:274
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-1.82428e-11, max=3.46876e-11, mean=-3.94731e-25, absmean=1.19235e-11, std=1.42625e-11
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:293
# ┌ Info: Time: 7
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -6.95738e-05 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-7.80277e-08, max=7.80414e-08, mean=1.51386e-27, absmean=6.97401e-11, std=9.91792e-10
# │ vⁿ:   min=-7.80975e-08, max=7.80587e-08, mean=4.24178e-27, absmean=6.9743e-11, std=9.91857e-10
# │ wⁿ:   min=-6.82068e-08, max=6.96822e-08, mean=-1.20038e-26, absmean=1.08327e-10, std=1.17683e-09
# │ Tⁿ:   min=283, max=283, mean=283, absmean=283, std=3.71081e-06
# │ Sⁿ:   min=35, max=35, mean=35, absmean=35, std=0
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-0.00205509, max=-0, mean=-0.000574629, absmean=0.000574629, std=0.000916667
# │ pⁿʰ⁺ˢ:min=-6.21775e-07, max=1.56946e-06, mean=-4.11997e-24, absmean=8.75503e-07, std=9.72092e-07
# │ pⁿ:   min=-0.00205361, max=-3.71993e-07, mean=-0.000574629, absmean=0.000574629, std=0.000915696
# │ ρⁿ:   min=1027, max=1027, mean=1027, absmean=1027, std=5.52727e-07
# │ δρ:   min=0, max=1.04747e-05, mean=2.94452e-08, absmean=2.94452e-08, std=5.52727e-07
# │ Gᵘⁿ⁺ʰ: min=-1.09017e-07, max=1.09064e-07, mean=1.50211e-26, absmean=1.4193e-09, std=1.18253e-08
# │ Gᵛⁿ⁺ʰ: min=-1.09027e-07, max=1.0902e-07, mean=-1.60936e-26, absmean=1.4181e-09, std=1.18311e-08
# │ Gʷⁿ⁺ʰ: min=-3.28855e-11, max=3.26111e-11, mean=-8.11624e-33, absmean=8.95758e-15, std=4.3375e-13
# │ Gᵀⁿ⁺ʰ: min=-9.24982e-06, max=9.67271e-21, mean=-2.60126e-08, absmean=2.60126e-08, std=4.88082e-07
# │ Gˢⁿ⁺ʰ: min=-1.34268e-21, max=1.19627e-21, mean=1.47158e-28, absmean=1.29891e-22, std=1.77868e-22
# │ ∇⋅u1:  min=-3.52752e-23, max=4.28937e-23, mean=8.37442e-30, absmean=3.65626e-24, std=4.93425e-24
# │ ∇⋅u2:  min=-8.47033e-25, max=8.47033e-25, mean=1.52819e-30, absmean=3.49268e-28, std=6.30436e-27
# │ wSurf: min=-3.98698e-20, max=4.23305e-20, mean=-6.46545e-28, absmean=5.26754e-21, std=7.08475e-21
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:314
# ┌ Info: Temperature source term:
# │ div_flux:  mean=-9.08866e-28, absmean=7.82522e-17, std=2.74945e-15
# │ lap_diff:  mean=-1.06387e-27, absmean=4.28587e-11, std=5.7989e-10
# │ Fᵀ[:,:,1]: mean=-2.60126e-06, absmean=2.60126e-06, std=4.14276e-06
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:216
# ┌ Info: Salinity source term:
# │ div_flux:  mean=2.28377e-28, absmean=1.27969e-22, std=1.72699e-22
# │ lap_diff:  mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:226
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-1.14813e-16, max=9.12123e-17, mean=-9.79204e-36, absmean=5.20894e-20, std=1.62083e-18
# │ Gwn_u_dot_w: min=-3.74367e-11, max=3.71244e-11, mean=-6.72607e-32, absmean=1.01981e-14, std=4.93801e-13
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:246
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-1.25258e-08, max=1.23995e-08, mean=-1.22423e-28, absmean=3.16502e-10, std=1.69382e-09
# │ RHS_rec: min=-1.25258e-08, max=1.23995e-08, mean=-1.86612e-27, absmean=3.16502e-10, std=1.69382e-09
# │ error:   min=-1.9904e-23, max=2.09639e-23, mean=-1.23784e-27, absmean=2.49044e-24, std=3.28441e-24
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:274
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-2.34823e-11, max=4.46503e-11, mean=-4.29141e-25, absmean=1.53481e-11, std=1.83588e-11
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:293
# ┌ Info: Time: 8
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -7.87243e-05 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-1.00419e-07, max=1.00437e-07, mean=1.43983e-26, absmean=8.97655e-11, std=1.27641e-09
# │ vⁿ:   min=-1.00509e-07, max=1.00459e-07, mean=2.50603e-26, absmean=8.9769e-11, std=1.27649e-09
# │ wⁿ:   min=-8.77584e-08, max=8.96566e-08, mean=-5.01718e-26, absmean=1.3943e-10, std=1.51438e-09
# │ Tⁿ:   min=283, max=283, mean=283, absmean=283, std=4.19884e-06
# │ Sⁿ:   min=35, max=35, mean=35, absmean=35, std=0
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-0.00236647, max=-0, mean=-0.000661693, absmean=0.000661693, std=0.00105555
# │ pⁿʰ⁺ˢ:min=-7.07873e-07, max=1.78744e-06, mean=-9.1073e-24, absmean=9.97094e-07, std=1.1071e-06
# │ pⁿ:   min=-0.00236478, max=-4.2375e-07, mean=-0.000661693, absmean=0.000661693, std=0.00105444
# │ ρⁿ:   min=1027, max=1027, mean=1027, absmean=1027, std=6.36437e-07
# │ δρ:   min=0, max=1.20611e-05, mean=3.39066e-08, absmean=3.39066e-08, std=6.36437e-07
# │ Gᵘⁿ⁺ʰ: min=-1.24139e-07, max=1.24198e-07, mean=1.5092e-26, absmean=1.6163e-09, std=1.34655e-08
# │ Gᵛⁿ⁺ʰ: min=-1.2415e-07, max=1.24142e-07, mean=1.86347e-26, absmean=1.61491e-09, std=1.3472e-08
# │ Gʷⁿ⁺ʰ: min=-4.30907e-11, max=4.27313e-11, mean=1.59053e-32, absmean=1.1739e-14, std=5.68397e-13
# │ Gᵀⁿ⁺ʰ: min=-9.24889e-06, max=1.14643e-20, mean=-2.60126e-08, absmean=2.60126e-08, std=4.88029e-07
# │ Gˢⁿ⁺ʰ: min=-1.79243e-21, max=1.41785e-21, mean=2.98296e-28, absmean=1.5889e-22, std=2.13322e-22
# │ ∇⋅u1:  min=-4.2763e-23, max=5.05696e-23, mean=1.64296e-30, absmean=4.36311e-24, std=5.85589e-24
# │ ∇⋅u2:  min=-8.47033e-25, max=8.47033e-25, mean=1.36016e-29, absmean=4.37458e-28, std=7.25388e-27
# │ wSurf: min=-4.56551e-20, max=5.28464e-20, mean=1.37057e-26, absmean=6.24523e-21, std=8.40561e-21
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:314
# ┌ Info: Temperature source term:
# │ div_flux:  mean=-2.68334e-27, absmean=1.13948e-16, std=4.00334e-15
# │ lap_diff:  mean=-4.60244e-27, absmean=4.84924e-11, std=6.56085e-10
# │ Fᵀ[:,:,1]: mean=-2.60126e-06, absmean=2.60126e-06, std=4.14276e-06
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:216
# ┌ Info: Salinity source term:
# │ div_flux:  mean=9.98131e-29, absmean=1.5271e-22, std=2.04957e-22
# │ lap_diff:  mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:226
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-1.90121e-16, max=1.51028e-16, mean=-1.91146e-36, absmean=8.62652e-20, std=2.68394e-18
# │ Gwn_u_dot_w: min=-4.81613e-11, max=4.77597e-11, mean=-9.03116e-32, absmean=1.31214e-14, std=6.35308e-13
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:246
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-1.40489e-08, max=1.3908e-08, mean=4.30134e-28, absmean=3.55027e-10, std=1.89991e-09
# │ RHS_rec: min=-1.40489e-08, max=1.3908e-08, mean=-1.86943e-28, absmean=3.55027e-10, std=1.89991e-09
# │ error:   min=-2.54617e-23, max=2.29543e-23, mean=3.84017e-28, absmean=2.72796e-24, std=3.63409e-24
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:274
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-2.93614e-11, max=5.5829e-11, mean=-6.84244e-25, absmean=1.91907e-11, std=2.29552e-11
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:293
# ┌ Info: Time: 9
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -8.78738e-05 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-1.25536e-07, max=1.25558e-07, mean=4.2582e-26, absmean=1.12234e-10, std=1.5957e-09
# │ vⁿ:   min=-1.25649e-07, max=1.25586e-07, mean=5.13183e-27, absmean=1.12238e-10, std=1.59578e-09
# │ wⁿ:   min=-1.09683e-07, max=1.12055e-07, mean=-1.74747e-25, absmean=1.74326e-10, std=1.89298e-09
# │ Tⁿ:   min=283, max=283, mean=283, absmean=283, std=4.68681e-06
# │ Sⁿ:   min=35, max=35, mean=35, absmean=35, std=0
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-0.00267784, max=-0, mean=-0.000748758, absmean=0.000748758, std=0.00119443
# │ pⁿʰ⁺ˢ:min=-7.93912e-07, max=2.00541e-06, mean=-8.23994e-24, absmean=1.11868e-06, std=1.2421e-06
# │ pⁿ:   min=-0.00267595, max=-4.75544e-07, mean=-0.000748758, absmean=0.000748758, std=0.00119319
# │ ρⁿ:   min=1027, max=1027, mean=1027, absmean=1027, std=7.20138e-07
# │ δρ:   min=0, max=1.36474e-05, mean=3.8368e-08, absmean=3.8368e-08, std=7.20138e-07
# │ Gᵘⁿ⁺ʰ: min=-1.39256e-07, max=1.39329e-07, mean=2.21506e-26, absmean=1.81326e-09, std=1.51051e-08
# │ Gᵛⁿ⁺ʰ: min=-1.39269e-07, max=1.39259e-07, mean=-1.52466e-26, absmean=1.81169e-09, std=1.51124e-08
# │ Gʷⁿ⁺ʰ: min=-5.45961e-11, max=5.41409e-11, mean=-2.27734e-31, absmean=1.48754e-14, std=7.20213e-13
# │ Gᵀⁿ⁺ʰ: min=-9.24795e-06, max=1.40421e-20, mean=-2.60126e-08, absmean=2.60126e-08, std=4.87976e-07
# │ Gˢⁿ⁺ʰ: min=-1.93113e-21, max=1.73668e-21, mean=2.26746e-29, absmean=1.82379e-22, std=2.43368e-22
# │ ∇⋅u1:  min=-4.7137e-23, max=5.28471e-23, mean=5.4061e-30, absmean=5.13885e-24, std=6.88944e-24
# │ ∇⋅u2:  min=-8.47033e-25, max=8.47033e-25, mean=-2.94546e-30, absmean=5.43008e-28, std=9.00101e-27
# │ wSurf: min=-5.6802e-20, max=6.82285e-20, mean=-1.61965e-26, absmean=7.45778e-21, std=1.00499e-20
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:314
# ┌ Info: Temperature source term:
# │ div_flux:  mean=-1.28572e-27, absmean=1.59e-16, std=5.58567e-15
# │ lap_diff:  mean=-1.91904e-27, absmean=5.41248e-11, std=7.32257e-10
# │ Fᵀ[:,:,1]: mean=-2.60126e-06, absmean=2.60126e-06, std=4.14276e-06
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:216
# ┌ Info: Salinity source term:
# │ div_flux:  mean=2.10594e-29, absmean=1.7986e-22, std=2.41131e-22
# │ lap_diff:  mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:226
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-2.97064e-16, max=2.35961e-16, mean=-6.95877e-36, absmean=1.34803e-19, std=4.1936e-18
# │ Gwn_u_dot_w: min=-6.01853e-11, max=5.96836e-11, mean=-2.61376e-31, absmean=1.63995e-14, std=7.93976e-13
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:246
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-1.55712e-08, max=1.54157e-08, mean=1.2507e-27, absmean=3.93536e-10, std=2.10589e-09
# │ RHS_rec: min=-1.55712e-08, max=1.54157e-08, mean=7.17993e-28, absmean=3.93536e-10, std=2.10589e-09
# │ error:   min=-2.52807e-23, max=2.82146e-23, mean=1.25699e-27, absmean=2.99104e-24, std=3.94637e-24
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:274
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-3.58802e-11, max=6.82241e-11, mean=-3.9837e-25, absmean=2.34514e-11, std=2.80517e-11
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:293
# ┌ Info: Time: 10
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -9.70225e-05 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-1.5338e-07, max=1.53407e-07, mean=2.06633e-26, absmean=1.37145e-10, std=1.94964e-09
# │ vⁿ:   min=-1.53517e-07, max=1.5344e-07, mean=-6.89041e-27, absmean=1.37149e-10, std=1.94972e-09
# │ wⁿ:   min=-1.33979e-07, max=1.36876e-07, mean=-9.44063e-26, absmean=2.13016e-10, std=2.31259e-09
# │ Tⁿ:   min=283, max=283, mean=283, absmean=283, std=5.17474e-06
# │ Sⁿ:   min=35, max=35, mean=35, absmean=35, std=0
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-0.00298921, max=-0, mean=-0.000835822, absmean=0.000835822, std=0.00133331
# │ pⁿʰ⁺ˢ:min=-8.7989e-07, max=2.22339e-06, mean=5.63785e-24, absmean=1.24027e-06, std=1.3771e-06
# │ pⁿ:   min=-0.00298711, max=-5.27377e-07, mean=-0.000835822, absmean=0.000835822, std=0.00133193
# │ ρⁿ:   min=1027, max=1027, mean=1027, absmean=1027, std=8.03831e-07
# │ δρ:   min=0, max=1.52335e-05, mean=4.28294e-08, absmean=4.28294e-08, std=8.03831e-07
# │ Gᵘⁿ⁺ʰ: min=-1.54369e-07, max=1.54458e-07, mean=-1.91092e-26, absmean=2.0102e-09, std=1.67442e-08
# │ Gᵛⁿ⁺ʰ: min=-1.54383e-07, max=1.54372e-07, mean=-1.86347e-26, absmean=2.00844e-09, std=1.67524e-08
# │ Gʷⁿ⁺ʰ: min=-6.73997e-11, max=6.6838e-11, mean=4.25362e-31, absmean=1.83663e-14, std=8.89177e-13
# │ Gᵀⁿ⁺ʰ: min=-9.24702e-06, max=1.52119e-20, mean=-2.60126e-08, absmean=2.60126e-08, std=4.87923e-07
# │ Gˢⁿ⁺ʰ: min=-2.11819e-21, max=1.9082e-21, mean=-2.61927e-29, absmean=2.11147e-22, std=2.82439e-22
# │ ∇⋅u1:  min=-5.94067e-23, max=6.59495e-23, mean=1.31174e-30, absmean=6.08504e-24, std=8.10011e-24
# │ ∇⋅u2:  min=-1.69407e-24, max=1.69407e-24, mean=-1.2838e-29, absmean=6.6431e-28, std=1.09145e-26
# │ wSurf: min=-7.20486e-20, max=7.9926e-20, mean=-1.07734e-26, absmean=9.22843e-21, std=1.22777e-20
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:314
# ┌ Info: Temperature source term:
# │ div_flux:  mean=1.85984e-27, absmean=2.14482e-16, std=7.53416e-15
# │ lap_diff:  mean=8.0773e-28, absmean=5.9756e-11, std=8.08404e-10
# │ Fᵀ[:,:,1]: mean=-2.60126e-06, absmean=2.60126e-06, std=4.14276e-06
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:216
# ┌ Info: Salinity source term:
# │ div_flux:  mean=3.53469e-28, absmean=2.12977e-22, std=2.83505e-22
# │ lap_diff:  mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:226
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-4.4336e-16, max=3.52137e-16, mean=-1.39962e-36, absmean=2.0121e-19, std=6.25876e-18
# │ Gwn_u_dot_w: min=-7.35069e-11, max=7.28944e-11, mean=2.57554e-31, absmean=2.0032e-14, std=9.69785e-13
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:246
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-1.70925e-08, max=1.69227e-08, mean=-7.5108e-28, absmean=4.32031e-10, std=2.31177e-09
# │ RHS_rec: min=-1.70925e-08, max=1.69227e-08, mean=3.59327e-27, absmean=4.32031e-10, std=2.31177e-09
# │ error:   min=-2.97785e-23, max=2.6948e-23, mean=4.32322e-27, absmean=3.2283e-24, std=4.29734e-24
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:274
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-4.30388e-11, max=8.18358e-11, mean=-8.42401e-25, absmean=2.81302e-11, std=3.36484e-11
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:293
# ┌ Info: Time: 11
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -0.00010617 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-1.83947e-07, max=1.8398e-07, mean=8.94975e-27, absmean=1.64499e-10, std=2.33822e-09
# │ vⁿ:   min=-1.84112e-07, max=1.8402e-07, mean=3.75954e-26, absmean=1.64504e-10, std=2.33831e-09
# │ wⁿ:   min=-1.60643e-07, max=1.64117e-07, mean=-3.3716e-25, absmean=2.555e-10, std=2.77321e-09
# │ Tⁿ:   min=283, max=283, mean=283, absmean=283, std=5.66261e-06
# │ Sⁿ:   min=35, max=35, mean=35, absmean=35, std=0
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-0.00330059, max=-0, mean=-0.000922886, absmean=0.000922886, std=0.00147218
# │ pⁿʰ⁺ˢ:min=-9.65808e-07, max=2.44136e-06, mean=-6.93889e-24, absmean=1.36186e-06, std=1.5121e-06
# │ pⁿ:   min=-0.00329828, max=-5.79292e-07, mean=-0.000922886, absmean=0.000922886, std=0.00147067
# │ ρⁿ:   min=1027, max=1027, mean=1027, absmean=1027, std=8.87514e-07
# │ δρ:   min=0, max=1.68194e-05, mean=4.72908e-08, absmean=4.72908e-08, std=8.87514e-07
# │ Gᵘⁿ⁺ʰ: min=-1.69477e-07, max=1.69583e-07, mean=-1.15384e-26, absmean=2.2071e-09, std=1.83828e-08
# │ Gᵛⁿ⁺ʰ: min=-1.69492e-07, max=1.6948e-07, mean=8.97855e-26, absmean=2.20516e-09, std=1.83917e-08
# │ Gʷⁿ⁺ʰ: min=-8.14999e-11, max=8.08208e-11, mean=1.64369e-31, absmean=2.22115e-14, std=1.07527e-12
# │ Gᵀⁿ⁺ʰ: min=-9.24609e-06, max=1.88955e-20, mean=-2.60126e-08, absmean=2.60126e-08, std=4.8787e-07
# │ Gˢⁿ⁺ʰ: min=-2.59734e-21, max=2.3369e-21, mean=5.52914e-28, absmean=2.48688e-22, std=3.29407e-22
# │ ∇⋅u1:  min=-7.06579e-23, max=6.37508e-23, mean=-1.08948e-29, absmean=6.90582e-24, std=9.23155e-24
# │ ∇⋅u2:  min=-1.69407e-24, max=1.69407e-24, mean=6.7137e-30, absmean=7.96635e-28, std=1.31076e-26
# │ wSurf: min=-7.51149e-20, max=9.97974e-20, mean=3.12137e-26, absmean=1.06555e-20, std=1.43297e-20
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:314
# ┌ Info: Temperature source term:
# │ div_flux:  mean=-6.38009e-27, absmean=2.81469e-16, std=9.88644e-15
# │ lap_diff:  mean=-3.02492e-27, absmean=6.53859e-11, std=8.84529e-10
# │ Fᵀ[:,:,1]: mean=-2.60126e-06, absmean=2.60126e-06, std=4.14276e-06
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:216
# ┌ Info: Salinity source term:
# │ div_flux:  mean=2.84011e-28, absmean=2.41704e-22, std=3.23105e-22
# │ lap_diff:  mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:226
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-6.3756e-16, max=5.06338e-16, mean=-1.08322e-35, absmean=2.89372e-19, std=9.00011e-18
# │ Gwn_u_dot_w: min=-8.81244e-11, max=8.73903e-11, mean=-1.33349e-31, absmean=2.40186e-14, std=1.16272e-12
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:246
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-1.86129e-08, max=1.8429e-08, mean=-3.44107e-28, absmean=4.7051e-10, std=2.51755e-09
# │ RHS_rec: min=-1.86129e-08, max=1.8429e-08, mean=-3.02748e-27, absmean=4.7051e-10, std=2.51755e-09
# │ error:   min=-4.07386e-23, max=3.90584e-23, mean=-2.06409e-27, absmean=3.96239e-24, std=5.54266e-24
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:274
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-5.08373e-11, max=9.66643e-11, mean=-9.74088e-25, absmean=3.32274e-11, std=3.97455e-11
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:293
# ┌ Info: Time: 12
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -0.000115317 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-2.17239e-07, max=2.17277e-07, mean=8.94816e-28, absmean=1.94297e-10, std=2.76143e-09
# │ vⁿ:   min=-2.17433e-07, max=2.17324e-07, mean=1.52069e-26, absmean=1.94302e-10, std=2.76151e-09
# │ wⁿ:   min=-1.89674e-07, max=1.93774e-07, mean=-4.99199e-25, absmean=3.01776e-10, std=3.2748e-09
# │ Tⁿ:   min=283, max=283, mean=283, absmean=283, std=6.15042e-06
# │ Sⁿ:   min=35, max=35, mean=35, absmean=35, std=0
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-0.00361196, max=-0, mean=-0.00100995, absmean=0.00100995, std=0.00161106
# │ pⁿʰ⁺ˢ:min=-1.05167e-06, max=2.65934e-06, mean=1.30104e-24, absmean=1.48344e-06, std=1.6471e-06
# │ pⁿ:   min=-0.00360944, max=-6.31246e-07, mean=-0.00100995, absmean=0.00100995, std=0.00160941
# │ ρⁿ:   min=1027, max=1027, mean=1027, absmean=1027, std=9.71188e-07
# │ δρ:   min=0, max=1.84052e-05, mean=5.17522e-08, absmean=5.17522e-08, std=9.71188e-07
# │ Gᵘⁿ⁺ʰ: min=-1.8458e-07, max=1.84705e-07, mean=-8.44344e-27, absmean=2.40398e-09, std=2.00209e-08
# │ Gᵛⁿ⁺ʰ: min=-1.84597e-07, max=1.84584e-07, mean=-1.18585e-26, absmean=2.40184e-09, std=2.00306e-08
# │ Gʷⁿ⁺ʰ: min=-9.68948e-11, max=9.60878e-11, mean=-1.16827e-31, absmean=2.64106e-14, std=1.27847e-12
# │ Gᵀⁿ⁺ʰ: min=-9.24515e-06, max=2.19067e-20, mean=-2.60126e-08, absmean=2.60126e-08, std=4.87817e-07
# │ Gˢⁿ⁺ʰ: min=-2.4955e-21, max=2.7093e-21, mean=2.42336e-28, absmean=2.76642e-22, std=3.69977e-22
# │ ∇⋅u1:  min=-7.28439e-23, max=8.07576e-23, mean=2.98135e-29, absmean=8.06718e-24, std=1.08763e-23
# │ ∇⋅u2:  min=-1.69407e-24, max=1.69407e-24, mean=1.56339e-29, absmean=9.47705e-28, std=1.632e-26
# │ wSurf: min=-9.49016e-20, max=1.02305e-19, mean=-1.88261e-26, absmean=1.24101e-20, std=1.67765e-20
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:314
# ┌ Info: Temperature source term:
# │ div_flux:  mean=-6.27394e-28, absmean=3.61035e-16, std=1.26801e-14
# │ lap_diff:  mean=3.13334e-27, absmean=7.10145e-11, std=9.60629e-10
# │ Fᵀ[:,:,1]: mean=-2.60126e-06, absmean=2.60126e-06, std=4.14276e-06
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:216
# ┌ Info: Salinity source term:
# │ div_flux:  mean=5.51239e-28, absmean=2.82353e-22, std=3.80672e-22
# │ lap_diff:  mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:226
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-8.89042e-16, max=7.06004e-16, mean=7.42773e-36, absmean=4.03553e-19, std=1.255e-17
# │ Gwn_u_dot_w: min=-1.04036e-10, max=1.0317e-10, mean=7.65537e-31, absmean=2.8359e-14, std=1.37275e-12
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:246
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-2.01324e-08, max=1.99345e-08, mean=8.17254e-28, absmean=5.08975e-10, std=2.72323e-09
# │ RHS_rec: min=-2.01324e-08, max=1.99345e-08, mean=-3.30872e-30, absmean=5.08975e-10, std=2.72323e-09
# │ error:   min=-4.46678e-23, max=4.15077e-23, mean=2.57014e-28, absmean=4.14165e-24, std=5.7624e-24
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:274
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-5.9276e-11, max=1.1271e-10, mean=-1.37246e-24, absmean=3.87429e-11, std=4.63429e-11
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:293
# ┌ Info: Time: 13
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -0.000124463 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-2.53254e-07, max=2.53298e-07, mean=2.26211e-26, absmean=2.26538e-10, std=3.21926e-09
# │ vⁿ:   min=-2.5348e-07, max=2.53353e-07, mean=-4.56604e-27, absmean=2.26543e-10, std=3.21934e-09
# │ wⁿ:   min=-2.21068e-07, max=2.25847e-07, mean=-4.81775e-25, absmean=3.51847e-10, std=3.81733e-09
# │ Tⁿ:   min=283, max=283, mean=283, absmean=283, std=6.63819e-06
# │ Sⁿ:   min=35, max=35, mean=35, absmean=35, std=0
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-0.00392333, max=-0, mean=-0.00109701, absmean=0.00109701, std=0.00174993
# │ pⁿʰ⁺ˢ:min=-1.13747e-06, max=2.87731e-06, mean=-1.04083e-23, absmean=1.60502e-06, std=1.7821e-06
# │ pⁿ:   min=-0.00392061, max=-6.83259e-07, mean=-0.00109701, absmean=0.00109701, std=0.00174815
# │ ρⁿ:   min=1027, max=1027, mean=1027, absmean=1027, std=1.05485e-06
# │ δρ:   min=0, max=1.99908e-05, mean=5.62136e-08, absmean=5.62136e-08, std=1.05485e-06
# │ Gᵘⁿ⁺ʰ: min=-1.99679e-07, max=1.99825e-07, mean=2.97102e-26, absmean=2.60083e-09, std=2.16585e-08
# │ Gᵛⁿ⁺ʰ: min=-1.99697e-07, max=1.99683e-07, mean=-5.0822e-27, absmean=2.5985e-09, std=2.1669e-08
# │ Gʷⁿ⁺ʰ: min=-1.13583e-10, max=1.12637e-10, mean=-1.93102e-31, absmean=3.09632e-14, std=1.49876e-12
# │ Gᵀⁿ⁺ʰ: min=-9.24422e-06, max=2.4389e-20, mean=-2.60126e-08, absmean=2.60126e-08, std=4.87764e-07
# │ Gˢⁿ⁺ʰ: min=-3.18347e-21, max=3.01632e-21, mean=7.11576e-28, absmean=3.28285e-22, std=4.45013e-22
# │ ∇⋅u1:  min=-7.7993e-23, max=8.32847e-23, mean=1.65359e-29, absmean=9.0983e-24, std=1.23656e-23
# │ ∇⋅u2:  min=-1.69407e-24, max=1.69407e-24, mean=-2.39475e-29, absmean=1.11435e-27, std=1.8823e-26
# │ wSurf: min=-1.02305e-19, max=1.16535e-19, mean=-5.89947e-26, absmean=1.40423e-20, std=1.90983e-20
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:314
# ┌ Info: Temperature source term:
# │ div_flux:  mean=3.96344e-27, absmean=4.54253e-16, std=1.59528e-14
# │ lap_diff:  mean=1.98138e-27, absmean=7.66419e-11, std=1.03671e-09
# │ Fᵀ[:,:,1]: mean=-2.60126e-06, absmean=2.60126e-06, std=4.14276e-06
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:216
# ┌ Info: Salinity source term:
# │ div_flux:  mean=1.05413e-27, absmean=3.18442e-22, std=4.32797e-22
# │ lap_diff:  mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:226
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-1.20801e-15, max=9.59227e-16, mean=-3.37949e-35, absmean=5.48394e-19, std=1.70525e-17
# │ Gwn_u_dot_w: min=-1.2124e-10, max=1.2023e-10, mean=5.37576e-31, absmean=3.30527e-14, std=1.59986e-12
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:246
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-2.1651e-08, max=2.14392e-08, mean=1.89259e-27, absmean=5.47425e-10, std=2.92882e-09
# │ RHS_rec: min=-2.1651e-08, max=2.14392e-08, mean=-3.33188e-27, absmean=5.47425e-10, std=2.92882e-09
# │ error:   min=-4.17726e-23, max=4.07903e-23, mean=-2.61716e-27, absmean=4.11499e-24, std=5.7803e-24
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:274
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# ...
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-0.00485744, max=-0, mean=-0.00135821, absmean=0.00135821, std=0.00216654
# │ pⁿʰ⁺ˢ:min=-1.39451e-06, max=3.53122e-06, mean=3.33934e-23, absmean=1.96976e-06, std=2.18708e-06
# │ pⁿ:   min=-0.00485409, max=-8.39818e-07, mean=-0.00135821, absmean=0.00135821, std=0.00216436
# │ ρⁿ:   min=1027, max=1027, mean=1027, absmean=1027, std=1.30579e-06
# │ δρ:   min=0, max=2.47467e-05, mean=6.95978e-08, absmean=6.95978e-08, std=1.30579e-06
# │ Gᵘⁿ⁺ʰ: min=-2.44949e-07, max=2.45164e-07, mean=5.09957e-26, absmean=3.19121e-09, std=2.6568e-08
# │ Gᵛⁿ⁺ʰ: min=-2.45002e-07, max=2.44953e-07, mean=5.92923e-26, absmean=3.1883e-09, std=2.65809e-08
# │ Gʷⁿ⁺ʰ: min=-1.71387e-10, max=1.69961e-10, mean=-1.78985e-30, absmean=4.67388e-14, std=2.26197e-12
# │ Gᵀⁿ⁺ʰ: min=-9.24142e-06, max=3.36672e-20, mean=-2.60126e-08, absmean=2.60126e-08, std=4.87605e-07
# │ Gˢⁿ⁺ʰ: min=-4.45269e-21, max=4.16379e-21, mean=3.17941e-28, absmean=4.51423e-22, std=6.06846e-22
# │ ∇⋅u1:  min=-1.22733e-22, max=1.24305e-22, mean=-4.10928e-29, absmean=1.28192e-23, std=1.72206e-23
# │ ∇⋅u2:  min=-3.38813e-24, max=3.38813e-24, mean=-1.04755e-29, absmean=1.62936e-27, std=2.73518e-26
# │ wSurf: min=-1.55752e-19, max=1.52127e-19, mean=4.62291e-27, absmean=2.01254e-20, std=2.7025e-20
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:314
# ┌ Info: Temperature source term:
# │ div_flux:  mean=-9.04094e-27, absmean=8.26534e-16, std=2.902e-14
# │ lap_diff:  mean=1.24678e-28, absmean=9.35164e-11, std=1.26479e-09
# │ Fᵀ[:,:,1]: mean=-2.60126e-06, absmean=2.60126e-06, std=4.14276e-06
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:216
# ┌ Info: Salinity source term:
# │ div_flux:  mean=4.14895e-28, absmean=4.4867e-22, std=6.02716e-22
# │ lap_diff:  mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:226
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-2.68428e-15, max=2.13095e-15, mean=5.15125e-35, absmean=1.21892e-18, std=3.78905e-17
# │ Gwn_u_dot_w: min=-1.80587e-10, max=1.79086e-10, mean=-1.09405e-30, absmean=4.92509e-14, std=2.38348e-12
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:246
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-2.62014e-08, max=2.59489e-08, mean=-5.12852e-28, absmean=6.62686e-10, std=3.54496e-09
# │ RHS_rec: min=-2.62014e-08, max=2.59489e-08, mean=1.86943e-27, absmean=6.62686e-10, std=3.54496e-09
# │ error:   min=-4.4797e-23, max=4.30134e-23, mean=3.23599e-27, absmean=5.24568e-24, std=6.88048e-24
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:274
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-9.9434e-11, max=1.89068e-10, mean=-1.02041e-24, absmean=6.49903e-11, std=7.77392e-11
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:293
# ┌ Info: Time: 17
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -0.000161038 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-4.24524e-07, max=4.24599e-07, mean=-4.67678e-27, absmean=3.79938e-10, std=5.39662e-09
# │ vⁿ:   min=-4.24904e-07, max=4.24689e-07, mean=1.94321e-26, absmean=3.79942e-10, std=5.39661e-09
# │ wⁿ:   min=-3.70237e-07, max=3.78238e-07, mean=-4.30377e-25, absmean=5.90067e-10, std=6.39645e-09
# │ Tⁿ:   min=283, max=283, mean=283, absmean=283, std=8.58871e-06
# │ Sⁿ:   min=35, max=35, mean=35, absmean=35, std=0
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-0.00516882, max=-0, mean=-0.00144527, absmean=0.00144527, std=0.00230541
# │ pⁿʰ⁺ˢ:min=-1.48007e-06, max=3.74919e-06, mean=6.50521e-24, absmean=2.09134e-06, std=2.32207e-06
# │ pⁿ:   min=-0.00516525, max=-8.92162e-07, mean=-0.00144527, absmean=0.00144527, std=0.00230309
# │ ρⁿ:   min=1027, max=1027, mean=1027, absmean=1027, std=1.38942e-06
# │ δρ:   min=0, max=2.63317e-05, mean=7.40592e-08, absmean=7.40592e-08, std=1.38942e-06
# │ Gᵘⁿ⁺ʰ: min=-2.6003e-07, max=2.60271e-07, mean=-7.96536e-26, absmean=3.38795e-09, std=2.82035e-08
# │ Gᵛⁿ⁺ʰ: min=-2.60099e-07, max=2.60034e-07, mean=-2.03288e-26, absmean=3.38485e-09, std=2.82172e-08
# │ Gʷⁿ⁺ʰ: min=-1.93229e-10, max=1.91623e-10, mean=-9.23939e-31, absmean=5.2702e-14, std=2.55042e-12
# │ Gᵀⁿ⁺ʰ: min=-9.24049e-06, max=3.80935e-20, mean=-2.60126e-08, absmean=2.60126e-08, std=4.87553e-07
# │ Gˢⁿ⁺ʰ: min=-4.87057e-21, max=4.71118e-21, mean=6.6857e-28, absmean=5.00353e-22, std=6.68278e-22
# │ ∇⋅u1:  min=-1.24604e-22, max=1.36025e-22, mean=1.53129e-29, absmean=1.40481e-23, std=1.88345e-23
# │ ∇⋅u2:  min=-3.38813e-24, max=3.38813e-24, mean=-1.0248e-29, absmean=1.82739e-27, std=2.94353e-26
# │ wSurf: min=-1.77945e-19, max=1.76996e-19, mean=2.27785e-27, absmean=2.21583e-20, std=2.97584e-20
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:314
# ┌ Info: Temperature source term:
# │ div_flux:  mean=1.96131e-27, absmean=9.85071e-16, std=3.45836e-14
# │ lap_diff:  mean=-9.88793e-27, absmean=9.91387e-11, std=1.34078e-09
# │ Fᵀ[:,:,1]: mean=-2.60126e-06, absmean=2.60126e-06, std=4.14276e-06
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:216
# ┌ Info: Salinity source term:
# │ div_flux:  mean=-1.23135e-27, absmean=4.91688e-22, std=6.59214e-22
# │ lap_diff:  mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:226
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-3.39174e-15, max=2.69237e-15, mean=1.97009e-34, absmean=1.54032e-18, std=4.78763e-17
# │ Gwn_u_dot_w: min=-2.02943e-10, max=2.01256e-10, mean=-1.14576e-30, absmean=5.53547e-14, std=2.67872e-12
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:246
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-2.77163e-08, max=2.74506e-08, mean=1.28048e-27, absmean=7.01078e-10, std=3.75015e-09
# │ RHS_rec: min=-2.77163e-08, max=2.74506e-08, mean=6.80935e-27, absmean=7.01078e-10, std=3.75015e-09
# │ error:   min=-4.30134e-23, max=4.48487e-23, mean=8.70815e-27, absmean=5.44588e-24, std=7.22254e-24
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:274
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-1.11075e-10, max=2.11203e-10, mean=-8.99973e-25, absmean=7.25989e-11, std=8.68403e-11
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:293
# ┌ Info: Time: 18
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -0.000170179 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-4.7414e-07, max=4.74224e-07, mean=4.53802e-26, absmean=4.24398e-10, std=6.02741e-09
# │ vⁿ:   min=-4.74564e-07, max=4.74325e-07, mean=3.21839e-26, absmean=4.24402e-10, std=6.02737e-09
# │ wⁿ:   min=-4.13416e-07, max=4.22349e-07, mean=-4.45958e-25, absmean=6.59107e-10, std=7.14335e-09
# │ Tⁿ:   min=283, max=283, mean=283, absmean=283, std=9.07621e-06
# │ Sⁿ:   min=35, max=35, mean=35, absmean=35, std=0
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-0.00548019, max=-0, mean=-0.00153233, absmean=0.00153233, std=0.00244427
# │ pⁿʰ⁺ˢ:min=-1.56557e-06, max=3.96716e-06, mean=-7.80626e-24, absmean=2.21292e-06, std=2.45705e-06
# │ pⁿ:   min=-0.00547641, max=-9.44611e-07, mean=-0.00153233, absmean=0.00153233, std=0.00244182
# │ ρⁿ:   min=1027, max=1027, mean=1027, absmean=1027, std=1.47304e-06
# │ δρ:   min=0, max=2.79165e-05, mean=7.85206e-08, absmean=7.85206e-08, std=1.47304e-06
# │ Gᵘⁿ⁺ʰ: min=-2.75106e-07, max=2.75375e-07, mean=4.53412e-26, absmean=3.58468e-09, std=2.98385e-08
# │ Gᵛⁿ⁺ʰ: min=-2.75194e-07, max=2.75111e-07, mean=1.69407e-26, absmean=3.58137e-09, std=2.9853e-08
# │ Gʷⁿ⁺ʰ: min=-2.16356e-10, max=2.14558e-10, mean=-2.34259e-30, absmean=5.9017e-14, std=2.85586e-12
# │ Gᵀⁿ⁺ʰ: min=-9.23956e-06, max=3.83382e-20, mean=-2.60126e-08, absmean=2.60126e-08, std=4.875e-07
# │ Gˢⁿ⁺ʰ: min=-5.16014e-21, max=4.74148e-21, mean=-2.2191e-27, absmean=5.40968e-22, std=7.22466e-22
# │ ∇⋅u1:  min=-1.306e-22, max=1.49485e-22, mean=-1.34564e-29, absmean=1.51472e-23, std=2.03948e-23
# │ ∇⋅u2:  min=-3.38813e-24, max=3.38813e-24, mean=-1.79835e-29, absmean=2.11815e-27, std=3.62652e-26
# │ wSurf: min=-2.02576e-19, max=1.92005e-19, mean=3.01218e-27, absmean=2.37707e-20, std=3.22527e-20
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:314
# ┌ Info: Temperature source term:
# │ div_flux:  mean=-7.89122e-27, absmean=1.16261e-15, std=4.08134e-14
# │ lap_diff:  mean=4.61328e-27, absmean=1.0476e-10, std=1.41673e-09
# │ Fᵀ[:,:,1]: mean=-2.60126e-06, absmean=2.60126e-06, std=4.14276e-06
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:216
# ┌ Info: Salinity source term:
# │ div_flux:  mean=-2.64761e-27, absmean=5.30151e-22, std=7.13818e-22
# │ lap_diff:  mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:226
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-4.23006e-15, max=3.35756e-15, mean=-1.93202e-35, absmean=1.92123e-18, std=5.97091e-17
# │ Gwn_u_dot_w: min=-2.26582e-10, max=2.24699e-10, mean=-1.92713e-30, absmean=6.18102e-14, std=2.99094e-12
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:246
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-2.92304e-08, max=2.89516e-08, mean=1.24077e-27, absmean=7.39455e-10, std=3.95523e-09
# │ RHS_rec: min=-2.92304e-08, max=2.89516e-08, mean=-3.08042e-27, absmean=7.39455e-10, std=3.95523e-09
# │ error:   min=-5.40769e-23, max=4.98635e-23, mean=-3.48893e-27, absmean=5.65486e-24, std=7.56155e-24
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:274
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-1.23357e-10, max=2.34556e-10, mean=-7.94093e-25, absmean=8.06264e-11, std=9.64425e-11
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:293
# ┌ Info: Time: 19
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -0.00017932 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-5.26474e-07, max=5.26567e-07, mean=9.15242e-27, absmean=4.71303e-10, std=6.69277e-09
# │ vⁿ:   min=-5.26945e-07, max=5.26679e-07, mean=7.16669e-27, absmean=4.71305e-10, std=6.69268e-09
# │ wⁿ:   min=-4.58945e-07, max=4.68861e-07, mean=-5.85143e-25, absmean=7.3194e-10, std=7.93105e-09
# │ Tⁿ:   min=283, max=283, mean=283, absmean=283, std=9.56366e-06
# │ Sⁿ:   min=35, max=35, mean=35, absmean=35, std=0
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-0.00579156, max=-0, mean=-0.0016194, absmean=0.0016194, std=0.00258314
# │ pⁿʰ⁺ˢ:min=-1.65101e-06, max=4.18512e-06, mean=1.73472e-24, absmean=2.33449e-06, std=2.59204e-06
# │ pⁿ:   min=-0.00578758, max=-9.97165e-07, mean=-0.0016194, absmean=0.0016194, std=0.00258055
# │ ρⁿ:   min=1027, max=1027, mean=1027, absmean=1027, std=1.55665e-06
# │ δρ:   min=0, max=2.95012e-05, mean=8.2982e-08, absmean=8.2982e-08, std=1.55665e-06
# │ Gᵘⁿ⁺ʰ: min=-2.90178e-07, max=2.90476e-07, mean=-4.25114e-26, absmean=3.78139e-09, std=3.14729e-08
# │ Gᵛⁿ⁺ʰ: min=-2.90285e-07, max=2.90183e-07, mean=-3.38813e-27, absmean=3.77785e-09, std=3.14882e-08
# │ Gʷⁿ⁺ʰ: min=-2.40765e-10, max=2.38764e-10, mean=5.34063e-31, absmean=6.56835e-14, std=3.17827e-12
# │ Gᵀⁿ⁺ʰ: min=-9.23863e-06, max=3.95988e-20, mean=-2.60126e-08, absmean=2.60126e-08, std=4.87447e-07
# │ Gˢⁿ⁺ʰ: min=-5.85647e-21, max=4.89737e-21, mean=-3.49736e-27, absmean=5.76314e-22, std=7.75782e-22
# │ ∇⋅u1:  min=-1.43113e-22, max=1.61173e-22, mean=3.38536e-30, absmean=1.63987e-23, std=2.21594e-23
# │ ∇⋅u2:  min=-3.38813e-24, max=5.0822e-24, mean=-8.59063e-31, absmean=2.29412e-27, std=3.73083e-26
# │ wSurf: min=-2.23651e-19, max=2.09793e-19, mean=8.95175e-27, absmean=2.5805e-20, std=3.53625e-20
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:314
# ┌ Info: Temperature source term:
# │ div_flux:  mean=5.8829e-27, absmean=1.36022e-15, std=4.77469e-14
# │ lap_diff:  mean=-7.58942e-27, absmean=1.1038e-10, std=1.49267e-09
# │ Fᵀ[:,:,1]: mean=-2.60126e-06, absmean=2.60126e-06, std=4.14276e-06
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:216
# ┌ Info: Salinity source term:
# │ div_flux:  mean=1.14179e-27, absmean=5.73955e-22, std=7.75574e-22
# │ lap_diff:  mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:226
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-5.21437e-15, max=4.13853e-15, mean=7.46845e-35, absmean=2.36851e-18, std=7.36023e-17
# │ Gwn_u_dot_w: min=-2.51502e-10, max=2.49413e-10, mean=-2.21238e-30, absmean=6.8617e-14, std=3.32012e-12
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:246
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-3.07435e-08, max=3.04518e-08, mean=1.23084e-27, absmean=7.77818e-10, std=4.16021e-09
# │ RHS_rec: min=-3.07435e-08, max=3.04518e-08, mean=-4.2881e-27, absmean=7.77818e-10, std=4.16021e-09
# │ error:   min=-4.76146e-23, max=4.76146e-23, mean=-3.81898e-27, absmean=5.74723e-24, std=7.62143e-24
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:274
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-1.3628e-10, max=2.59128e-10, mean=-4.18223e-25, absmean=8.90728e-11, std=1.06546e-10
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:293
# ┌ Info: Time: 20
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -0.00018846 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-5.81525e-07, max=5.81627e-07, mean=2.90748e-26, absmean=5.20651e-10, std=7.39268e-09
# │ vⁿ:   min=-5.82045e-07, max=5.81751e-07, mean=-5.11661e-26, absmean=5.20652e-10, std=7.39253e-09
# │ wⁿ:   min=-5.06821e-07, max=5.1777e-07, mean=-3.97057e-25, absmean=8.08568e-10, std=8.75953e-09
# │ Tⁿ:   min=283, max=283, mean=283, absmean=283, std=1.00511e-05
# │ Sⁿ:   min=35, max=35, mean=35, absmean=35, std=0
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-0.00610293, max=-0, mean=-0.00170646, absmean=0.00170646, std=0.002722
# │ pⁿʰ⁺ˢ:min=-1.7364e-06, max=4.40309e-06, mean=6.93889e-24, absmean=2.45606e-06, std=2.72703e-06
# │ pⁿ:   min=-0.00609874, max=-1.04982e-06, mean=-0.00170646, absmean=0.00170646, std=0.00271928
# │ ρⁿ:   min=1027, max=1027, mean=1027, absmean=1027, std=1.64025e-06
# │ δρ:   min=0, max=3.10857e-05, mean=8.74434e-08, absmean=8.74434e-08, std=1.64025e-06
# │ Gᵘⁿ⁺ʰ: min=-3.05255e-07, max=3.05574e-07, mean=3.03312e-26, absmean=3.97809e-09, std=3.31069e-08
# │ Gᵛⁿ⁺ʰ: min=-3.05373e-07, max=3.0525e-07, mean=-3.38813e-26, absmean=3.97431e-09, std=3.3123e-08
# │ Gʷⁿ⁺ʰ: min=-2.66455e-10, max=2.64241e-10, mean=-2.77127e-30, absmean=7.27011e-14, std=3.51763e-12
# │ Gᵀⁿ⁺ʰ: min=-9.2377e-06, max=4.26257e-20, mean=-2.60126e-08, absmean=2.60126e-08, std=4.87394e-07
# │ Gˢⁿ⁺ʰ: min=-6.23556e-21, max=5.27173e-21, mean=3.41543e-27, absmean=6.23579e-22, std=8.42486e-22
# │ ∇⋅u1:  min=-1.57484e-22, max=1.72495e-22, mean=-1.92846e-29, absmean=1.76425e-23, std=2.39193e-23
# │ ∇⋅u2:  min=-3.38813e-24, max=6.77626e-24, mean=7.91885e-30, absmean=2.54047e-27, std=3.97959e-26
# │ wSurf: min=-2.50044e-19, max=2.32629e-19, mean=-5.47221e-27, absmean=2.7958e-20, std=3.85335e-20
# └ @ Main C:\Users\Ali\Documents\Git\OceanDispatch.jl\examples\deep_convection.jl:314

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for k in 1:Nᶻ
        withfig(fig) do
            PyPlot.pcolormesh(xC, yC, Ru[t,:,:,k], cmap="bwr")
            PyPlot.title("u-velocity @ time step n=$t, z-level k=$k")
            PyPlot.xlabel("x")
            PyPlot.ylabel("y")
            PyPlot.colorbar(label="m/s")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-b864b16e-d55f-4ee4-ac79-73b2a2cca9b6", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-b864b16e-d55f-4ee4-ac79-73b2a2cca9b6\",\"id\":\"ob_254\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-b864b16e-d55f-4ee4-ac79-73b2a2cca9b6\",\"id\":\"ob_253\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:k=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-2b801c83-9b1b-4809-8501-1fd56ba3b7f8", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["k"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-2b801c83-9b1b-4809-8501-1fd56ba3b7f8\",\"id\":\"ob_256\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-2b801c83-9b1b-4809-8501-1fd56ba3b7f8\",\"id\":\"ob_255\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000061153A58>), nothing, getfield(Main, Symbol("##189#194")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000061153A58>))), nothing, getfield(Main, Symbol("##190#195")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:k=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-2b801c83-9b1b-4809-8501-1fd56ba3b7f8", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["k"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-2b801c83-9b1b-4809-8501-1fd56ba3b7f8\",\"id\":\"ob_256\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-2b801c83-9b1b-4809-8501-1fd56ba3b7f8\",\"id\":\"ob_255\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000061153A58>), nothing, getfield(Main, Symbol("##189#194")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000061153A58>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for j in 1:Nʸ
        withfig(fig) do
            PyPlot.pcolormesh(xC, zC, copy(Ru[t, :, j, :]'), cmap="bwr")
            PyPlot.title("u-velocity @ time step n=$t, y-slice j=$j")
            PyPlot.xlabel("x (m)")
            PyPlot.ylabel("z (m)")
            PyPlot.colorbar(label="m/s")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-eab47d7b-c191-470a-b170-fc24a484ef24", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-eab47d7b-c191-470a-b170-fc24a484ef24\",\"id\":\"ob_44\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-eab47d7b-c191-470a-b170-fc24a484ef24\",\"id\":\"ob_43\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:j=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-95a097ac-240e-4111-9e83-103dfbe7ee20", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["j"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-95a097ac-240e-4111-9e83-103dfbe7ee20\",\"id\":\"ob_46\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-95a097ac-240e-4111-9e83-103dfbe7ee20\",\"id\":\"ob_45\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000004694A20>), nothing, getfield(Main, Symbol("##39#44")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000004694A20>))), nothing, getfield(Main, Symbol("##40#45")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:j=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-95a097ac-240e-4111-9e83-103dfbe7ee20", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["j"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-95a097ac-240e-4111-9e83-103dfbe7ee20\",\"id\":\"ob_46\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-95a097ac-240e-4111-9e83-103dfbe7ee20\",\"id\":\"ob_45\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000004694A20>), nothing, getfield(Main, Symbol("##39#44")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000004694A20>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for i in 1:Nˣ
        withfig(fig) do
            PyPlot.pcolormesh(xC, zC, copy(Ru[t, i, :, :]'), cmap="bwr")
            PyPlot.title("u-velocity @ time step n=$t, x-slice i=$i")
            PyPlot.xlabel("y (m)")
            PyPlot.ylabel("z (m)")
            PyPlot.colorbar(label="m/s")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-5f2a16fb-0509-4d68-8c6f-8a960c126cba", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-5f2a16fb-0509-4d68-8c6f-8a960c126cba\",\"id\":\"ob_30\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-5f2a16fb-0509-4d68-8c6f-8a960c126cba\",\"id\":\"ob_29\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:i=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-4ed42281-8309-4aae-a148-3d4a8bad7211", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["i"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-4ed42281-8309-4aae-a148-3d4a8bad7211\",\"id\":\"ob_32\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-4ed42281-8309-4aae-a148-3d4a8bad7211\",\"id\":\"ob_31\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000030A6EF60>), nothing, getfield(Main, Symbol("##29#34")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000030A6EF60>))), nothing, getfield(Main, Symbol("##30#35")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:i=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-4ed42281-8309-4aae-a148-3d4a8bad7211", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["i"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-4ed42281-8309-4aae-a148-3d4a8bad7211\",\"id\":\"ob_32\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-4ed42281-8309-4aae-a148-3d4a8bad7211\",\"id\":\"ob_31\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000030A6EF60>), nothing, getfield(Main, Symbol("##29#34")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000030A6EF60>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for k in 1:Nᶻ
        withfig(fig) do
            PyPlot.pcolormesh(xC, yC, Rv[t,:,:,k], cmap="bwr")
            PyPlot.title("v-velocity @ time step n=$t, z-level k=$k")
            PyPlot.xlabel("x")
            PyPlot.ylabel("y")
            PyPlot.colorbar(label="m/s")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-24e26e67-fa50-433b-885d-352a50b44c9b", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-24e26e67-fa50-433b-885d-352a50b44c9b\",\"id\":\"ob_58\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-24e26e67-fa50-433b-885d-352a50b44c9b\",\"id\":\"ob_57\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:k=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-8a1e697a-2a0e-4ba6-b3bd-6816b97d50d8", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["k"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-8a1e697a-2a0e-4ba6-b3bd-6816b97d50d8\",\"id\":\"ob_60\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-8a1e697a-2a0e-4ba6-b3bd-6816b97d50d8\",\"id\":\"ob_59\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000045B8EE10>), nothing, getfield(Main, Symbol("##49#54")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000045B8EE10>))), nothing, getfield(Main, Symbol("##50#55")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:k=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-8a1e697a-2a0e-4ba6-b3bd-6816b97d50d8", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["k"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-8a1e697a-2a0e-4ba6-b3bd-6816b97d50d8\",\"id\":\"ob_60\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-8a1e697a-2a0e-4ba6-b3bd-6816b97d50d8\",\"id\":\"ob_59\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000045B8EE10>), nothing, getfield(Main, Symbol("##49#54")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000045B8EE10>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for j in 1:Nʸ
        withfig(fig) do
            PyPlot.pcolormesh(xC, zC, copy(Rv[t, :, j, :]'), cmap="bwr")
            PyPlot.title("v-velocity @ time step n=$t, y-slice j=$j")
            PyPlot.xlabel("x (m)")
            PyPlot.ylabel("z (m)")
            PyPlot.colorbar(label="m/s")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-8d0ed50f-df8d-4168-ace7-860196f6db92", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-8d0ed50f-df8d-4168-ace7-860196f6db92\",\"id\":\"ob_72\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-8d0ed50f-df8d-4168-ace7-860196f6db92\",\"id\":\"ob_71\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:j=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-64fb3d34-c05a-4628-ab2d-536ec77ad72d", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["j"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-64fb3d34-c05a-4628-ab2d-536ec77ad72d\",\"id\":\"ob_74\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-64fb3d34-c05a-4628-ab2d-536ec77ad72d\",\"id\":\"ob_73\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000003002FEB8>), nothing, getfield(Main, Symbol("##59#64")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000003002FEB8>))), nothing, getfield(Main, Symbol("##60#65")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:j=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-64fb3d34-c05a-4628-ab2d-536ec77ad72d", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["j"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-64fb3d34-c05a-4628-ab2d-536ec77ad72d\",\"id\":\"ob_74\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-64fb3d34-c05a-4628-ab2d-536ec77ad72d\",\"id\":\"ob_73\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000003002FEB8>), nothing, getfield(Main, Symbol("##59#64")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000003002FEB8>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for i in 1:Nˣ
        withfig(fig) do
            PyPlot.pcolormesh(xC, zC, copy(Rv[t, i, :, :]'), cmap="bwr")
            PyPlot.title("v-velocity @ time step n=$t, x-slice i=$i")
            PyPlot.xlabel("y (m)")
            PyPlot.ylabel("z (m)")
            PyPlot.colorbar(label="m/s")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-375e2480-51cb-4312-9674-fba4f0be95b2", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-375e2480-51cb-4312-9674-fba4f0be95b2\",\"id\":\"ob_86\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-375e2480-51cb-4312-9674-fba4f0be95b2\",\"id\":\"ob_85\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:i=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-0e5b4992-43da-414d-bf0e-721949101d6f", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["i"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-0e5b4992-43da-414d-bf0e-721949101d6f\",\"id\":\"ob_88\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-0e5b4992-43da-414d-bf0e-721949101d6f\",\"id\":\"ob_87\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x00000000304858D0>), nothing, getfield(Main, Symbol("##69#74")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x00000000304858D0>))), nothing, getfield(Main, Symbol("##70#75")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:i=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-0e5b4992-43da-414d-bf0e-721949101d6f", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["i"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-0e5b4992-43da-414d-bf0e-721949101d6f\",\"id\":\"ob_88\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-0e5b4992-43da-414d-bf0e-721949101d6f\",\"id\":\"ob_87\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x00000000304858D0>), nothing, getfield(Main, Symbol("##69#74")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x00000000304858D0>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for k in 1:Nᶻ
        withfig(fig) do
            PyPlot.pcolormesh(xC, yC, Rw[t,:,:,k], cmap="bwr")
            PyPlot.title("w-velocity @ time step n=$t, z-level k=$k")
            PyPlot.xlabel("x")
            PyPlot.ylabel("y")
            PyPlot.colorbar(label="m/s")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-78dbecf6-4f03-458a-9bac-85e397da8a7d", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-78dbecf6-4f03-458a-9bac-85e397da8a7d\",\"id\":\"ob_100\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-78dbecf6-4f03-458a-9bac-85e397da8a7d\",\"id\":\"ob_99\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:k=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-e596f982-ed80-45f0-ae55-aeba188177d2", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["k"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-e596f982-ed80-45f0-ae55-aeba188177d2\",\"id\":\"ob_102\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-e596f982-ed80-45f0-ae55-aeba188177d2\",\"id\":\"ob_101\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000004663198>), nothing, getfield(Main, Symbol("##79#84")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000004663198>))), nothing, getfield(Main, Symbol("##80#85")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:k=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-e596f982-ed80-45f0-ae55-aeba188177d2", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["k"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-e596f982-ed80-45f0-ae55-aeba188177d2\",\"id\":\"ob_102\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-e596f982-ed80-45f0-ae55-aeba188177d2\",\"id\":\"ob_101\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000004663198>), nothing, getfield(Main, Symbol("##79#84")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000004663198>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for j in 1:Nʸ
        withfig(fig) do
            PyPlot.pcolormesh(xC, zC, copy(Rw[t, :, j, :]'), cmap="bwr")
            PyPlot.title("w-velocity @ time step n=$t, y-slice j=$j")
            PyPlot.xlabel("x (m)")
            PyPlot.ylabel("z (m)")
            PyPlot.colorbar(label="m/s")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-0170b384-9992-4aab-a4f7-0c5c8834c653", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-0170b384-9992-4aab-a4f7-0c5c8834c653\",\"id\":\"ob_114\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-0170b384-9992-4aab-a4f7-0c5c8834c653\",\"id\":\"ob_113\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:j=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-3e15b493-9867-4b73-81a7-011d0d0f6f3a", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["j"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-3e15b493-9867-4b73-81a7-011d0d0f6f3a\",\"id\":\"ob_116\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-3e15b493-9867-4b73-81a7-011d0d0f6f3a\",\"id\":\"ob_115\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x00000000312D15F8>), nothing, getfield(Main, Symbol("##89#94")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x00000000312D15F8>))), nothing, getfield(Main, Symbol("##90#95")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:j=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-3e15b493-9867-4b73-81a7-011d0d0f6f3a", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["j"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-3e15b493-9867-4b73-81a7-011d0d0f6f3a\",\"id\":\"ob_116\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-3e15b493-9867-4b73-81a7-011d0d0f6f3a\",\"id\":\"ob_115\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x00000000312D15F8>), nothing, getfield(Main, Symbol("##89#94")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x00000000312D15F8>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for i in 1:Nˣ
        withfig(fig) do
            PyPlot.pcolormesh(xC, zC, copy(Rw[t, i, :, :]'), cmap="bwr")
            PyPlot.title("w-velocity @ time step n=$t, x-slice i=$i")
            PyPlot.xlabel("y (m)")
            PyPlot.ylabel("z (m)")
            PyPlot.colorbar(label="m/s")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-369eb36f-ee52-49a7-a4ed-1fe03e25e4da", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-369eb36f-ee52-49a7-a4ed-1fe03e25e4da\",\"id\":\"ob_128\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-369eb36f-ee52-49a7-a4ed-1fe03e25e4da\",\"id\":\"ob_127\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:i=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-b6da1d4d-e7da-45f1-a3f4-8e183fc68893", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["i"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-b6da1d4d-e7da-45f1-a3f4-8e183fc68893\",\"id\":\"ob_130\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-b6da1d4d-e7da-45f1-a3f4-8e183fc68893\",\"id\":\"ob_129\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000030064710>), nothing, getfield(Main, Symbol("##99#104")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000030064710>))), nothing, getfield(Main, Symbol("##100#105")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:i=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-b6da1d4d-e7da-45f1-a3f4-8e183fc68893", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["i"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-b6da1d4d-e7da-45f1-a3f4-8e183fc68893\",\"id\":\"ob_130\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-b6da1d4d-e7da-45f1-a3f4-8e183fc68893\",\"id\":\"ob_129\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000030064710>), nothing, getfield(Main, Symbol("##99#104")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000030064710>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for k in 1:Nᶻ
        withfig(fig) do
            PyPlot.pcolormesh(xC, yC, RT[t,:,:,k], cmap="bwr")
            PyPlot.title("Temperature @ time step n=$t, z-level k=$k")
            PyPlot.xlabel("x")
            PyPlot.ylabel("y")
            PyPlot.colorbar(label="K")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-4b20d28f-cf2e-4148-a6f0-7bbd5f142185", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-4b20d28f-cf2e-4148-a6f0-7bbd5f142185\",\"id\":\"ob_142\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-4b20d28f-cf2e-4148-a6f0-7bbd5f142185\",\"id\":\"ob_141\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:k=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-8c123156-2bb4-4a2b-9888-6e018b609dda", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["k"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-8c123156-2bb4-4a2b-9888-6e018b609dda\",\"id\":\"ob_144\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-8c123156-2bb4-4a2b-9888-6e018b609dda\",\"id\":\"ob_143\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000031823160>), nothing, getfield(Main, Symbol("##109#114")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000031823160>))), nothing, getfield(Main, Symbol("##110#115")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:k=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-8c123156-2bb4-4a2b-9888-6e018b609dda", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["k"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-8c123156-2bb4-4a2b-9888-6e018b609dda\",\"id\":\"ob_144\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-8c123156-2bb4-4a2b-9888-6e018b609dda\",\"id\":\"ob_143\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000031823160>), nothing, getfield(Main, Symbol("##109#114")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000031823160>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for j in 1:Nʸ
        withfig(fig) do
            PyPlot.pcolormesh(xC, zC, copy(Rw[t, :, j, :]'), cmap="bwr")
            PyPlot.title("Temperature @ time step n=$t, y-slice j=$j")
            PyPlot.xlabel("x (m)")
            PyPlot.ylabel("z (m)")
            PyPlot.colorbar(label="K")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-02823869-1880-49de-a0b5-fc9353cccdcc", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-02823869-1880-49de-a0b5-fc9353cccdcc\",\"id\":\"ob_156\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-02823869-1880-49de-a0b5-fc9353cccdcc\",\"id\":\"ob_155\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:j=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-f1b7498f-771b-451c-bc6e-17145ac28c0a", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["j"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-f1b7498f-771b-451c-bc6e-17145ac28c0a\",\"id\":\"ob_158\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-f1b7498f-771b-451c-bc6e-17145ac28c0a\",\"id\":\"ob_157\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x00000000317D6E48>), nothing, getfield(Main, Symbol("##119#124")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x00000000317D6E48>))), nothing, getfield(Main, Symbol("##120#125")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:j=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-f1b7498f-771b-451c-bc6e-17145ac28c0a", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["j"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-f1b7498f-771b-451c-bc6e-17145ac28c0a\",\"id\":\"ob_158\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-f1b7498f-771b-451c-bc6e-17145ac28c0a\",\"id\":\"ob_157\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x00000000317D6E48>), nothing, getfield(Main, Symbol("##119#124")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x00000000317D6E48>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for i in 1:Nˣ
        withfig(fig) do
            PyPlot.pcolormesh(xC, zC, copy(RT[t, i, :, :]'), cmap="bwr")
            PyPlot.title("Temperature @ time step n=$t, x-slice i=$i")
            PyPlot.xlabel("y (m)")
            PyPlot.ylabel("z (m)")
            PyPlot.colorbar(label="K")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-f8ca6de7-67a1-47d3-b4ac-5b96e6a7ad14", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-f8ca6de7-67a1-47d3-b4ac-5b96e6a7ad14\",\"id\":\"ob_170\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-f8ca6de7-67a1-47d3-b4ac-5b96e6a7ad14\",\"id\":\"ob_169\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:i=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-c12c7597-4832-47b4-8ccd-cc155e9f311c", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["i"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-c12c7597-4832-47b4-8ccd-cc155e9f311c\",\"id\":\"ob_172\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-c12c7597-4832-47b4-8ccd-cc155e9f311c\",\"id\":\"ob_171\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000003018F390>), nothing, getfield(Main, Symbol("##129#134")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000003018F390>))), nothing, getfield(Main, Symbol("##130#135")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:i=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-c12c7597-4832-47b4-8ccd-cc155e9f311c", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["i"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-c12c7597-4832-47b4-8ccd-cc155e9f311c\",\"id\":\"ob_172\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-c12c7597-4832-47b4-8ccd-cc155e9f311c\",\"id\":\"ob_171\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000003018F390>), nothing, getfield(Main, Symbol("##129#134")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000003018F390>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for k in 1:Nᶻ
        withfig(fig) do
            PyPlot.pcolormesh(xC, yC, RS[t,:,:,k], cmap="bwr")
            PyPlot.title("Salinity @ time step n=$t, z-level k=$k")
            PyPlot.xlabel("x")
            PyPlot.ylabel("y")
            PyPlot.colorbar(label="psu")
        end
    end
end

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for j in 1:Nʸ
        withfig(fig) do
            PyPlot.pcolormesh(xC, zC, copy(RS[t, :, j, :]'), cmap="bwr")
            PyPlot.title("Salinity @ time step n=$t, y-slice j=$j")
            PyPlot.xlabel("x (m)")
            PyPlot.ylabel("z (m)")
            PyPlot.colorbar(label="psu")
        end
    end
end

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for i in 1:Nˣ
        withfig(fig) do
            PyPlot.pcolormesh(xC, zC, copy(RS[t, i, :, :]'), cmap="bwr")
            PyPlot.title("Salinity @ time step n=$t, x-slice i=$i")
            PyPlot.xlabel("y (m)")
            PyPlot.ylabel("z (m)")
            PyPlot.colorbar(label="K")
        end
    end
end

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for k in 1:Nᶻ
        withfig(fig) do
            PyPlot.pcolormesh(xC, yC, RpHY′[t,:,:,k], cmap="bwr")
            PyPlot.title("pHY′ @ time step n=$t, z-level k=$k")
            PyPlot.xlabel("x")
            PyPlot.ylabel("y")
            PyPlot.colorbar(label="Pa")
        end
   end
end

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for j in 1:Nʸ
        withfig(fig) do
            PyPlot.pcolormesh(xC, zC, copy(RpHY′[t, :, j, :]'), cmap="bwr")
            PyPlot.title("pHY′ @ time step n=$t, y-slice j=$j")
            PyPlot.xlabel("x (m)")
            PyPlot.ylabel("z (m)")
            PyPlot.colorbar(label="Pa")
        end
    end
end

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for i in 1:Nˣ
        withfig(fig) do
            PyPlot.pcolormesh(xC, zC, copy(RpHY′[t, i, :, :]'), cmap="bwr")
            PyPlot.title("pHY′ @ time step n=$t, x-slice i=$i")
            PyPlot.xlabel("y (m)")
            PyPlot.ylabel("z (m)")
            PyPlot.colorbar(label="Pa")
        end
    end
end

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for k in 1:Nᶻ
        withfig(fig) do
            PyPlot.pcolormesh(xC, yC, RpNHS[t,:,:,k], cmap="bwr")
            PyPlot.title("pHY+S @ time step n=$t, z-level k=$k")
            PyPlot.xlabel("x")
            PyPlot.ylabel("y")
            PyPlot.colorbar(label="Pa")
        end
   end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-f9252587-0ddf-46ed-8d90-53557cabe2ef", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-f9252587-0ddf-46ed-8d90-53557cabe2ef\",\"id\":\"ob_184\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-f9252587-0ddf-46ed-8d90-53557cabe2ef\",\"id\":\"ob_183\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:k=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-b337e946-4671-4b6a-8397-dc0f9e4cf80e", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["k"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-b337e946-4671-4b6a-8397-dc0f9e4cf80e\",\"id\":\"ob_186\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-b337e946-4671-4b6a-8397-dc0f9e4cf80e\",\"id\":\"ob_185\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000004605F6D8>), nothing, getfield(Main, Symbol("##139#144")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000004605F6D8>))), nothing, getfield(Main, Symbol("##140#145")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:k=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-b337e946-4671-4b6a-8397-dc0f9e4cf80e", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["k"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-b337e946-4671-4b6a-8397-dc0f9e4cf80e\",\"id\":\"ob_186\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-b337e946-4671-4b6a-8397-dc0f9e4cf80e\",\"id\":\"ob_185\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000004605F6D8>), nothing, getfield(Main, Symbol("##139#144")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000004605F6D8>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for j in 1:Nʸ
        withfig(fig) do
            PyPlot.pcolormesh(xC, zC, copy(RpNHS[t, :, j, :]'), cmap="bwr")
            PyPlot.title("pNH+S @ time step n=$t, y-slice j=$j")
            PyPlot.xlabel("x (m)")
            PyPlot.ylabel("z (m)")
            PyPlot.colorbar(label="Pa")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-b1873939-8d4f-485a-86fb-be05adf032df", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-b1873939-8d4f-485a-86fb-be05adf032df\",\"id\":\"ob_198\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-b1873939-8d4f-485a-86fb-be05adf032df\",\"id\":\"ob_197\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:j=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-b0478f78-3552-4515-a817-24c464b8dc81", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["j"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-b0478f78-3552-4515-a817-24c464b8dc81\",\"id\":\"ob_200\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-b0478f78-3552-4515-a817-24c464b8dc81\",\"id\":\"ob_199\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000045FF7240>), nothing, getfield(Main, Symbol("##149#154")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000045FF7240>))), nothing, getfield(Main, Symbol("##150#155")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:j=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-b0478f78-3552-4515-a817-24c464b8dc81", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["j"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-b0478f78-3552-4515-a817-24c464b8dc81\",\"id\":\"ob_200\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-b0478f78-3552-4515-a817-24c464b8dc81\",\"id\":\"ob_199\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000045FF7240>), nothing, getfield(Main, Symbol("##149#154")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000045FF7240>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for i in 1:Nˣ
        withfig(fig) do
            PyPlot.pcolormesh(xC, zC, copy(RpNHS[t, i, :, :]'), cmap="bwr")
            PyPlot.title("pNH+S @ time step n=$t, x-slice i=$i")
            PyPlot.xlabel("y (m)")
            PyPlot.ylabel("z (m)")
            PyPlot.colorbar(label="Pa")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-43a224ba-633c-4203-b0c0-f780655ad6d4", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-43a224ba-633c-4203-b0c0-f780655ad6d4\",\"id\":\"ob_212\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-43a224ba-633c-4203-b0c0-f780655ad6d4\",\"id\":\"ob_211\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:i=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-7f1714f2-0224-4836-be07-195bf003f344", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["i"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-7f1714f2-0224-4836-be07-195bf003f344\",\"id\":\"ob_214\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-7f1714f2-0224-4836-be07-195bf003f344\",\"id\":\"ob_213\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000031328780>), nothing, getfield(Main, Symbol("##159#164")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000031328780>))), nothing, getfield(Main, Symbol("##160#165")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:i=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-7f1714f2-0224-4836-be07-195bf003f344", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["i"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-7f1714f2-0224-4836-be07-195bf003f344\",\"id\":\"ob_214\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-7f1714f2-0224-4836-be07-195bf003f344\",\"id\":\"ob_213\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000031328780>), nothing, getfield(Main, Symbol("##159#164")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000031328780>)))))

# %%
PyPlot.pcolormesh(xC, yC, Ru[5,50,:,:] .- 283, cmap="bwr"); PyPlot.colorbar();
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000066A83A20>)

# %%
import Makie
# Out:
# ┌ Info: Precompiling Makie [ee78f7c6-11fb-53f2-987a-cfe4a2b5a57a]
# └ @ Base loading.jl:1186
# WARNING: Method definition contour() in module AbstractPlotting at C:\Users\Ali\.julia\packages\AbstractPlotting\7QqXZ\src\recipes.jl:127 overwritten in module Makie at C:\Users\Ali\.julia\packages\AbstractPlotting\7QqXZ\src\recipes.jl:127.
# ERROR: LoadError: LoadError: cannot assign variable AbstractPlotting.Contour from module Makie
# Stacktrace:
#  [1] top-level scope at C:\Users\Ali\.julia\packages\AbstractPlotting\7QqXZ\src\recipes.jl:128
#  [2] include at .\boot.jl:317 [inlined]
#  [3] include_relative(::Module, ::String) at .\loading.jl:1038
#  [4] include at .\sysimg.jl:29 [inlined]
#  [5] include(::String) at C:\Users\Ali\.julia\packages\Makie\YPDAk\src\Makie.jl:1
#  [6] top-level scope at none:0
#  [7] include at .\boot.jl:317 [inlined]
#  [8] include_relative(::Module, ::String) at .\loading.jl:1038
#  [9] include(::Module, ::String) at .\sysimg.jl:29
#  [10] top-level scope at none:2
#  [11] eval at .\boot.jl:319 [inlined]
#  [12] eval(::Expr) at .\client.jl:389
#  [13] top-level scope at .\none:3
# in expression starting at C:\Users\Ali\.julia\packages\Makie\YPDAk\src\makie_recipes.jl:1
# in expression starting at C:\Users\Ali\.julia\packages\Makie\YPDAk\src\Makie.jl:67
# Failed to precompile Makie [ee78f7c6-11fb-53f2-987a-cfe4a2b5a57a] to C:\Users\Ali\.julia\compiled\v1.0\Makie\iZ1Bl.ji.
#
# Stacktrace:
#  [1] error(::String) at .\error.jl:33
#  [2] macro expansion at .\logging.jl:313 [inlined]
#  [3] compilecache(::Base.PkgId, ::String) at .\loading.jl:1184
#  [4] macro expansion at .\logging.jl:311 [inlined]
#  [5] _require(::Base.PkgId) at .\loading.jl:941
#  [6] require(::Base.PkgId) at .\loading.jl:852
#  [7] macro expansion at .\logging.jl:311 [inlined]
#  [8] require(::Module, ::Symbol) at .\loading.jl:834
#  [9] top-level scope at In[33]:1
