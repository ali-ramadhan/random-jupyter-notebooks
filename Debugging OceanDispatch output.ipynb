# %%
using PyPlot
pygui(false)
# Out:
# false

# %%
cd("D:\\Home\\Git\\OceanDispatch.jl\\")
pwd()
# Out:
# "D:\\Home\\Git\\OceanDispatch.jl"

# %%
include("examples\\deep_convection.jl")
# Out:
# ┌ Info: Recompiling stale cache file C:\Users\Ali\.julia\compiled\v1.0\Interact\XmYW4.ji for Interact [c601a237-2ae4-5e1e-952c-7a85b0c7eef1]
# └ @ Base loading.jl:1184
# HTML{String}("    <script id=\"webio-setup-17216844411110294662\">\n    // Immediately-invoked-function-expression to avoid global variables.\n    (function() {\n        var warning_div = document.getElementById(\"webio-warning-84855594059448056\");\n        var hide = function () {\n            var script = document.getElementById(\"webio-setup-17216844411110294662\");\n            var parent = script && script.parentElement;\n            var grandparent = parent && parent.parentElement;\n            if (grandparent) {\n                grandparent.style.display = \"none\";\n            }\n            warning_div.style.display = \"none\";\n        };\n        if (window.require && require.defined) {\n            // Jupyter notebook.\n            if (require.defined(\"nbextensions/webio/main\")\n                    || require.defined(\"/assetserver/28f5f30a59da434290b7f09bd0d0ddea74a5f34e-dist/main.js\")) {\n                // Extension already loaded.\n                hide();\n                return;\n            }\n            console.warn(\"Loading WebIO Jupyter extension on an ad-hoc basis. Consider enabling the WebIO nbextension for a stabler experience (this should happen automatically when building WebIO).\");\n            require([\"/assetserver/28f5f30a59da434290b7f09bd0d0ddea74a5f34e-dist/main.js\"], function (webIOModule) {\n                webIOModule.load_ipython_extension();\n            });\n            warning_div.innerHTML = \"<strong>Loading WebIO Jupyter extension on an ad-hoc basis. Consider enabling the WebIO nbextension for a stabler experience (this should happen automatically when building WebIO).</strong>\";\n        } else if (window.location.pathname.includes(\"/lab\")) {\n            // Guessing JupyterLab\n            warning_div.innerHTML = \"WebIO does not support JupyterLab yet.\";\n        }\n    })();\n    </script>\n    <div\n        id=\"webio-warning-84855594059448056\"\n        class=\"output_text output_stderr\"\n        style=\"padding: 1em; font-weight: bold;\"\n    >\n        Unable to load WebIO. Please make sure WebIO works for your Jupyter client.\n        <!-- TODO: link to installation docs. -->\n    </div>\n")
# ┌ Info: Recompiling stale cache file C:\Users\Ali\.julia\compiled\v1.0\FFTW\PvIn2.ji for FFTW [7a1cc6ca-52ef-59f5-83cd-3a7055c09341]
# └ @ Base loading.jl:1184
# ┌ Info: Ocean LES model parameters:
# │ NumType: Float64
# │ (Nˣ, Nʸ, Nᶻ) = (100, 100, 100) [#]
# │ (Lˣ, Lʸ, Lᶻ) = (2000, 2000, 2000) [m]
# │ (Δx, Δy, Δz) = (20.0, 20.0, 20.0) [m]
# │ (Aˣ, Aʸ, Aᶻ) = (400.0, 400.0, 400.0) [m²]
# │ V = 8000.0 [m³]
# │ M = 8.216e6 [kg]
# │ Nᵗ = 20 [s]
# │ Δt = 1 [s]
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:130
# ┌ Info: T₀[50, 50, 1] = 283 K
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:177
# ┌ Info: Temperature source term:
# │ div_flux:  mean=0, absmean=0, std=0
# │ lap_diff:  mean=0, absmean=0, std=0
# │ Fᵀ[:,:,1]: mean=-2.60131e-06, absmean=2.60131e-06, std=4.14284e-06
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:215
# ┌ Info: Salinity source term:
# │ div_flux:  mean=0, absmean=0, std=0
# │ lap_diff:  mean=0, absmean=0, std=0
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:225
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:245
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=0, max=0, mean=0, absmean=0, std=0
# │ RHS_rec: min=0, max=0, mean=0, absmean=0, std=0
# │ error:   min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:273
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:292
# ┌ Info: Time: 1
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -1.47625e-05 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=0, max=0, mean=0, absmean=0, std=0
# │ vⁿ:   min=0, max=0, mean=0, absmean=0, std=0
# │ wⁿ:   min=0, max=0, mean=0, absmean=0, std=0
# │ Tⁿ:   min=283, max=283, mean=283, absmean=283, std=7.81556e-07
# │ Sⁿ:   min=35, max=35, mean=35, absmean=35, std=0
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-0, max=-0, mean=0, absmean=0, std=0
# │ pⁿʰ⁺ˢ:min=0, max=0, mean=0, absmean=0, std=0
# │ pⁿ:   min=0, max=0, mean=0, absmean=0, std=0
# │ ρⁿ:   min=1027, max=1027, mean=1027, absmean=1027, std=0
# │ δρ:   min=0, max=0, mean=0, absmean=0, std=0
# │ Gᵘⁿ⁺ʰ: min=0, max=0, mean=0, absmean=0, std=0
# │ Gᵛⁿ⁺ʰ: min=0, max=0, mean=0, absmean=0, std=0
# │ Gʷⁿ⁺ʰ: min=0, max=0, mean=0, absmean=0, std=0
# │ Gᵀⁿ⁺ʰ: min=-1.48107e-05, max=0, mean=-4.16209e-08, absmean=4.16209e-08, std=7.81556e-07
# │ Gˢⁿ⁺ʰ: min=0, max=0, mean=0, absmean=0, std=0
# │ ∇⋅u1:  min=0, max=0, mean=0, absmean=0, std=0
# │ ∇⋅u2:  min=0, max=0, mean=0, absmean=0, std=0
# │ wSurf: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:313
# ┌ Info: Temperature source term:
# │ div_flux:  mean=0, absmean=0, std=0
# │ lap_diff:  mean=2.11758e-28, absmean=9.03062e-12, std=1.22231e-10
# │ Fᵀ[:,:,1]: mean=-2.60131e-06, absmean=2.60131e-06, std=4.14284e-06
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:215
# ┌ Info: Salinity source term:
# │ div_flux:  mean=0, absmean=0, std=0
# │ lap_diff:  mean=0, absmean=0, std=0
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:225
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:245
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-3.91433e-09, max=3.87818e-09, mean=-8.18909e-29, absmean=9.89916e-11, std=5.29993e-10
# │ RHS_rec: min=-3.91433e-09, max=3.87818e-09, mean=-7.37845e-28, absmean=9.89916e-11, std=5.29993e-10
# │ error:   min=-5.9292e-24, max=5.93244e-24, mean=-1.43411e-29, absmean=7.01268e-25, std=9.59783e-25
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:273
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-1.59149e-15, max=3.02613e-15, mean=2.95265e-27, absmean=1.0402e-15, std=1.24426e-15
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:292
# ┌ Info: Time: 2
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -2.39867e-05 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-3.87516e-08, max=3.87673e-08, mean=-2.33448e-27, absmean=5.04571e-10, std=4.20557e-09
# │ vⁿ:   min=-3.87673e-08, max=3.8752e-08, mean=2.96462e-27, absmean=5.03962e-10, std=4.20611e-09
# │ wⁿ:   min=-1.21277e-08, max=1.24357e-12, mean=-3.40815e-11, absmean=3.40882e-11, std=6.39956e-10
# │ Tⁿ:   min=283, max=283, mean=283, absmean=283, std=1.26989e-06
# │ Sⁿ:   min=35, max=35, mean=35, absmean=35, std=0
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-0.00049821, max=-0, mean=-0.000139307, absmean=0.000139307, std=0.000222235
# │ pⁿʰ⁺ˢ:min=-2.21621e-07, max=5.58028e-07, mean=-7.04731e-25, absmean=3.11309e-07, std=3.45654e-07
# │ pⁿ:   min=-0.000497698, max=-7.32365e-08, mean=-0.000139307, absmean=0.000139307, std=0.00022189
# │ ρⁿ:   min=1027, max=1027, mean=1027, absmean=1027, std=1.34044e-07
# │ δρ:   min=0, max=2.54016e-06, mean=7.13837e-09, absmean=7.13837e-09, std=1.34044e-07
# │ Gᵘⁿ⁺ʰ: min=-3.87866e-08, max=3.88023e-08, mean=-1.09022e-27, absmean=5.0506e-10, std=4.20967e-09
# │ Gᵛⁿ⁺ʰ: min=-3.88023e-08, max=3.87866e-08, mean=8.47033e-28, absmean=5.04451e-10, std=4.21021e-09
# │ Gʷⁿ⁺ʰ: min=0, max=0, mean=0, absmean=0, std=0
# │ Gᵀⁿ⁺ʰ: min=-9.25422e-06, max=0, mean=-2.60131e-08, absmean=2.60131e-08, std=4.88337e-07
# │ Gˢⁿ⁺ʰ: min=0, max=0, mean=0, absmean=0, std=0
# │ ∇⋅u1:  min=-4.51629e-09, max=3.8744e-09, mean=-3.56515e-28, absmean=1.01997e-10, std=5.31675e-10
# │ ∇⋅u2:  min=-9.65618e-23, max=1.05032e-22, mean=-1.2688e-27, absmean=3.14827e-25, std=2.40192e-24
# │ wSurf: min=-7.71007e-06, max=7.78194e-06, mean=-2.03288e-24, absmean=1.9779e-07, std=1.05769e-06
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:313
# ┌ Info: Temperature source term:
# │ div_flux:  mean=-1.31078e-25, absmean=2.88652e-08, std=1.50464e-07
# │ lap_diff:  mean=8.47033e-28, absmean=1.46715e-11, std=1.98564e-10
# │ Fᵀ[:,:,1]: mean=-2.60131e-06, absmean=2.60131e-06, std=4.14284e-06
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:215
# ┌ Info: Salinity source term:
# │ div_flux:  mean=-1.81583e-26, absmean=3.5699e-09, std=1.86086e-08
# │ lap_diff:  mean=0, absmean=0, std=0
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:225
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-4.85734e-17, max=4.51026e-17, mean=6.85598e-37, absmean=1.49206e-20, std=4.02688e-19
# │ Gwn_u_dot_w: min=-2.42062e-12, max=3.65475e-12, mean=9.56147e-33, absmean=7.39414e-15, std=1.00071e-13
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:245
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-4.88559e-09, max=4.84034e-09, mean=-3.07711e-28, absmean=1.23613e-10, std=6.61665e-10
# │ RHS_rec: min=-4.88559e-09, max=4.84034e-09, mean=3.97047e-29, absmean=1.23613e-10, std=6.61665e-10
# │ error:   min=-1.11282e-23, max=9.43422e-24, mean=3.49631e-29, absmean=1.05208e-24, std=1.44226e-24
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:273
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-3.5812e-15, max=6.80946e-15, mean=-5.81062e-27, absmean=2.34069e-15, std=2.79985e-15
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:292
# ┌ Info: Time: 3
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -3.34839e-05 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-8.7137e-08, max=8.71724e-08, mean=1.60887e-27, absmean=1.13499e-09, std=9.45836e-09
# │ vⁿ:   min=-8.71723e-08, max=8.715e-08, mean=1.52466e-26, absmean=1.13359e-09, std=9.45939e-09
# │ wⁿ:   min=-3.18331e-08, max=1.16999e-12, mean=-8.94695e-11, absmean=8.94817e-11, std=1.67977e-09
# │ Tⁿ:   min=283, max=283, mean=283, absmean=283, std=1.787e-06
# │ Sⁿ:   min=35, max=35, mean=35, absmean=35, std=2.97738e-08
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-0.000809588, max=-0, mean=-0.000226373, absmean=0.000226373, std=0.000361128
# │ pⁿʰ⁺ˢ:min=-2.76572e-07, max=6.97534e-07, mean=-7.58942e-25, absmean=3.89125e-07, std=4.32054e-07
# │ pⁿ:   min=-0.000808923, max=-1.57856e-07, mean=-0.000226373, absmean=0.000226373, std=0.000360696
# │ ρⁿ:   min=1027, max=1027, mean=1027, absmean=1027, std=2.17798e-07
# │ δρ:   min=0, max=4.12735e-06, mean=1.15998e-08, absmean=1.15998e-08, std=2.17798e-07
# │ Gᵘⁿ⁺ʰ: min=-4.84336e-08, max=4.84531e-08, mean=1.96972e-27, absmean=6.31036e-10, std=5.25791e-09
# │ Gᵛⁿ⁺ʰ: min=-4.8453e-08, max=4.84459e-08, mean=1.2282e-26, absmean=6.30241e-10, std=5.25839e-09
# │ Gʷⁿ⁺ʰ: min=-3.873e-12, max=5.8476e-12, mean=-3.98292e-31, absmean=1.18306e-14, std=1.60114e-13
# │ Gᵀⁿ⁺ʰ: min=-9.52382e-06, max=2.04202e-06, mean=-2.60131e-08, absmean=7.2063e-08, std=5.55569e-07
# │ Gˢⁿ⁺ʰ: min=-2.16967e-07, max=2.52912e-07, mean=-1.87671e-26, absmean=5.71185e-09, std=2.97738e-08
# │ ∇⋅u1:  min=-1.03801e-08, max=8.71004e-09, mean=-7.5108e-28, absmean=2.30569e-10, std=1.19711e-09
# │ ∇⋅u2:  min=-2.10064e-22, max=2.04982e-22, mean=-7.04333e-27, absmean=7.349e-25, std=5.78885e-24
# │ wSurf: min=-1.7333e-05, max=1.74946e-05, mean=-1.35525e-23, absmean=4.44775e-07, std=2.37814e-06
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:313
# ┌ Info: Temperature source term:
# │ div_flux:  mean=2.5411e-27, absmean=6.52509e-08, std=3.38783e-07
# │ lap_diff:  mean=2.56271e-28, absmean=4.70776e-11, std=3.06052e-10
# │ Fᵀ[:,:,1]: mean=-2.60131e-06, absmean=2.60131e-06, std=4.14284e-06
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:215
# ┌ Info: Salinity source term:
# │ div_flux:  mean=-7.99387e-27, absmean=8.0699e-09, std=4.18989e-08
# │ lap_diff:  mean=3.65834e-29, absmean=3.32772e-12, std=1.55135e-11
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:225
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-2.88445e-16, max=2.64352e-16, mean=9.66913e-36, absmean=9.78534e-20, std=2.42563e-18
# │ Gwn_u_dot_w: min=-6.34954e-12, max=9.5885e-12, mean=-6.00921e-31, absmean=1.94057e-14, std=2.62609e-13
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:245
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-1.30465e-07, max=1.31202e-07, mean=1.16649e-26, absmean=1.57949e-09, std=8.74578e-09
# │ RHS_rec: min=-1.30465e-07, max=1.31202e-07, mean=4.15079e-27, absmean=1.57949e-09, std=8.74578e-09
# │ error:   min=-1.05879e-22, max=7.94093e-23, mean=6.46129e-28, absmean=2.46416e-24, std=3.88083e-24
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:273
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-2.86861e-09, max=2.89535e-09, mean=-6.51346e-19, absmean=7.35922e-11, std=3.93523e-10
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:292
# ┌ Info: Time: 4
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -4.33221e-05 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-7.61411e-07, max=7.6149e-07, mean=-2.71543e-27, absmean=7.72924e-09, std=4.63624e-08
# │ vⁿ:   min=-7.6129e-07, max=7.61947e-07, mean=1.52466e-26, absmean=7.72549e-09, std=4.63776e-08
# │ wⁿ:   min=-5.91045e-08, max=3.11163e-09, mean=-1.65533e-10, absmean=2.3881e-10, std=3.13907e-09
# │ Tⁿ:   min=283, max=283, mean=283, absmean=283, std=2.39007e-06
# │ Sⁿ:   min=35, max=35, mean=35, absmean=35, std=8.56223e-08
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-0.00584267, max=0.0047773, mean=-0.000313466, absmean=0.000351563, std=0.000622538
# │ pⁿʰ⁺ˢ:min=-8.25554e-06, max=8.72924e-06, mean=-1.95156e-24, absmean=5.7963e-07, std=8.40508e-07
# │ pⁿ:   min=-0.00583394, max=0.00476905, mean=-0.000313466, absmean=0.000351484, std=0.000621713
# │ ρⁿ:   min=1027, max=1027, mean=1027, absmean=1027, std=3.06486e-07
# │ δρ:   min=-3.49819e-07, max=5.76067e-06, mean=1.60613e-08, absmean=2.3957e-08, std=3.06486e-07
# │ Gᵘⁿ⁺ʰ: min=-8.49357e-07, max=8.49444e-07, mean=-2.95831e-26, absmean=8.51187e-09, std=5.17683e-08
# │ Gᵛⁿ⁺ʰ: min=-8.49206e-07, max=8.49943e-07, mean=-2.5411e-27, absmean=8.50767e-09, std=5.17852e-08
# │ Gʷⁿ⁺ʰ: min=-8.70688e-12, max=1.31488e-11, mean=1.01804e-30, absmean=2.66127e-14, std=3.60132e-13
# │ Gᵀⁿ⁺ʰ: min=-9.86229e-06, max=3.92731e-06, mean=-2.60131e-08, absmean=1.12858e-07, std=6.86022e-07
# │ Gˢⁿ⁺ʰ: min=-4.06191e-07, max=4.86189e-07, mean=1.23349e-26, absmean=1.07663e-08, std=5.58514e-08
# │ ∇⋅u1:  min=-1.21772e-07, max=1.22428e-07, mean=1.19114e-26, absmean=1.42218e-09, std=7.85794e-09
# │ ∇⋅u2:  min=-1.50433e-21, max=1.61614e-21, mean=-5.71146e-26, absmean=6.34613e-24, std=3.94705e-23
# │ wSurf: min=-0.000107248, max=0.000106731, mean=-1.04354e-22, absmean=2.69299e-06, std=1.25394e-05
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:313
# ┌ Info: Temperature source term:
# │ div_flux:  mean=-3.3822e-24, absmean=4.02477e-07, std=2.2238e-06
# │ lap_diff:  mean=-8.02365e-29, absmean=1.03013e-10, std=5.13127e-10
# │ Fᵀ[:,:,1]: mean=-2.60131e-06, absmean=2.60131e-06, std=4.14284e-06
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:215
# ┌ Info: Salinity source term:
# │ div_flux:  mean=-4.15681e-25, absmean=4.97763e-08, std=2.75028e-07
# │ lap_diff:  mean=9.0964e-29, absmean=9.57758e-12, std=4.45725e-11
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:225
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-8.1977e-16, max=7.20164e-16, mean=7.25999e-36, absmean=1.19294e-18, std=9.59821e-18
# │ Gwn_u_dot_w: min=-1.07582e-11, max=1.6795e-11, mean=6.51346e-25, absmean=7.88189e-14, std=5.27352e-13
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:245
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-3.33595e-07, max=3.35515e-07, mean=1.47106e-26, absmean=4.12528e-09, std=2.26848e-08
# │ RHS_rec: min=-3.33595e-07, max=3.35515e-07, mean=8.54312e-27, absmean=4.12528e-09, std=2.26848e-08
# │ error:   min=-2.11758e-22, max=2.11758e-22, mean=-1.68914e-27, absmean=5.70878e-24, std=9.50847e-24
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:273
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-1.11066e-08, max=1.12101e-08, mean=-9.77019e-18, absmean=2.85019e-10, std=1.52391e-09
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:292
# ┌ Info: Time: 5
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -5.36073e-05 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-2.95941e-06, max=2.95998e-06, mean=-4.80381e-26, absmean=2.96576e-08, std=1.80333e-07
# │ vⁿ:   min=-2.95882e-06, max=2.96139e-06, mean=3.55754e-26, absmean=2.96427e-08, std=1.8039e-07
# │ wⁿ:   min=-9.39337e-08, max=1.21428e-08, mean=-2.61486e-10, absmean=5.45845e-10, std=5.16717e-09
# │ Tⁿ:   min=283, max=283, mean=283, absmean=283, std=4.29469e-06
# │ Sⁿ:   min=35, max=35, mean=35, absmean=35, std=4.00037e-07
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-0.0167805, max=0.0155061, mean=-0.000400591, absmean=0.00055657, std=0.00137799
# │ pⁿʰ⁺ˢ:min=-2.17569e-05, max=2.22393e-05, mean=5.42101e-24, absmean=8.52713e-07, std=1.82317e-06
# │ pⁿ:   min=-0.0167583, max=0.0154843, mean=-0.000400591, absmean=0.000556335, std=0.00137617
# │ ρⁿ:   min=1027, max=1027, mean=1027, absmean=1027, std=4.09919e-07
# │ δρ:   min=-1.02339e-06, max=7.45215e-06, mean=2.05228e-08, absmean=4.33132e-08, std=4.09919e-07
# │ Gᵘⁿ⁺ʰ: min=-2.20014e-06, max=2.20063e-06, mean=-5.1236e-26, absmean=2.21397e-08, std=1.34859e-07
# │ Gᵛⁿ⁺ʰ: min=-2.19969e-06, max=2.20158e-06, mean=-2.37169e-26, absmean=2.21284e-08, std=1.34901e-07
# │ Gʷⁿ⁺ʰ: min=-1.34117e-11, max=2.11241e-11, mean=1.04216e-24, absmean=1.14468e-13, std=7.0119e-13
# │ Gᵀⁿ⁺ʰ: min=-5.69326e-05, max=5.66214e-05, mean=-2.60131e-08, absmean=6.95286e-07, std=3.74232e-06
# │ Gˢⁿ⁺ʰ: min=-7.04113e-06, max=7.00265e-06, mean=-3.19543e-25, absmean=8.28088e-08, std=4.58053e-07
# │ ∇⋅u1:  min=-4.55454e-07, max=4.58033e-07, mean=1.72914e-26, absmean=5.52571e-09, std=3.04732e-08
# │ ∇⋅u2:  min=-6.09144e-21, max=5.72764e-21, mean=-7.85277e-26, absmean=2.46074e-23, std=1.55838e-22
# │ wSurf: min=-0.000434608, max=0.000432246, mean=-9.48677e-23, absmean=1.09222e-05, std=5.11436e-05
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:313
# ┌ Info: Temperature source term:
# │ div_flux:  mean=-1.03457e-23, absmean=1.56378e-06, std=8.62392e-06
# │ lap_diff:  mean=-1.44521e-27, absmean=4.07655e-10, std=2.12471e-09
# │ Fᵀ[:,:,1]: mean=-2.60131e-06, absmean=2.60131e-06, std=4.14284e-06
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:215
# ┌ Info: Salinity source term:
# │ div_flux:  mean=-1.04905e-24, absmean=1.934e-07, std=1.06656e-06
# │ lap_diff:  mean=-1.63565e-28, absmean=4.66011e-11, std=2.56593e-10
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:225
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-1.93074e-15, max=1.62605e-15, mean=1.10046e-34, absmean=1.49609e-17, std=1.03182e-16
# │ Gwn_u_dot_w: min=-1.67508e-11, max=2.44403e-11, mean=9.77008e-24, absmean=2.23042e-13, std=1.10448e-12
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:245
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-2.0322e-06, max=2.02675e-06, mean=1.17704e-25, absmean=1.42184e-08, std=9.32681e-08
# │ RHS_rec: min=-2.0322e-06, max=2.02675e-06, mean=7.04923e-26, absmean=1.42184e-08, std=9.32681e-08
# │ error:   min=-1.05879e-21, max=1.05879e-21, mean=1.54484e-26, absmean=2.08657e-23, std=3.79267e-23
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:273
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-2.15537e-08, max=2.15164e-08, mean=-6.29634e-18, absmean=6.10552e-10, std=2.7046e-09
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:292
# ┌ Info: Time: 6
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -6.44455e-05 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-8.79235e-06, max=8.7995e-06, mean=7.34139e-26, absmean=5.71968e-08, std=3.64377e-07
# │ vⁿ:   min=-8.79507e-06, max=8.78398e-06, mean=-7.7927e-26, absmean=5.71919e-08, std=3.6443e-07
# │ wⁿ:   min=-1.36302e-07, max=7.26962e-08, mean=-3.76293e-10, absmean=1.22551e-09, std=8.42098e-09
# │ Tⁿ:   min=283, max=283, mean=283, absmean=283, std=1.60058e-05
# │ Sⁿ:   min=35, max=35, mean=35, absmean=35, std=1.93467e-06
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-0.0705351, max=0.0685153, mean=-0.000487758, absmean=0.000899585, std=0.00337286
# │ pⁿʰ⁺ˢ:min=-0.000116716, max=0.000118071, mean=-5.85469e-24, absmean=1.49079e-06, std=5.75349e-06
# │ pⁿ:   min=-0.070417, max=0.0683986, mean=-0.000487758, absmean=0.000898825, std=0.00336715
# │ ρⁿ:   min=1027, max=1027, mean=1027, absmean=1027, std=7.36579e-07
# │ δρ:   min=-8.8469e-06, max=9.21974e-06, mean=2.49843e-08, absmean=1.26588e-07, std=7.36579e-07
# │ Gᵘⁿ⁺ʰ: min=-1.17623e-05, max=1.17693e-05, mean=1.45319e-26, absmean=7.71003e-08, std=5.11054e-07
# │ Gᵛⁿ⁺ʰ: min=-1.17679e-05, max=1.17542e-05, mean=2.5411e-27, absmean=7.7063e-08, std=5.11162e-07
# │ Gʷⁿ⁺ʰ: min=-2.21239e-11, max=2.90274e-11, mean=1.52413e-23, absmean=3.09576e-13, std=1.48102e-12
# │ Gᵀⁿ⁺ʰ: min=-0.000186551, max=0.000185495, mean=-2.60131e-08, absmean=2.28928e-06, std=1.248e-05
# │ Gˢⁿ⁺ʰ: min=-2.30717e-05, max=2.29411e-05, mean=-1.45901e-24, absmean=2.79957e-07, std=1.54191e-06
# │ ∇⋅u1:  min=-1.57733e-06, max=1.57351e-06, mean=-3.77194e-27, absmean=1.04956e-08, std=6.71756e-08
# │ ∇⋅u2:  min=-1.02593e-20, max=1.12215e-20, mean=-8.18535e-27, absmean=5.10322e-23, std=2.968e-22
# │ wSurf: min=-0.000718947, max=0.000720324, mean=1.0842e-22, absmean=1.8289e-05, std=7.94825e-05
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:313
# ┌ Info: Temperature source term:
# │ div_flux:  mean=8.47372e-24, absmean=2.97024e-06, std=1.90107e-05
# │ lap_diff:  mean=-2.20878e-27, absmean=1.84014e-09, std=9.90573e-09
# │ Fᵀ[:,:,1]: mean=-2.60131e-06, absmean=2.60131e-06, std=4.14284e-06
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:215
# ┌ Info: Salinity source term:
# │ div_flux:  mean=7.17437e-25, absmean=3.67345e-07, std=2.35115e-06
# │ lap_diff:  mean=3.63003e-28, absmean=2.23127e-10, std=1.22314e-09
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:225
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-1.79989e-14, max=1.70041e-14, mean=2.45572e-33, absmean=6.03867e-17, std=5.50614e-16
# │ Gwn_u_dot_w: min=-5.77374e-11, max=5.78953e-11, mean=3.47222e-24, absmean=6.05739e-13, std=3.06783e-12
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:245
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-8.94881e-06, max=8.92338e-06, mean=7.4749e-25, absmean=6.75467e-08, std=4.32081e-07
# │ RHS_rec: min=-8.94881e-06, max=8.92338e-06, mean=4.72535e-25, absmean=6.75467e-08, std=4.32081e-07
# │ error:   min=-5.0822e-21, max=4.23516e-21, mean=-1.11416e-25, absmean=9.84451e-23, std=1.76059e-22
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:273
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-1.96966e-07, max=1.96025e-07, mean=-7.49043e-18, absmean=4.94655e-09, std=2.30251e-08
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:292
# ┌ Info: Time: 7
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -7.59422e-05 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-6.16161e-05, max=6.1647e-05, mean=-1.62543e-24, absmean=4.16095e-07, std=2.73595e-06
# │ vⁿ:   min=-6.16457e-05, max=6.15762e-05, mean=-8.80914e-26, absmean=4.15854e-07, std=2.73656e-06
# │ wⁿ:   min=-4.60501e-07, max=4.58032e-07, mean=-5.08674e-10, absmean=5.78668e-09, std=3.10224e-08
# │ Tⁿ:   min=282.999, max=283.001, mean=283, absmean=283, std=2.31388e-05
# │ Sⁿ:   min=34.9999, max=35.0001, mean=35, absmean=35, std=2.81904e-06
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-0.367983, max=0.364018, mean=-0.000574976, absmean=0.00320481, std=0.0186465
# │ pⁿʰ⁺ˢ:min=-0.000525994, max=0.000529777, mean=2.1684e-25, absmean=4.80279e-06, std=2.71523e-05
# │ pⁿ:   min=-0.367453, max=0.363492, mean=-0.000574976, absmean=0.00320087, std=0.0186193
# │ ρⁿ:   min=1027, max=1027, mean=1027, absmean=1027, std=2.74514e-06
# │ δρ:   min=-4.06609e-05, max=4.08874e-05, mean=2.94458e-08, absmean=5.14477e-07, std=2.74514e-06
# │ Gᵘⁿ⁺ʰ: min=-5.28751e-05, max=5.28988e-05, mean=-1.16659e-24, absmean=3.68576e-07, std=2.39455e-06
# │ Gᵛⁿ⁺ʰ: min=-5.2902e-05, max=5.28435e-05, mean=-4.23516e-26, absmean=3.68348e-07, std=2.39511e-06
# │ Gʷⁿ⁺ʰ: min=-9.70531e-11, max=9.73241e-11, mean=-3.06495e-25, absmean=9.76916e-13, std=5.04133e-12
# │ Gᵀⁿ⁺ʰ: min=-0.000790057, max=0.000792065, mean=-2.60131e-08, absmean=5.32717e-06, std=3.46774e-05
# │ Gˢⁿ⁺ʰ: min=-9.77102e-05, max=9.79586e-05, mean=9.0209e-26, absmean=6.5568e-07, std=4.28811e-06
# │ ∇⋅u1:  min=-1.05368e-05, max=1.05075e-05, mean=7.76299e-25, absmean=7.65442e-08, std=4.96286e-07
# │ ∇⋅u2:  min=-8.18573e-20, max=8.97042e-20, mean=5.40312e-24, absmean=3.86668e-22, std=2.35907e-21
# │ wSurf: min=-0.00633973, max=0.00635684, mean=1.37477e-20, absmean=0.000151973, std=0.0006976
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:313
# ┌ Info: Temperature source term:
# │ div_flux:  mean=-2.102e-22, absmean=2.1662e-05, std=0.000140449
# │ lap_diff:  mean=3.30086e-27, absmean=2.7049e-09, std=1.60058e-08
# │ Fᵀ[:,:,1]: mean=-2.60131e-06, absmean=2.60131e-06, std=4.14284e-06
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:215
# ┌ Info: Salinity source term:
# │ div_flux:  mean=-2.47933e-23, absmean=2.67905e-06, std=1.737e-05
# │ lap_diff:  mean=-3.33586e-28, absmean=3.29454e-10, std=1.97779e-09
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:225
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-9.10576e-13, max=8.17746e-13, mean=1.04155e-31, absmean=3.46705e-15, std=3.19192e-14
# │ Gwn_u_dot_w: min=-3.55764e-10, max=3.56831e-10, mean=5.86107e-24, absmean=3.49812e-12, std=1.89257e-11
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:245
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-1.273e-05, max=1.275e-05, mean=3.21495e-25, absmean=6.57157e-08, std=4.26647e-07
# │ RHS_rec: min=-1.273e-05, max=1.275e-05, mean=2.44538e-25, absmean=6.57157e-08, std=4.26647e-07
# │ error:   min=-6.77626e-21, max=5.0822e-21, mean=-1.83618e-26, absmean=9.82307e-23, std=1.88253e-22
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:273
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-2.52871e-07, max=2.50819e-07, mean=-1.95359e-18, absmean=7.48107e-09, std=3.20795e-08
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:292
# ┌ Info: Time: 8
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -8.82023e-05 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-3.59484e-05, max=3.59875e-05, mean=-1.24662e-24, absmean=4.0456e-07, std=2.09933e-06
# │ vⁿ:   min=-3.60682e-05, max=3.59923e-05, mean=1.21973e-25, absmean=4.04352e-07, std=2.10023e-06
# │ wⁿ:   min=-4.36942e-07, max=4.35717e-07, mean=-6.57104e-10, absmean=7.12037e-09, std=3.15147e-08
# │ Tⁿ:   min=282.995, max=283.005, mean=283, absmean=283, std=0.000233521
# │ Sⁿ:   min=34.9994, max=35.0006, mean=35, absmean=35, std=2.88751e-05
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-0.294044, max=0.291876, mean=-0.000662254, absmean=0.00301264, std=0.0135929
# │ pⁿʰ⁺ˢ:min=-0.000666582, max=0.000666677, mean=1.30104e-24, absmean=4.77424e-06, std=2.46992e-05
# │ pⁿ:   min=-0.293377, max=0.29121, mean=-0.000662254, absmean=0.00300914, std=0.0135707
# │ ρⁿ:   min=1027, max=1027, mean=1027, absmean=1027, std=3.96851e-06
# │ δρ:   min=-9.50394e-05, max=9.4841e-05, mean=3.39072e-08, absmean=7.15071e-07, std=3.96851e-06
# │ Gᵘⁿ⁺ʰ: min=-6.70678e-05, max=6.67571e-05, mean=-6.65503e-25, absmean=3.53727e-07, std=2.27078e-06
# │ Gᵛⁿ⁺ʰ: min=-6.68802e-05, max=6.70343e-05, mean=3.37966e-25, absmean=3.53637e-07, std=2.27088e-06
# │ Gʷⁿ⁺ʰ: min=-5.34581e-10, max=5.36208e-10, mean=7.29439e-24, absmean=5.26174e-12, std=2.85872e-11
# │ Gᵀⁿ⁺ʰ: min=-0.00448986, max=0.00450248, mean=-2.60131e-08, absmean=3.31245e-05, std=0.000213685
# │ Gˢⁿ⁺ʰ: min=-0.000555284, max=0.000556843, mean=-4.79772e-23, absmean=4.09353e-06, std=2.64274e-05
# │ ∇⋅u1:  min=-4.40458e-06, max=4.39146e-06, mean=2.63904e-25, absmean=6.96947e-08, std=3.44036e-07
# │ ∇⋅u2:  min=-5.48301e-20, max=5.37764e-20, mean=7.91051e-26, absmean=2.87578e-22, std=1.58078e-21
# │ wSurf: min=-0.00422601, max=0.0042532, mean=-6.50521e-22, absmean=0.000124768, std=0.000511181
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:313
# ┌ Info: Temperature source term:
# │ div_flux:  mean=-5.63819e-23, absmean=1.97236e-05, std=9.73622e-05
# │ lap_diff:  mean=-3.61064e-26, absmean=2.54031e-08, std=1.60774e-07
# │ Fᵀ[:,:,1]: mean=-2.60131e-06, absmean=2.60131e-06, std=4.14284e-06
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:215
# ┌ Info: Salinity source term:
# │ div_flux:  mean=-5.55908e-24, absmean=2.43931e-06, std=1.20413e-05
# │ lap_diff:  mean=-6.81571e-27, absmean=3.13604e-09, std=1.98834e-08
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:225
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-3.52099e-13, max=2.66497e-13, mean=7.77501e-33, absmean=2.80946e-15, std=1.88378e-14
# │ Gwn_u_dot_w: min=-3.91619e-10, max=3.9122e-10, mean=2.22532e-23, absmean=3.8e-12, std=1.71731e-11
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:245
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-0.000131272, max=0.000131568, mean=2.68401e-24, absmean=7.08099e-07, std=5.03415e-06
# │ RHS_rec: min=-0.000131272, max=0.000131568, mean=4.04034e-24, absmean=7.08099e-07, std=5.03415e-06
# │ error:   min=-8.13152e-20, max=8.13152e-20, mean=-3.86204e-25, absmean=1.10875e-21, std=2.10593e-21
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:273
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-1.18466e-06, max=1.18699e-06, mean=-4.2324e-18, absmean=2.99835e-08, std=1.30304e-07
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:292
# ┌ Info: Time: 9
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -0.00010133 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-0.000742434, max=0.000740027, mean=-1.92591e-23, absmean=3.59491e-06, std=2.62615e-05
# │ vⁿ:   min=-0.000740988, max=0.000742024, mean=-6.09864e-24, absmean=3.59557e-06, std=2.62638e-05
# │ wⁿ:   min=-8.5745e-06, max=8.59696e-06, mean=-8.19808e-10, absmean=5.85026e-08, std=3.82481e-07
# │ Tⁿ:   min=282.997, max=283.003, mean=283, absmean=283, std=0.000263341
# │ Sⁿ:   min=34.9996, max=35.0004, mean=35, absmean=35, std=3.25622e-05
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-4.84086, max=4.8508, mean=-0.0007496, absmean=0.0258425, std=0.188872
# │ pⁿʰ⁺ˢ:min=-0.00735482, max=0.00733666, mean=2.2855e-22, absmean=4.02007e-05, std=0.000290711
# │ pⁿ:   min=-4.83352, max=4.84345, mean=-0.0007496, absmean=0.0258034, std=0.188581
# │ ρⁿ:   min=1027, max=1027, mean=1027, absmean=1027, std=4.0051e-05
# │ δρ:   min=-0.000867254, max=0.000864893, mean=3.83687e-08, absmean=6.15602e-06, std=4.0051e-05
# │ Gᵘⁿ⁺ʰ: min=-0.000737794, max=0.00073558, mean=-1.54386e-24, absmean=3.74249e-06, std=2.69273e-05
# │ Gᵛⁿ⁺ʰ: min=-0.000736463, max=0.000737379, mean=-8.20775e-24, absmean=3.7427e-06, std=2.69303e-05
# │ Gʷⁿ⁺ʰ: min=-8.40677e-10, max=8.3941e-10, mean=3.20885e-23, absmean=5.99679e-12, std=3.00618e-11
# │ Gᵀⁿ⁺ʰ: min=-0.00284355, max=0.00284552, mean=-2.60131e-08, absmean=2.64026e-05, std=0.000131586
# │ Gˢⁿ⁺ʰ: min=-0.000351676, max=0.000351919, mean=-1.20067e-23, absmean=3.26221e-06, std=1.62736e-05
# │ ∇⋅u1:  min=-0.000133807, max=0.000134094, mean=4.61477e-24, absmean=6.82539e-07, std=4.93725e-06
# │ ∇⋅u2:  min=-6.99636e-19, max=8.09899e-19, mean=2.40171e-23, absmean=3.62143e-21, std=2.02841e-20
# │ wSurf: min=-0.0553004, max=0.0551897, mean=5.22802e-20, absmean=0.00134522, std=0.00583341
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:313
# ┌ Info: Temperature source term:
# │ div_flux:  mean=-1.43011e-21, absmean=0.000193159, std=0.00139724
# │ lap_diff:  mean=-1.41911e-26, absmean=3.02081e-08, std=1.63489e-07
# │ Fᵀ[:,:,1]: mean=-2.60131e-06, absmean=2.60131e-06, std=4.14284e-06
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:215
# ┌ Info: Salinity source term:
# │ div_flux:  mean=-1.75025e-22, absmean=2.38889e-05, std=0.000172804
# │ lap_diff:  mean=-6.34479e-27, absmean=3.72972e-09, std=2.02191e-08
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:225
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-1.42907e-10, max=1.20462e-10, mean=4.04705e-30, absmean=3.05213e-13, std=3.31861e-12
# │ Gwn_u_dot_w: min=-7.01761e-09, max=7.00164e-09, mean=-1.50468e-22, absmean=4.15593e-11, std=2.68125e-10
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:245
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-0.000107466, max=0.000107627, mean=1.33119e-24, absmean=9.08361e-07, std=5.77313e-06
# │ RHS_rec: min=-0.000107466, max=0.000107627, mean=-1.60139e-24, absmean=9.08361e-07, std=5.77313e-06
# │ error:   min=-6.77626e-20, max=6.77626e-20, mean=-5.60124e-25, absmean=1.30085e-21, std=2.35162e-21
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:273
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-4.26208e-06, max=4.30487e-06, mean=-1.66057e-17, absmean=1.05089e-07, std=4.75383e-07
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:292
# ┌ Info: Time: 10
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -0.000115428 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-0.0013589, max=0.00136055, mean=8.66758e-24, absmean=8.30904e-06, std=5.6947e-05
# │ vⁿ:   min=-0.00135479, max=0.00135854, mean=5.28549e-25, absmean=8.30636e-06, std=5.69568e-05
# │ wⁿ:   min=-1.30543e-05, max=1.30804e-05, mean=-9.94772e-10, absmean=1.30511e-07, std=7.76091e-07
# │ Tⁿ:   min=282.942, max=283.058, mean=283, absmean=283, std=0.0020737
# │ Sⁿ:   min=34.9928, max=35.0072, mean=35, absmean=35, std=0.000256463
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-6.00878, max=6.01897, mean=-0.000837021, absmean=0.0454676, std=0.299585
# │ pⁿʰ⁺ˢ:min=-0.00670115, max=0.00667961, mean=2.29634e-22, absmean=5.75807e-05, std=0.000362596
# │ pⁿ:   min=-6.0021, max=6.01226, mean=-0.000837021, absmean=0.0454115, std=0.299224
# │ ρⁿ:   min=1027, max=1027, mean=1027, absmean=1027, std=4.51654e-05
# │ δρ:   min=-0.000592319, max=0.000590356, mean=4.28302e-08, absmean=8.37168e-06, std=4.51654e-05
# │ Gᵘⁿ⁺ʰ: min=-0.000668998, max=0.000668964, mean=3.96783e-24, absmean=5.01409e-06, std=3.20545e-05
# │ Gᵛⁿ⁺ʰ: min=-0.000666303, max=0.00066805, mean=-1.4674e-23, absmean=5.01122e-06, std=3.20625e-05
# │ Gʷⁿ⁺ʰ: min=-1.09932e-08, max=1.09679e-08, mean=-2.54101e-22, absmean=6.60385e-11, std=4.2479e-10
# │ Gᵀⁿ⁺ʰ: min=-0.0603365, max=0.0602048, mean=-2.60131e-08, absmean=0.000312836, std=0.00225027
# │ Gˢⁿ⁺ʰ: min=-0.00746211, max=0.00744582, mean=-2.47608e-22, absmean=3.86868e-05, std=0.000278302
# │ ∇⋅u1:  min=-0.000231574, max=0.000234004, mean=1.02568e-23, absmean=1.54523e-06, std=1.04781e-05
# │ ∇⋅u2:  min=-1.72822e-18, max=1.72432e-18, mean=-4.53839e-23, absmean=8.14136e-21, std=4.92455e-20
# │ wSurf: min=-0.127719, max=0.127582, mean=-8.84709e-20, absmean=0.00306966, std=0.0138523
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:313
# ┌ Info: Temperature source term:
# │ div_flux:  mean=-2.13382e-21, absmean=0.000437301, std=0.0029653
# │ lap_diff:  mean=5.92716e-25, absmean=2.11517e-07, std=1.49987e-06
# │ Fᵀ[:,:,1]: mean=-2.60131e-06, absmean=2.60131e-06, std=4.14284e-06
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:215
# ┌ Info: Salinity source term:
# │ div_flux:  mean=-2.8038e-22, absmean=5.40832e-05, std=0.000366733
# │ lap_diff:  mean=7.11182e-26, absmean=2.61525e-08, std=1.85497e-07
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:225
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-5.45316e-10, max=4.80461e-10, mean=2.0421e-29, absmean=1.72708e-12, std=1.69513e-11
# │ Gwn_u_dot_w: min=-9.85684e-09, max=9.79602e-09, mean=1.16075e-21, absmean=8.66604e-11, std=5.12877e-10
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:245
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-0.00110992, max=0.00110674, mean=-8.68884e-25, absmean=4.46585e-06, std=3.46869e-05
# │ RHS_rec: min=-0.00110992, max=0.00110674, mean=1.16176e-24, absmean=4.46585e-06, std=3.46869e-05
# │ error:   min=-5.42101e-19, max=4.33681e-19, mean=-9.77618e-25, absmean=7.50027e-21, std=1.43269e-20
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:273
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-3.22085e-06, max=3.2362e-06, mean=3.46304e-16, absmean=9.59567e-08, std=3.62219e-07
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:292
# ┌ Info: Time: 11
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -0.000130598 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-0.00463601, max=0.00466384, mean=-4.17087e-23, absmean=1.719e-05, std=0.000133574
# │ vⁿ:   min=-0.0046612, max=0.004641, mean=5.42643e-23, absmean=1.71844e-05, std=0.000133576
# │ wⁿ:   min=-8.07094e-05, max=8.05632e-05, mean=-1.17974e-09, absmean=3.78788e-07, std=2.71299e-06
# │ Tⁿ:   min=282.86, max=283.14, mean=283, absmean=283, std=0.00592704
# │ Sⁿ:   min=34.9826, max=35.0173, mean=35, absmean=35, std=0.000733025
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-36.443, max=36.373, mean=-0.000924523, absmean=0.143131, std=1.13524
# │ pⁿʰ⁺ˢ:min=-0.0595788, max=0.0596952, mean=-3.08998e-22, absmean=0.000240091, std=0.00190719
# │ pⁿ:   min=-36.3833, max=36.3135, mean=-0.000924523, absmean=0.142893, std=1.13333
# │ ρⁿ:   min=1026.99, max=1027.01, mean=1027, absmean=1027, std=0.000355657
# │ δρ:   min=-0.00994281, max=0.00996318, mean=4.72917e-08, absmean=4.87858e-05, std=0.000355657
# │ Gᵘⁿ⁺ʰ: min=-0.00596268, max=0.00600072, mean=-1.4581e-23, absmean=2.3113e-05, std=0.000181574
# │ Gᵛⁿ⁺ʰ: min=-0.00599733, max=0.00596976, mean=-1.88499e-23, absmean=2.31068e-05, std=0.00018158
# │ Gʷⁿ⁺ʰ: min=-1.19696e-08, max=1.19542e-08, mean=1.94747e-21, absmean=1.15187e-10, std=6.67941e-10
# │ Gᵀⁿ⁺ʰ: min=-0.0835733, max=0.0820688, mean=-2.60131e-08, absmean=0.000588997, std=0.00392904
# │ Gˢⁿ⁺ʰ: min=-0.0103359, max=0.0101499, mean=-2.76275e-22, absmean=7.28411e-05, std=0.000485923
# │ ∇⋅u1:  min=-0.000882238, max=0.000879926, mean=2.41495e-23, absmean=3.31259e-06, std=2.56589e-05
# │ ∇⋅u2:  min=-3.40526e-18, max=3.2409e-18, mean=-1.9541e-22, absmean=1.74781e-20, std=8.715e-20
# │ wSurf: min=-0.219371, max=0.219854, mean=-3.13985e-19, absmean=0.00590401, std=0.0231449
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:313
# ┌ Info: Temperature source term:
# │ div_flux:  mean=-8.06139e-21, absmean=0.000937464, std=0.00726146
# │ lap_diff:  mean=-1.41231e-25, absmean=6.2485e-07, std=4.17206e-06
# │ Fᵀ[:,:,1]: mean=-2.60131e-06, absmean=2.60131e-06, std=4.14284e-06
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:215
# ┌ Info: Salinity source term:
# │ div_flux:  mean=-3.39315e-22, absmean=0.000115941, std=0.000898061
# │ lap_diff:  mean=6.51529e-26, absmean=7.72709e-08, std=5.1598e-07
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:225
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-5.87171e-09, max=3.93646e-09, mean=1.46308e-29, absmean=6.86272e-12, std=8.93272e-11
# │ Gwn_u_dot_w: min=-6.82625e-08, max=6.8455e-08, mean=2.09723e-20, absmean=2.79706e-10, std=2.01044e-09
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:245
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-0.00289023, max=0.00288628, mean=-4.21664e-23, absmean=1.39602e-05, std=0.000103016
# │ RHS_rec: min=-0.00289023, max=0.00288628, mean=-1.25059e-23, absmean=1.39602e-05, std=0.000103016
# │ error:   min=-1.30104e-18, max=1.30104e-18, mean=5.2079e-24, absmean=2.24404e-20, std=4.25254e-20
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:273
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-2.16232e-05, max=2.16298e-05, mean=-1.52371e-15, absmean=5.58425e-07, std=2.30517e-06
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:292
# ┌ Info: Time: 12
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -0.00014694 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-0.0205035, max=0.0206408, mean=-8.87845e-23, absmean=8.78427e-05, std=0.00067049
# │ vⁿ:   min=-0.0206071, max=0.0205142, mean=4.88081e-22, absmean=8.78094e-05, std=0.000670523
# │ wⁿ:   min=-0.000306288, max=0.000306262, mean=-1.37221e-09, absmean=1.70189e-06, std=1.20874e-05
# │ Tⁿ:   min=282.702, max=283.299, mean=283, absmean=283, std=0.00833626
# │ Sⁿ:   min=34.9631, max=35.037, mean=35, absmean=35, std=0.00103099
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-116.34, max=116.349, mean=-0.00101212, absmean=0.538692, std=4.14858
# │ pⁿʰ⁺ˢ:min=-0.159183, max=0.159123, mean=5.18249e-22, absmean=0.000761389, std=0.00581843
# │ pⁿ:   min=-116.181, max=116.19, mean=-0.00101212, absmean=0.537932, std=4.14276
# │ ρⁿ:   min=1026.98, max=1027.02, mean=1027, absmean=1027, std=0.00101654
# │ δρ:   min=-0.0240183, max=0.0240756, mean=5.17532e-08, absmean=0.000146786, std=0.00101654
# │ Gᵘⁿ⁺ʰ: min=-0.0159351, max=0.0159925, mean=-3.3055e-22, absmean=7.30769e-05, std=0.000545778
# │ Gᵛⁿ⁺ʰ: min=-0.0159751, max=0.0159584, mean=1.828e-22, absmean=7.30713e-05, std=0.000545815
# │ Gʷⁿ⁺ʰ: min=-1.14962e-07, max=1.15294e-07, mean=3.28592e-20, absmean=4.79663e-10, std=3.46039e-09
# │ Gᵀⁿ⁺ʰ: min=-0.437704, max=0.438861, mean=-2.60131e-08, absmean=0.00167493, std=0.0130998
# │ Gˢⁿ⁺ʰ: min=-0.054133, max=0.0542761, mean=-8.93236e-22, absmean=0.000207144, std=0.00162012
# │ ∇⋅u1:  min=-0.00378095, max=0.00376897, mean=3.48326e-23, absmean=1.68564e-05, std=0.000127246
# │ ∇⋅u2:  min=-1.39888e-17, max=1.37598e-17, mean=2.22704e-22, absmean=9.41421e-20, std=5.26852e-19
# │ wSurf: min=-1.35608, max=1.36088, mean=4.33681e-19, absmean=0.0335317, std=0.141434
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:313
# ┌ Info: Temperature source term:
# │ div_flux:  mean=-1.95711e-21, absmean=0.00477035, std=0.0360108
# │ lap_diff:  mean=1.14612e-24, absmean=8.49018e-07, std=6.20051e-06
# │ Fᵀ[:,:,1]: mean=-2.60131e-06, absmean=2.60131e-06, std=4.14284e-06
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:215
# ┌ Info: Salinity source term:
# │ div_flux:  mean=-1.59971e-21, absmean=0.000589973, std=0.00445363
# │ lap_diff:  mean=1.36357e-25, absmean=1.04994e-07, std=7.66847e-07
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:225
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-1.26784e-07, max=9.76667e-08, mean=1.30074e-27, absmean=2.08623e-10, std=2.4418e-09
# │ Gwn_u_dot_w: min=-2.53313e-07, max=2.53835e-07, mean=-4.66488e-19, absmean=1.26072e-09, std=8.70148e-09
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:245
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-0.00377112, max=0.00376145, mean=4.83014e-23, absmean=1.29803e-05, std=9.47577e-05
# │ RHS_rec: min=-0.00377112, max=0.00376145, mean=5.26132e-23, absmean=1.29803e-05, std=9.47577e-05
# │ error:   min=-1.73472e-18, max=1.73472e-18, mean=6.86507e-24, absmean=2.13196e-20, std=4.18812e-20
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:273
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-5.52418e-05, max=5.51017e-05, mean=-8.72757e-17, absmean=1.35372e-06, std=5.97271e-06
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:292
# ┌ Info: Time: 13
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -0.000164552 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-0.0106968, max=0.0105806, mean=1.28594e-22, absmean=8.46217e-05, std=0.000511632
# │ vⁿ:   min=-0.0107023, max=0.0107218, mean=3.64563e-24, absmean=8.4611e-05, std=0.000511777
# │ wⁿ:   min=-0.000199714, max=0.000201713, mean=-1.56936e-09, absmean=1.73477e-06, std=9.36022e-06
# │ Tⁿ:   min=281.146, max=284.861, mean=283, absmean=283, std=0.060619
# │ Sⁿ:   min=34.7707, max=35.2301, mean=35, absmean=35, std=0.00749705
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-85.2663, max=85.8586, mean=-0.00109975, absmean=0.46036, std=2.78657
# │ pⁿʰ⁺ˢ:min=-0.191127, max=0.190798, mean=-3.97273e-21, absmean=0.000736808, std=0.00517837
# │ pⁿ:   min=-85.0922, max=85.684, mean=-0.00109975, absmean=0.459686, std=2.78199
# │ ρⁿ:   min=1026.95, max=1027.05, mean=1027, absmean=1027, std=0.00142974
# │ δρ:   min=-0.0512632, max=0.0511516, mean=5.62146e-08, absmean=0.000199977, std=0.00142974
# │ Gᵘⁿ⁺ʰ: min=-0.0192438, max=0.019148, mean=1.32868e-23, absmean=6.84329e-05, std=0.000493442
# │ Gᵛⁿ⁺ʰ: min=-0.0192377, max=0.0193043, mean=-2.2865e-22, absmean=6.84447e-05, std=0.000493492
# │ Gʷⁿ⁺ʰ: min=-3.64507e-07, max=3.65064e-07, mean=-7.58964e-19, absmean=1.86326e-09, std=1.27585e-08
# │ Gᵀⁿ⁺ʰ: min=-1.55762, max=1.56187, mean=-2.60131e-08, absmean=0.00713181, std=0.0534483
# │ Gˢⁿ⁺ʰ: min=-0.192639, max=0.193164, mean=9.03888e-22, absmean=0.000882023, std=0.00661022
# │ ∇⋅u1:  min=-0.00159801, max=0.00158722, mean=2.1939e-23, absmean=1.53123e-05, std=9.19351e-05
# ...
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:273
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-0.000539808, max=0.000536468, mean=1.29329e-13, absmean=1.36345e-05, std=5.7152e-05
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:292
# ┌ Info: Time: 16
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -0.000225927 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-0.424246, max=0.425631, mean=1.03525e-21, absmean=0.0013257, std=0.00992045
# │ vⁿ:   min=-0.426966, max=0.425661, mean=2.60322e-21, absmean=0.00132585, std=0.00992167
# │ wⁿ:   min=-0.013647, max=0.0136521, mean=-2.12788e-09, absmean=4.35172e-05, std=0.000336178
# │ Tⁿ:   min=250.445, max=315.535, mean=283, absmean=283, std=1.01743
# │ Sⁿ:   min=30.9737, max=39.0238, mean=35, absmean=35, std=0.125831
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-4195.29, max=4197.24, mean=-0.00134749, absmean=11.4969, std=99.4695
# │ pⁿʰ⁺ˢ:min=-7.26368, max=7.26609, mean=2.74611e-20, absmean=0.0201175, std=0.177986
# │ pⁿ:   min=-4188.03, max=4189.97, mean=-0.00134749, absmean=11.4771, std=99.2928
# │ ρⁿ:   min=1024.96, max=1029.05, mean=1027, absmean=1027, std=0.0538785
# │ δρ:   min=-2.04293, max=2.04628, mean=6.95991e-08, absmean=0.00644764, std=0.0538785
# │ Gᵘⁿ⁺ʰ: min=-0.728005, max=0.731887, mean=-2.74396e-22, absmean=0.0019536, std=0.0172941
# │ Gᵛⁿ⁺ʰ: min=-0.733841, max=0.731075, mean=5.44269e-21, absmean=0.00195418, std=0.0172947
# │ Gʷⁿ⁺ʰ: min=-5.29044e-06, max=5.28653e-06, mean=1.56994e-16, absmean=2.83913e-08, std=1.9736e-07
# │ Gᵀⁿ⁺ʰ: min=-20.6243, max=20.848, mean=-2.60131e-08, absmean=0.0946602, std=0.719987
# │ Gˢⁿ⁺ʰ: min=-2.55071, max=2.57838, mean=1.13035e-22, absmean=0.0117071, std=0.0890444
# │ ∇⋅u1:  min=-0.08379, max=0.0847633, mean=-3.63773e-22, absmean=0.000253328, std=0.00191916
# │ ∇⋅u2:  min=-1.10342e-16, max=1.11407e-16, mean=-1.32752e-20, absmean=9.99559e-19, std=4.48903e-18
# │ wSurf: min=-9.44972, max=9.1867, mean=-2.65787e-17, absmean=0.309965, std=1.07426
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:313
# ┌ Info: Temperature source term:
# │ div_flux:  mean=-1.4301e-19, absmean=0.0716934, std=0.543146
# │ lap_diff:  mean=-1.17734e-22, absmean=9.74788e-05, std=0.000750682
# │ Fᵀ[:,:,1]: mean=-2.60131e-06, absmean=2.60131e-06, std=4.14284e-06
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:215
# ┌ Info: Salinity source term:
# │ div_flux:  mean=1.0141e-20, absmean=0.00886668, std=0.0671735
# │ lap_diff:  mean=-5.19715e-24, absmean=1.20557e-05, std=9.28405e-05
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:225
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-4.4671e-05, max=2.90606e-05, mean=-1.85712e-25, absmean=4.55714e-08, std=5.83787e-07
# │ Gwn_u_dot_w: min=-1.20353e-05, max=1.19662e-05, mean=2.93229e-15, absmean=3.27546e-08, std=2.60008e-07
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:245
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-0.43641, max=0.435796, mean=1.34108e-21, absmean=0.00147036, std=0.0121922
# │ RHS_rec: min=-0.43641, max=0.435796, mean=5.10097e-21, absmean=0.00147036, std=0.0121922
# │ error:   min=-2.22045e-16, max=2.22045e-16, mean=1.35932e-21, absmean=2.66048e-18, std=5.20615e-18
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:273
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-0.000434578, max=0.000438649, mean=1.126e-11, absmean=1.12768e-05, std=4.3977e-05
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:292
# ┌ Info: Time: 17
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -0.000249518 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-2.73101, max=2.74816, mean=-6.68955e-22, absmean=0.00815148, std=0.0705312
# │ vⁿ:   min=-2.75501, max=2.74374, mean=2.31354e-20, absmean=0.00815357, std=0.0705325
# │ wⁿ:   min=-0.0654883, max=0.0653915, mean=-2.6913e-09, absmean=0.000233615, std=0.0019027
# │ Tⁿ:   min=264.343, max=301.469, mean=283, absmean=283, std=0.675616
# │ Sⁿ:   min=32.6926, max=37.2841, mean=35, absmean=35, std=0.0835568
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-16555.9, max=16515.2, mean=-0.0015841, absmean=53.4367, std=457.128
# │ pⁿʰ⁺ˢ:min=-23.0974, max=23.1637, mean=-2.08936e-19, absmean=0.077698, std=0.658142
# │ pⁿ:   min=-16532.8, max=16492.1, mean=-0.0015841, absmean=53.3591, std=456.47
# │ ρⁿ:   min=1021.42, max=1032.58, mean=1027, absmean=1027, std=0.174499
# │ δρ:   min=-5.58011, max=5.58354, mean=7.40605e-08, absmean=0.0221252, std=0.174499
# │ Gᵘⁿ⁺ʰ: min=-2.31366, max=2.32737, mean=6.47453e-21, absmean=0.00754776, std=0.063289
# │ Gᵛⁿ⁺ʰ: min=-2.3303, max=2.32032, mean=-1.66651e-21, absmean=0.00754944, std=0.06329
# │ Gʷⁿ⁺ʰ: min=-2.17964e-05, max=2.17052e-05, mean=4.64217e-15, absmean=5.82582e-08, std=4.82672e-07
# │ Gᵀⁿ⁺ʰ: min=-48.3121, max=47.2389, mean=-2.60131e-08, absmean=0.129301, std=1.0829
# │ Gˢⁿ⁺ʰ: min=-5.975, max=5.84227, mean=-2.9972e-20, absmean=0.0159912, std=0.133927
# │ ∇⋅u1:  min=-0.522371, max=0.522726, mean=-1.43899e-21, absmean=0.00159228, std=0.0136492
# │ ∇⋅u2:  min=-1.6378e-15, max=1.69731e-15, mean=-4.99651e-20, absmean=9.24699e-18, std=4.51728e-17
# │ wSurf: min=-120.856, max=120.547, mean=-1.28197e-16, absmean=3.13727, std=12.1892
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:313
# ┌ Info: Temperature source term:
# │ div_flux:  mean=-1.12567e-19, absmean=0.450577, std=3.86226
# │ lap_diff:  mean=-4.26788e-23, absmean=7.90715e-05, std=0.000472953
# │ Fᵀ[:,:,1]: mean=-2.60131e-06, absmean=2.60131e-06, std=4.14284e-06
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:215
# ┌ Info: Salinity source term:
# │ div_flux:  mean=7.30511e-20, absmean=0.0557251, std=0.477664
# │ lap_diff:  mean=1.80828e-24, absmean=9.77915e-06, std=5.84925e-05
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:225
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-0.00225012, max=0.00146989, mean=4.67456e-25, absmean=2.08678e-06, std=3.05642e-05
# │ Gwn_u_dot_w: min=-5.60633e-05, max=5.60819e-05, mean=-3.11516e-14, absmean=1.78763e-07, std=1.44111e-06
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:245
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-0.170748, max=0.165796, mean=1.24052e-21, absmean=0.00123701, std=0.0080795
# │ RHS_rec: min=-0.170748, max=0.165796, mean=-1.91899e-21, absmean=0.00123701, std=0.0080795
# │ error:   min=-8.32667e-17, max=1.11022e-16, mean=6.49988e-22, absmean=1.85979e-18, std=3.42669e-18
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:273
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-0.00148197, max=0.0014825, mean=-2.7792e-11, absmean=4.18176e-05, std=0.00015676
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:292
# ┌ Info: Time: 18
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -0.000274804 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-2.98572, max=2.95798, mean=-3.65111e-20, absmean=0.0132378, std=0.102536
# │ vⁿ:   min=-2.99231, max=2.99021, mean=2.43161e-20, absmean=0.0132335, std=0.102537
# │ wⁿ:   min=-0.0547276, max=0.0537161, mean=-2.155e-10, absmean=0.000331647, std=0.00234673
# │ Tⁿ:   min=44.9692, max=519.695, mean=283, absmean=283, std=5.94513
# │ Sⁿ:   min=5.56156, max=64.2732, mean=35, absmean=35, std=0.735263
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-10914.6, max=10717.5, mean=-0.000882084, absmean=59.9473, std=435.011
# │ pⁿʰ⁺ˢ:min=-10.216, max=10.4328, mean=2.38264e-19, absmean=0.069805, std=0.470461
# │ pⁿ:   min=-10904.5, max=10707.7, mean=-0.000882084, absmean=59.8798, std=434.562
# │ ρⁿ:   min=1023.83, max=1030.2, mean=1027, absmean=1027, std=0.115874
# │ δρ:   min=-3.16758, max=3.19988, mean=7.8522e-08, absmean=0.0190425, std=0.115874
# │ Gᵘⁿ⁺ʰ: min=-1.03114, max=1.03318, mean=1.37958e-20, absmean=0.00658621, std=0.0434802
# │ Gᵛⁿ⁺ʰ: min=-1.028, max=1.02894, mean=-6.99591e-21, absmean=0.00658345, std=0.0434833
# │ Gʷⁿ⁺ʰ: min=-8.24801e-05, max=8.25513e-05, mean=-5.1602e-14, absmean=2.71719e-07, std=2.16609e-06
# │ Gᵀⁿ⁺ʰ: min=-222.217, max=222.011, mean=-2.60131e-08, absmean=0.698621, std=5.92445
# │ Gˢⁿ⁺ʰ: min=-27.4826, max=27.4572, mean=2.26616e-19, absmean=0.0864019, std=0.732706
# │ ∇⋅u1:  min=-0.537358, max=0.541816, mean=-8.39464e-21, absmean=0.00254491, std=0.0195215
# │ ∇⋅u2:  min=-2.99795e-15, max=3.5419e-15, mean=-2.8576e-20, absmean=1.46747e-17, std=7.90055e-17
# │ wSurf: min=-196.907, max=197.111, mean=-5.73236e-17, absmean=5.02364, std=20.5605
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:313
# ┌ Info: Temperature source term:
# │ div_flux:  mean=-3.9466e-19, absmean=0.719915, std=5.52278
# │ lap_diff:  mean=-2.06122e-21, absmean=0.000519963, std=0.00449408
# │ Fᵀ[:,:,1]: mean=-2.60131e-06, absmean=2.60131e-06, std=4.14284e-06
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:215
# ┌ Info: Salinity source term:
# │ div_flux:  mean=4.47728e-20, absmean=0.0890354, std=0.683029
# │ lap_diff:  mean=1.202e-24, absmean=6.43064e-05, std=0.000555805
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:225
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-0.0038047, max=0.00277155, mean=7.79609e-24, absmean=5.77313e-06, std=7.05118e-05
# │ Gwn_u_dot_w: min=-4.10059e-05, max=4.18687e-05, mean=1.96252e-13, absmean=2.43961e-07, std=1.6847e-06
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:245
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-2.44697, max=2.42174, mean=-2.79598e-21, absmean=0.00613094, std=0.0563018
# │ RHS_rec: min=-2.44697, max=2.42174, mean=-7.17691e-21, absmean=0.00613094, std=0.0563018
# │ error:   min=-8.88178e-16, max=1.11022e-15, mean=-1.01147e-20, absmean=1.20929e-17, std=2.34345e-17
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:273
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-0.00419369, max=0.00417207, mean=-4.36151e-11, absmean=0.00010953, std=0.000436199
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:292
# ┌ Info: Time: 19
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -0.000301848 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-9.86644, max=9.83057, mean=2.77043e-20, absmean=0.0233569, std=0.209188
# │ vⁿ:   min=-9.86111, max=9.89369, mean=1.61289e-21, absmean=0.0233666, std=0.209203
# │ wⁿ:   min=-0.331123, max=0.326981, mean=-3.6117e-09, absmean=0.000872504, std=0.00765125
# │ Tⁿ:   min=-94.1119, max=682.055, mean=283, absmean=283.008, std=12.1849
# │ Sⁿ:   min=-11.6393, max=84.3531, mean=35, absmean=35.001, std=1.50697
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-79847, max=78936.4, mean=-0.000640012, absmean=193.553, std=1802.34
# │ pⁿʰ⁺ˢ:min=-125.808, max=127.027, mean=-1.63098e-18, absmean=0.31978, std=2.96739
# │ pⁿ:   min=-79719.9, max=78810.6, mean=-0.000640012, absmean=193.236, std=1799.38
# │ ρⁿ:   min=986.405, max=1067.82, mean=1027, absmean=1027, std=1.01964
# │ δρ:   min=-40.5953, max=40.8244, mean=8.29835e-08, absmean=0.116536, std=1.01964
# │ Gᵘⁿ⁺ʰ: min=-12.7449, max=12.6825, mean=2.72628e-20, absmean=0.0312723, std=0.289046
# │ Gᵛⁿ⁺ʰ: min=-12.7312, max=12.7783, mean=-4.86528e-20, absmean=0.0312851, std=0.289057
# │ Gʷⁿ⁺ʰ: min=-4.34145e-05, max=4.48653e-05, mean=3.32694e-13, absmean=3.00142e-07, std=1.96235e-06
# │ Gᵀⁿ⁺ʰ: min=-148.914, max=177.939, mean=-2.60131e-08, absmean=0.90528, std=6.69225
# │ Gˢⁿ⁺ʰ: min=-18.4169, max=22.0066, mean=-1.71738e-19, absmean=0.11196, std=0.827663
# │ ∇⋅u1:  min=-1.94013, max=1.90609, mean=-3.50217e-21, absmean=0.00456277, std=0.0409215
# │ ∇⋅u2:  min=-3.45324e-15, max=3.12639e-15, mean=-3.26227e-20, absmean=2.29912e-17, std=1.01442e-16
# │ wSurf: min=-236.631, max=244.449, mean=-6.00853e-17, absmean=7.38384, std=25.8992
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:313
# ┌ Info: Temperature source term:
# │ div_flux:  mean=5.57521e-18, absmean=1.29318, std=11.6607
# │ lap_diff:  mean=3.1833e-21, absmean=0.00114822, std=0.00901831
# │ Fᵀ[:,:,1]: mean=-2.60131e-06, absmean=2.60131e-06, std=4.14284e-06
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:215
# ┌ Info: Salinity source term:
# │ div_flux:  mean=1.05349e-19, absmean=0.159934, std=1.44213
# │ lap_diff:  mean=1.13125e-22, absmean=0.000142007, std=0.00111534
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:225
# ┌ Info: Vertical velocity source term:
# │ Gwn_u_dot_w: min=-0.0270362, max=0.0132018, mean=-1.42844e-23, absmean=1.73068e-05, std=0.000282309
# │ Gwn_u_dot_w: min=-0.000286038, max=0.000289935, mean=-1.01475e-15, absmean=6.76166e-07, std=5.98206e-06
# │ Gwn_u_dot_w: min=0, max=0, mean=0, absmean=0, std=0
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:245
# ┌ Info: Fourier-spectral solver diagnostics:
# │ RHS:     min=-4.71602, max=4.75739, mean=4.77794e-20, absmean=0.0153973, std=0.130383
# │ RHS_rec: min=-4.71602, max=4.75739, mean=2.37057e-20, absmean=0.0153973, std=0.130383
# │ error:   min=-2.66454e-15, max=2.22045e-15, mean=-1.18512e-20, absmean=2.80561e-17, std=5.50421e-17
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:273
# ┌ Info: Imposing w=0 at top and bottom boundary:
# │ Before w[:, :, 1]:  min=0, max=0, mean=0, absmean=0, std=0
# │ Before w[:, :, 50]: min=-0.0043394, max=0.00423063, mean=8.35295e-10, absmean=0.000119221, std=0.00047723
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:292
# ┌ Info: Time: 20
# │ Tⁿ[50, 50, 1] = 283 K
# │ Tⁿ[50, 50, 2] = 283 K
# │ ΔT[50, 50, 1] = -0.000330705 K
# │ pʰʸ[1, 1, 1]  = 100.714 kPa
# │ pʰʸ[1, 1, 50] = 9970.72 kPa
# │ uⁿ:   min=-35.0114, max=34.8086, mean=4.638e-19, absmean=0.0967159, std=0.861958
# │ vⁿ:   min=-34.9641, max=35.1036, mean=-1.5841e-19, absmean=0.096749, std=0.861978
# │ wⁿ:   min=-0.932706, max=0.962652, mean=-7.25593e-08, absmean=0.00313699, std=0.0263711
# │ Tⁿ:   min=-386.048, max=819.57, mean=283, absmean=283.042, std=12.4818
# │ Sⁿ:   min=-47.7445, max=101.36, mean=35, absmean=35.0052, std=1.54368
# │ pʰʸ:  min=100714, max=2.00421e+07, mean=1.00714e+07, absmean=1.00714e+07, std=5.81445e+06
# │ pʰʸ′: min=-189341, max=194323, mean=-0.028622, absmean=588.051, std=5144.15
# │ pⁿʰ⁺ˢ:min=-254.385, max=246.607, mean=-1.06008e-18, absmean=0.812697, std=7.0064
# │ pⁿ:   min=-189094, max=194069, mean=-0.028622, absmean=587.239, std=5137.15
# │ ρⁿ:   min=958.559, max=1091.68, mean=1027, absmean=1027, std=2.08982
# │ δρ:   min=-68.4415, max=64.6781, mean=8.7445e-08, absmean=0.260743, std=2.08982
# │ Gᵘⁿ⁺ʰ: min=-25.1782, max=25.0289, mean=1.08595e-19, absmean=0.0789385, std=0.675415
# │ Gᵛⁿ⁺ʰ: min=-25.1272, max=25.2343, mean=-5.02681e-20, absmean=0.0789595, std=0.675424
# │ Gʷⁿ⁺ʰ: min=-0.000478996, max=0.000484512, mean=-1.19375e-13, absmean=1.15378e-06, std=1.02625e-05
# │ Gᵀⁿ⁺ʰ: min=-1068.1, max=902.515, mean=-2.60131e-08, absmean=2.28324, std=21.1145
# │ Gˢⁿ⁺ʰ: min=-132.098, max=111.618, mean=1.16537e-18, absmean=0.282379, std=2.61133
# │ ∇⋅u1:  min=-6.68169, max=6.69069, mean=6.43929e-20, absmean=0.0189274, std=0.167279
# │ ∇⋅u2:  min=-1.4289e-14, max=1.41753e-14, mean=-4.32267e-18, absmean=1.11707e-16, std=5.60552e-16
# │ wSurf: min=-1423.92, max=1429.83, mean=-8.71352e-15, absmean=37.3436, std=143.28
# └ @ Main D:\Home\Git\OceanDispatch.jl\examples\deep_convection.jl:313

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for k in 1:Nᶻ
        withfig(fig) do
            PyPlot.pcolormesh(xC, yC, Ru[t,:,:,k], cmap="bwr")
            PyPlot.title("u-velocity @ time step n=$t, z-level k=$k")
            PyPlot.xlabel("x")
            PyPlot.ylabel("y")
            PyPlot.colorbar(label="m/s")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-a1fd1152-5160-4491-9179-4e90db41db71", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-a1fd1152-5160-4491-9179-4e90db41db71\",\"id\":\"ob_1086\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-a1fd1152-5160-4491-9179-4e90db41db71\",\"id\":\"ob_1085\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:k=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-90790640-8ef0-44b2-a65f-d2bc164d5def", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["k"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-90790640-8ef0-44b2-a65f-d2bc164d5def\",\"id\":\"ob_1088\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-90790640-8ef0-44b2-a65f-d2bc164d5def\",\"id\":\"ob_1087\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##409#414")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>))), nothing, getfield(Main, Symbol("##410#415")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:k=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-90790640-8ef0-44b2-a65f-d2bc164d5def", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["k"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-90790640-8ef0-44b2-a65f-d2bc164d5def\",\"id\":\"ob_1088\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-90790640-8ef0-44b2-a65f-d2bc164d5def\",\"id\":\"ob_1087\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##409#414")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for j in 1:Nʸ
        withfig(fig) do
            PyPlot.pcolormesh(xC, zC, copy(Ru[t, :, j, :]'), cmap="bwr")
            PyPlot.title("u-velocity @ time step n=$t, y-slice j=$j")
            PyPlot.xlabel("x (m)")
            PyPlot.ylabel("z (m)")
            PyPlot.colorbar(label="m/s")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-85044268-7697-41dd-8e3a-6fb657b2d715", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-85044268-7697-41dd-8e3a-6fb657b2d715\",\"id\":\"ob_1014\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-85044268-7697-41dd-8e3a-6fb657b2d715\",\"id\":\"ob_1013\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:j=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-71a413b2-3c69-49e6-8706-1294b7c13548", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["j"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-71a413b2-3c69-49e6-8706-1294b7c13548\",\"id\":\"ob_1016\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-71a413b2-3c69-49e6-8706-1294b7c13548\",\"id\":\"ob_1015\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##379#384")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>))), nothing, getfield(Main, Symbol("##380#385")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:j=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-71a413b2-3c69-49e6-8706-1294b7c13548", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["j"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-71a413b2-3c69-49e6-8706-1294b7c13548\",\"id\":\"ob_1016\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-71a413b2-3c69-49e6-8706-1294b7c13548\",\"id\":\"ob_1015\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##379#384")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for i in 1:Nˣ
        withfig(fig) do
            PyPlot.pcolormesh(xC, zC, copy(Ru[t, i, :, :]'), cmap="bwr")
            PyPlot.title("u-velocity @ time step n=$t, x-slice i=$i")
            PyPlot.xlabel("y (m)")
            PyPlot.ylabel("z (m)")
            PyPlot.colorbar(label="m/s")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-78af1397-5da3-4368-aca5-f6574225bb1b", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-78af1397-5da3-4368-aca5-f6574225bb1b\",\"id\":\"ob_1028\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-78af1397-5da3-4368-aca5-f6574225bb1b\",\"id\":\"ob_1027\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:i=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-b3448cdc-75f1-46dc-b1e8-231611ab3a7d", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["i"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-b3448cdc-75f1-46dc-b1e8-231611ab3a7d\",\"id\":\"ob_1030\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-b3448cdc-75f1-46dc-b1e8-231611ab3a7d\",\"id\":\"ob_1029\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##389#394")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>))), nothing, getfield(Main, Symbol("##390#395")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:i=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-b3448cdc-75f1-46dc-b1e8-231611ab3a7d", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["i"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-b3448cdc-75f1-46dc-b1e8-231611ab3a7d\",\"id\":\"ob_1030\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-b3448cdc-75f1-46dc-b1e8-231611ab3a7d\",\"id\":\"ob_1029\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##389#394")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for k in 1:Nᶻ
        withfig(fig) do
            PyPlot.pcolormesh(xC, yC, Rv[t,:,:,k], cmap="bwr")
            PyPlot.title("v-velocity @ time step n=$t, z-level k=$k")
            PyPlot.xlabel("x")
            PyPlot.ylabel("y")
            PyPlot.colorbar(label="m/s")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-66a79e09-3594-4b54-9455-f6df85ae5289", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-66a79e09-3594-4b54-9455-f6df85ae5289\",\"id\":\"ob_1174\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-66a79e09-3594-4b54-9455-f6df85ae5289\",\"id\":\"ob_1173\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:k=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-0ac73c33-3ba9-42fe-a479-6a64eef53ca0", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["k"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-0ac73c33-3ba9-42fe-a479-6a64eef53ca0\",\"id\":\"ob_1176\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-0ac73c33-3ba9-42fe-a479-6a64eef53ca0\",\"id\":\"ob_1175\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##459#464")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>))), nothing, getfield(Main, Symbol("##460#465")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:k=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-0ac73c33-3ba9-42fe-a479-6a64eef53ca0", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["k"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-0ac73c33-3ba9-42fe-a479-6a64eef53ca0\",\"id\":\"ob_1176\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-0ac73c33-3ba9-42fe-a479-6a64eef53ca0\",\"id\":\"ob_1175\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##459#464")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for j in 1:Nʸ
        withfig(fig) do
            PyPlot.pcolormesh(xC, zC, copy(Rv[t, :, j, :]'), cmap="bwr")
            PyPlot.title("v-velocity @ time step n=$t, y-slice j=$j")
            PyPlot.xlabel("x (m)")
            PyPlot.ylabel("z (m)")
            PyPlot.colorbar(label="m/s")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-2f0c1419-7d44-4bbc-be67-3c6068a1b85c", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-2f0c1419-7d44-4bbc-be67-3c6068a1b85c\",\"id\":\"ob_1212\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-2f0c1419-7d44-4bbc-be67-3c6068a1b85c\",\"id\":\"ob_1211\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:j=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-a7e06369-0d88-4e7b-840f-2e5573be6525", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["j"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-a7e06369-0d88-4e7b-840f-2e5573be6525\",\"id\":\"ob_1214\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-a7e06369-0d88-4e7b-840f-2e5573be6525\",\"id\":\"ob_1213\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##469#474")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>))), nothing, getfield(Main, Symbol("##470#475")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:j=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-a7e06369-0d88-4e7b-840f-2e5573be6525", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["j"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-a7e06369-0d88-4e7b-840f-2e5573be6525\",\"id\":\"ob_1214\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-a7e06369-0d88-4e7b-840f-2e5573be6525\",\"id\":\"ob_1213\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##469#474")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for i in 1:Nˣ
        withfig(fig) do
            PyPlot.pcolormesh(xC, zC, copy(Rv[t, i, :, :]'), cmap="bwr")
            PyPlot.title("v-velocity @ time step n=$t, x-slice i=$i")
            PyPlot.xlabel("y (m)")
            PyPlot.ylabel("z (m)")
            PyPlot.colorbar(label="m/s")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-258155f6-b756-4ea9-8c9d-d72f0d680a23", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-258155f6-b756-4ea9-8c9d-d72f0d680a23\",\"id\":\"ob_1240\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-258155f6-b756-4ea9-8c9d-d72f0d680a23\",\"id\":\"ob_1239\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:i=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-7acdb5fb-8ce2-4bcb-b3e3-dbe562ecdd8a", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["i"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-7acdb5fb-8ce2-4bcb-b3e3-dbe562ecdd8a\",\"id\":\"ob_1242\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-7acdb5fb-8ce2-4bcb-b3e3-dbe562ecdd8a\",\"id\":\"ob_1241\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##489#494")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>))), nothing, getfield(Main, Symbol("##490#495")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:i=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-7acdb5fb-8ce2-4bcb-b3e3-dbe562ecdd8a", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["i"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-7acdb5fb-8ce2-4bcb-b3e3-dbe562ecdd8a\",\"id\":\"ob_1242\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-7acdb5fb-8ce2-4bcb-b3e3-dbe562ecdd8a\",\"id\":\"ob_1241\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##489#494")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for k in 1:Nᶻ
        withfig(fig) do
            PyPlot.pcolormesh(xC, yC, Rw[t,:,:,k], cmap="bwr")
            PyPlot.title("w-velocity @ time step n=$t, z-level k=$k")
            PyPlot.xlabel("x")
            PyPlot.ylabel("y")
            PyPlot.colorbar(label="m/s")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-0b78dbb6-fa0c-4408-aa71-16b25f371852", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-0b78dbb6-fa0c-4408-aa71-16b25f371852\",\"id\":\"ob_1268\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-0b78dbb6-fa0c-4408-aa71-16b25f371852\",\"id\":\"ob_1267\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:k=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-3a7cc447-453f-4488-8dd9-c64e3d7f6434", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["k"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-3a7cc447-453f-4488-8dd9-c64e3d7f6434\",\"id\":\"ob_1270\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-3a7cc447-453f-4488-8dd9-c64e3d7f6434\",\"id\":\"ob_1269\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##509#514")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>))), nothing, getfield(Main, Symbol("##510#515")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:k=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-3a7cc447-453f-4488-8dd9-c64e3d7f6434", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["k"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-3a7cc447-453f-4488-8dd9-c64e3d7f6434\",\"id\":\"ob_1270\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-3a7cc447-453f-4488-8dd9-c64e3d7f6434\",\"id\":\"ob_1269\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##509#514")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for j in 1:Nʸ
        withfig(fig) do
            PyPlot.pcolormesh(xC, zC, copy(Rw[t, :, j, :]'), cmap="bwr")
            PyPlot.title("w-velocity @ time step n=$t, y-slice j=$j")
            PyPlot.xlabel("x (m)")
            PyPlot.ylabel("z (m)")
            PyPlot.colorbar(label="m/s")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-9ad6435d-93cf-4a7f-98c6-a715ce1e5644", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-9ad6435d-93cf-4a7f-98c6-a715ce1e5644\",\"id\":\"ob_1254\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-9ad6435d-93cf-4a7f-98c6-a715ce1e5644\",\"id\":\"ob_1253\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:j=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-5d0eacf0-01e7-452c-8dd2-39e63ccfd5e1", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["j"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-5d0eacf0-01e7-452c-8dd2-39e63ccfd5e1\",\"id\":\"ob_1256\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-5d0eacf0-01e7-452c-8dd2-39e63ccfd5e1\",\"id\":\"ob_1255\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##499#504")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>))), nothing, getfield(Main, Symbol("##500#505")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:j=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-5d0eacf0-01e7-452c-8dd2-39e63ccfd5e1", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["j"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-5d0eacf0-01e7-452c-8dd2-39e63ccfd5e1\",\"id\":\"ob_1256\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-5d0eacf0-01e7-452c-8dd2-39e63ccfd5e1\",\"id\":\"ob_1255\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##499#504")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for i in 1:Nˣ
        withfig(fig) do
            PyPlot.pcolormesh(xC, zC, copy(Rw[t, i, :, :]'), cmap="bwr")
            PyPlot.title("w-velocity @ time step n=$t, x-slice i=$i")
            PyPlot.xlabel("y (m)")
            PyPlot.ylabel("z (m)")
            PyPlot.colorbar(label="m/s")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-f1e30f46-87f2-47fb-a7db-b478daef4693", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-f1e30f46-87f2-47fb-a7db-b478daef4693\",\"id\":\"ob_1140\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-f1e30f46-87f2-47fb-a7db-b478daef4693\",\"id\":\"ob_1139\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:i=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-8f7ce22a-5bfa-4245-a029-1525390c1ba1", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["i"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-8f7ce22a-5bfa-4245-a029-1525390c1ba1\",\"id\":\"ob_1142\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-8f7ce22a-5bfa-4245-a029-1525390c1ba1\",\"id\":\"ob_1141\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##439#444")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>))), nothing, getfield(Main, Symbol("##440#445")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:i=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-8f7ce22a-5bfa-4245-a029-1525390c1ba1", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["i"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-8f7ce22a-5bfa-4245-a029-1525390c1ba1\",\"id\":\"ob_1142\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-8f7ce22a-5bfa-4245-a029-1525390c1ba1\",\"id\":\"ob_1141\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##439#444")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for k in 1:Nᶻ
        withfig(fig) do
            PyPlot.pcolormesh(xC, yC, RT[t,:,:,k], cmap="bwr")
            PyPlot.title("Temperature @ time step n=$t, z-level k=$k")
            PyPlot.xlabel("x")
            PyPlot.ylabel("y")
            PyPlot.colorbar(label="K")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-6116b49a-cb3c-4b6e-88b0-9881d1a6a774", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-6116b49a-cb3c-4b6e-88b0-9881d1a6a774\",\"id\":\"ob_1432\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-6116b49a-cb3c-4b6e-88b0-9881d1a6a774\",\"id\":\"ob_1431\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:k=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-b5a37b2a-0953-4eb4-afc0-02685f436759", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["k"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-b5a37b2a-0953-4eb4-afc0-02685f436759\",\"id\":\"ob_1434\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-b5a37b2a-0953-4eb4-afc0-02685f436759\",\"id\":\"ob_1433\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##579#584")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>))), nothing, getfield(Main, Symbol("##580#585")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:k=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-b5a37b2a-0953-4eb4-afc0-02685f436759", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["k"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-b5a37b2a-0953-4eb4-afc0-02685f436759\",\"id\":\"ob_1434\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-b5a37b2a-0953-4eb4-afc0-02685f436759\",\"id\":\"ob_1433\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##579#584")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for j in 1:Nʸ
        withfig(fig) do
            PyPlot.pcolormesh(xC, zC, copy(Rw[t, :, j, :]'), cmap="bwr")
            PyPlot.title("Temperature @ time step n=$t, y-slice j=$j")
            PyPlot.xlabel("x (m)")
            PyPlot.ylabel("z (m)")
            PyPlot.colorbar(label="K")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-d6972803-6619-456a-ada5-0db7fcdbed86", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-d6972803-6619-456a-ada5-0db7fcdbed86\",\"id\":\"ob_1446\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-d6972803-6619-456a-ada5-0db7fcdbed86\",\"id\":\"ob_1445\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:j=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-b1b9cb21-490a-41f4-a14e-4e93a984a2c6", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["j"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-b1b9cb21-490a-41f4-a14e-4e93a984a2c6\",\"id\":\"ob_1448\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-b1b9cb21-490a-41f4-a14e-4e93a984a2c6\",\"id\":\"ob_1447\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##589#594")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>))), nothing, getfield(Main, Symbol("##590#595")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:j=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-b1b9cb21-490a-41f4-a14e-4e93a984a2c6", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["j"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-b1b9cb21-490a-41f4-a14e-4e93a984a2c6\",\"id\":\"ob_1448\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-b1b9cb21-490a-41f4-a14e-4e93a984a2c6\",\"id\":\"ob_1447\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##589#594")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for i in 1:Nˣ
        withfig(fig) do
            PyPlot.pcolormesh(xC, zC, copy(RT[t, i, :, :]'), cmap="bwr")
            PyPlot.title("Temperature @ time step n=$t, x-slice i=$i")
            PyPlot.xlabel("y (m)")
            PyPlot.ylabel("z (m)")
            PyPlot.colorbar(label="K")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-65f0feaf-bddd-418e-9bb0-55d2b804fdfa", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-65f0feaf-bddd-418e-9bb0-55d2b804fdfa\",\"id\":\"ob_1474\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-65f0feaf-bddd-418e-9bb0-55d2b804fdfa\",\"id\":\"ob_1473\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:i=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-66a5c3fc-a668-4110-ab15-0cd724fa9351", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["i"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-66a5c3fc-a668-4110-ab15-0cd724fa9351\",\"id\":\"ob_1476\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-66a5c3fc-a668-4110-ab15-0cd724fa9351\",\"id\":\"ob_1475\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##609#614")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>))), nothing, getfield(Main, Symbol("##610#615")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:i=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-66a5c3fc-a668-4110-ab15-0cd724fa9351", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["i"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-66a5c3fc-a668-4110-ab15-0cd724fa9351\",\"id\":\"ob_1476\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-66a5c3fc-a668-4110-ab15-0cd724fa9351\",\"id\":\"ob_1475\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##609#614")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for k in 1:Nᶻ
        withfig(fig) do
            PyPlot.pcolormesh(xC, yC, RS[t,:,:,k], cmap="bwr")
            PyPlot.title("Salinity @ time step n=$t, z-level k=$k")
            PyPlot.xlabel("x")
            PyPlot.ylabel("y")
            PyPlot.colorbar(label="psu")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-72bc01a1-53ca-4e8d-9509-5be9c896c730", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-72bc01a1-53ca-4e8d-9509-5be9c896c730\",\"id\":\"ob_1502\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-72bc01a1-53ca-4e8d-9509-5be9c896c730\",\"id\":\"ob_1501\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:k=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-f9429767-f446-43e0-833f-29539753ae6b", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["k"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-f9429767-f446-43e0-833f-29539753ae6b\",\"id\":\"ob_1504\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-f9429767-f446-43e0-833f-29539753ae6b\",\"id\":\"ob_1503\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##629#634")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>))), nothing, getfield(Main, Symbol("##630#635")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:k=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-f9429767-f446-43e0-833f-29539753ae6b", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["k"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-f9429767-f446-43e0-833f-29539753ae6b\",\"id\":\"ob_1504\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-f9429767-f446-43e0-833f-29539753ae6b\",\"id\":\"ob_1503\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##629#634")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for j in 1:Nʸ
        withfig(fig) do
            PyPlot.pcolormesh(xC, zC, copy(RS[t, :, j, :]'), cmap="bwr")
            PyPlot.title("Salinity @ time step n=$t, y-slice j=$j")
            PyPlot.xlabel("x (m)")
            PyPlot.ylabel("z (m)")
            PyPlot.colorbar(label="psu")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-5df7bdb0-a49d-4b81-8721-66ddf052ce02", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-5df7bdb0-a49d-4b81-8721-66ddf052ce02\",\"id\":\"ob_1522\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-5df7bdb0-a49d-4b81-8721-66ddf052ce02\",\"id\":\"ob_1521\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:j=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-414775bb-95d0-4781-badd-fba3a05f231a", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["j"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-414775bb-95d0-4781-badd-fba3a05f231a\",\"id\":\"ob_1524\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-414775bb-95d0-4781-badd-fba3a05f231a\",\"id\":\"ob_1523\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##639#644")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>))), nothing, getfield(Main, Symbol("##640#645")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:j=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-414775bb-95d0-4781-badd-fba3a05f231a", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["j"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-414775bb-95d0-4781-badd-fba3a05f231a\",\"id\":\"ob_1524\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-414775bb-95d0-4781-badd-fba3a05f231a\",\"id\":\"ob_1523\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##639#644")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for i in 1:Nˣ
        withfig(fig) do
            PyPlot.pcolormesh(xC, zC, copy(RT[t, i, :, :]'), cmap="bwr")
            PyPlot.title("Salinity @ time step n=$t, x-slice i=$i")
            PyPlot.xlabel("y (m)")
            PyPlot.ylabel("z (m)")
            PyPlot.colorbar(label="K")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-aba9b7bf-3baf-4f68-ae50-cb851394cda9", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-aba9b7bf-3baf-4f68-ae50-cb851394cda9\",\"id\":\"ob_1536\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-aba9b7bf-3baf-4f68-ae50-cb851394cda9\",\"id\":\"ob_1535\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:i=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-ed0cf33f-5252-4f8a-985c-9f919f3ddb64", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["i"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-ed0cf33f-5252-4f8a-985c-9f919f3ddb64\",\"id\":\"ob_1538\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-ed0cf33f-5252-4f8a-985c-9f919f3ddb64\",\"id\":\"ob_1537\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##649#654")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>))), nothing, getfield(Main, Symbol("##650#655")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:i=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-ed0cf33f-5252-4f8a-985c-9f919f3ddb64", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["i"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-ed0cf33f-5252-4f8a-985c-9f919f3ddb64\",\"id\":\"ob_1538\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-ed0cf33f-5252-4f8a-985c-9f919f3ddb64\",\"id\":\"ob_1537\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##649#654")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for k in 1:Nᶻ
        withfig(fig) do
            PyPlot.pcolormesh(xC, yC, RpHY′[t,:,:,k], cmap="bwr")
            PyPlot.title("pHY′ @ time step n=$t, z-level k=$k")
            PyPlot.xlabel("x")
            PyPlot.ylabel("y")
            PyPlot.colorbar(label="Pa")
        end
   end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-bde2a629-5009-41a7-ad1f-43017876b4b5", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-bde2a629-5009-41a7-ad1f-43017876b4b5\",\"id\":\"ob_1550\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-bde2a629-5009-41a7-ad1f-43017876b4b5\",\"id\":\"ob_1549\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:k=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-3f71a7a2-e3e6-41be-bddb-50cf6db70e3c", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["k"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-3f71a7a2-e3e6-41be-bddb-50cf6db70e3c\",\"id\":\"ob_1552\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-3f71a7a2-e3e6-41be-bddb-50cf6db70e3c\",\"id\":\"ob_1551\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##659#664")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>))), nothing, getfield(Main, Symbol("##660#665")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:k=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-3f71a7a2-e3e6-41be-bddb-50cf6db70e3c", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["k"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-3f71a7a2-e3e6-41be-bddb-50cf6db70e3c\",\"id\":\"ob_1552\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-3f71a7a2-e3e6-41be-bddb-50cf6db70e3c\",\"id\":\"ob_1551\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##659#664")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for j in 1:Nʸ
        withfig(fig) do
            PyPlot.pcolormesh(xC, zC, copy(RpHY′[t, :, j, :]'), cmap="bwr")
            PyPlot.title("pHY′ @ time step n=$t, y-slice j=$j")
            PyPlot.xlabel("x (m)")
            PyPlot.ylabel("z (m)")
            PyPlot.colorbar(label="Pa")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-d7793d01-f62f-4d4b-8cf5-60ab7db2e79e", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-d7793d01-f62f-4d4b-8cf5-60ab7db2e79e\",\"id\":\"ob_1564\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-d7793d01-f62f-4d4b-8cf5-60ab7db2e79e\",\"id\":\"ob_1563\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:j=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-db638262-ad99-4bbd-ace3-5990593f7fca", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["j"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-db638262-ad99-4bbd-ace3-5990593f7fca\",\"id\":\"ob_1566\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-db638262-ad99-4bbd-ace3-5990593f7fca\",\"id\":\"ob_1565\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##669#674")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>))), nothing, getfield(Main, Symbol("##670#675")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:j=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-db638262-ad99-4bbd-ace3-5990593f7fca", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["j"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-db638262-ad99-4bbd-ace3-5990593f7fca\",\"id\":\"ob_1566\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-db638262-ad99-4bbd-ace3-5990593f7fca\",\"id\":\"ob_1565\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##669#674")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for i in 1:Nˣ
        withfig(fig) do
            PyPlot.pcolormesh(xC, zC, copy(RpHY′[t, i, :, :]'), cmap="bwr")
            PyPlot.title("pHY′ @ time step n=$t, x-slice i=$i")
            PyPlot.xlabel("y (m)")
            PyPlot.ylabel("z (m)")
            PyPlot.colorbar(label="Pa")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-a1c0119a-ab9c-44c8-81c4-dc7de9f0b5c3", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-a1c0119a-ab9c-44c8-81c4-dc7de9f0b5c3\",\"id\":\"ob_1592\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-a1c0119a-ab9c-44c8-81c4-dc7de9f0b5c3\",\"id\":\"ob_1591\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:i=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-002196be-eb37-446a-a254-93cc2ca8b74f", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["i"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-002196be-eb37-446a-a254-93cc2ca8b74f\",\"id\":\"ob_1594\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-002196be-eb37-446a-a254-93cc2ca8b74f\",\"id\":\"ob_1593\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##689#694")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>))), nothing, getfield(Main, Symbol("##690#695")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:i=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-002196be-eb37-446a-a254-93cc2ca8b74f", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["i"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-002196be-eb37-446a-a254-93cc2ca8b74f\",\"id\":\"ob_1594\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-002196be-eb37-446a-a254-93cc2ca8b74f\",\"id\":\"ob_1593\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##689#694")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for k in 1:Nᶻ
        withfig(fig) do
            PyPlot.pcolormesh(xC, yC, RpNHS[t,:,:,k], cmap="bwr")
            PyPlot.title("pHY+S @ time step n=$t, z-level k=$k")
            PyPlot.xlabel("x")
            PyPlot.ylabel("y")
            PyPlot.colorbar(label="Pa")
        end
   end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-5cccb11f-b77e-413a-bc63-470669cfeeff", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-5cccb11f-b77e-413a-bc63-470669cfeeff\",\"id\":\"ob_1606\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-5cccb11f-b77e-413a-bc63-470669cfeeff\",\"id\":\"ob_1605\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:k=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-5883a7d6-3ad3-48e5-a689-8e105ceb2ba3", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["k"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-5883a7d6-3ad3-48e5-a689-8e105ceb2ba3\",\"id\":\"ob_1608\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-5883a7d6-3ad3-48e5-a689-8e105ceb2ba3\",\"id\":\"ob_1607\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##699#704")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>))), nothing, getfield(Main, Symbol("##700#705")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:k=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-5883a7d6-3ad3-48e5-a689-8e105ceb2ba3", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["k"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-5883a7d6-3ad3-48e5-a689-8e105ceb2ba3\",\"id\":\"ob_1608\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-5883a7d6-3ad3-48e5-a689-8e105ceb2ba3\",\"id\":\"ob_1607\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##699#704")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for j in 1:Nʸ
        withfig(fig) do
            PyPlot.pcolormesh(xC, zC, copy(RpNHS[t, :, j, :]'), cmap="bwr")
            PyPlot.title("pNH+S @ time step n=$t, y-slice j=$j")
            PyPlot.xlabel("x (m)")
            PyPlot.ylabel("z (m)")
            PyPlot.colorbar(label="Pa")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-88fb2739-4479-4e7b-b1ee-8c47b77699ff", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-88fb2739-4479-4e7b-b1ee-8c47b77699ff\",\"id\":\"ob_1620\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-88fb2739-4479-4e7b-b1ee-8c47b77699ff\",\"id\":\"ob_1619\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:j=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-6d8029e2-06e3-4958-9908-2cf5c347247f", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["j"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-6d8029e2-06e3-4958-9908-2cf5c347247f\",\"id\":\"ob_1622\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-6d8029e2-06e3-4958-9908-2cf5c347247f\",\"id\":\"ob_1621\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##709#714")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>))), nothing, getfield(Main, Symbol("##710#715")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:j=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-6d8029e2-06e3-4958-9908-2cf5c347247f", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["j"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-6d8029e2-06e3-4958-9908-2cf5c347247f\",\"id\":\"ob_1622\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-6d8029e2-06e3-4958-9908-2cf5c347247f\",\"id\":\"ob_1621\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##709#714")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>)))))

# %%
PyPlot.close("all")
fig = PyPlot.figure(figsize=(6.5, 5))
@manipulate for t in 1:Nᵗ
    @manipulate for i in 1:Nˣ
        withfig(fig) do
            PyPlot.pcolormesh(xC, zC, copy(RpNHS[t, i, :, :]'), cmap="bwr")
            PyPlot.title("pNH+S @ time step n=$t, x-slice i=$i")
            PyPlot.xlabel("y (m)")
            PyPlot.ylabel("z (m)")
            PyPlot.colorbar(label="Pa")
        end
    end
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:t=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 10), Observable{Int64} with 2 listeners. Value:
# 10, Scope("knockout-component-e2bb6898-f8f0-45f3-8f42-96da02984c97", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["t"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>20,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 10, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":10}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-e2bb6898-f8f0-45f3-8f42-96da02984c97\",\"id\":\"ob_1634\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-e2bb6898-f8f0-45f3-8f42-96da02984c97\",\"id\":\"ob_1633\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:i=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-5d4d41d1-99a4-460c-8f16-9edae9da62a4", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["i"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-5d4d41d1-99a4-460c-8f16-9edae9da62a4\",\"id\":\"ob_1636\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-5d4d41d1-99a4-460c-8f16-9edae9da62a4\",\"id\":\"ob_1635\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##719#724")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>))), nothing, getfield(Main, Symbol("##720#725")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:i=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 2 listeners. Value:
# 50), Observable{Int64} with 2 listeners. Value:
# 50, Scope("knockout-component-5d4d41d1-99a4-460c-8f16-9edae9da62a4", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["i"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>100,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 2 listeners. Value:
# 50, nothing)), Set(String[]), nothing, Any["knockout"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout.js", "knockout_punches"=>"C:\\Users\\Ali\\.julia\\packages\\Knockout\\JIqpG\\src\\..\\assets\\knockout_punches.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\all.js", "C:\\Users\\Ali\\.julia\\packages\\InteractBase\\Q4IkI\\src\\..\\assets\\style.css", "C:\\Users\\Ali\\.julia\\packages\\InteractBulma\\Ohu5Y\\src\\..\\assets\\main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":50}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (_webIOScope.setObservableValue({\"name\":\"changes\",\"scope\":\"knockout-component-5d4d41d1-99a4-460c-8f16-9edae9da62a4\",\"id\":\"ob_1636\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (_webIOScope.setObservableValue({\"name\":\"value\",\"scope\":\"knockout-component-5d4d41d1-99a4-460c-8f16-9edae9da62a4\",\"id\":\"ob_1635\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), ##52#53{#dom#13{##dom#11#12{Dict{Any,Any},DOM}},typeof(scope)}(#dom#13{##dom#11#12{Dict{Any,Any},DOM}}(##dom#11#12{Dict{Any,Any},DOM}(Dict{Any,Any}(:className=>"field"), DOM(:html, :div))), scope))), Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>), nothing, getfield(Main, Symbol("##719#724")){Observable{Any}}(Observable{Any} with 0 listeners. Value:
# Figure(PyObject <Figure size 650x500 with 2 Axes>)))))
